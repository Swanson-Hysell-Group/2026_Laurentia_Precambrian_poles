# %% [markdown]
# # Stillwater ca. 2705 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Wyoming.
# - Compiled unit/pole label: Stillwater Complex - C2.
# - Sampling note: the paleomagnetic dataset used here is described as coming from the East Boulder Plateau area of the Stillwater Complex.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - mean direction DEC/INC = 171.0°/-63.0°; K = 32.0.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - **Proposed new nominal age 2709 Ma, lomagage 2709 Ma, himagage 2712 Ma** (legacy "2705±4" treatment).
# - Latest high-precision U-Pb zircon-baddeleyite CA-TIMS ages for J-M Reef mineralized samples (Wall et al., 2016) are:
#   - Basal series: Benbow area has a weighted mean 207Pb/206Pb date of 2712.24 ± 0.61 Ma
#   - Frog Pond adit: 2709.11 ± 0.56 Ma
#   - East Boulder mine: 2709.28 ± 0.32 Ma
#   - West Fork area: 2709.00 ± 0.45 Ma
# - Most of the paleomagnetic samples from Selkin et al., 2008, are from above the basal series which means the date for the paleomagnetic pole is probably closer to 2709 Ma.
#
# ## References
#
# - Paleomagnetic source: Selkin, P. A., Gee, J. S., Meurer, W. P., & Hemming, S. R. (2008). Paleointensity record from the 2.7 Ga Stillwater Complex, Montana. Geochemistry, Geophysics, Geosystems, 9, 23 pp. https://doi.org/10.1029/2008GC001950
# - Geochronology source: Wall, C. J., & Scoates, J. S. (2016). High-Precision U-Pb Zircon-Baddeleyite Dating of the J-M Reef Platinum Group Element Deposit in the Stillwater Complex, Montana (USA). Economic Geology, 111(3), 771-782. https://doi.org/10.2113/econgeo.111.3.771

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
_ = plot_pole_overlap('Stillwater Complex - C2', Laurentia_poles, Torsvik2012_Laurentia)
