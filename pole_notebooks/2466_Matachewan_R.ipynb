# %% [markdown]
# # Matachewan R ca. 2466 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Superior(East).
# - Compiled unit/pole label: MATACHEWAN R.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - mean direction DEC/INC = 207.6°/-16.6°; K = 1000.0.
# - Field/statistical tests noted in compilation: C+.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: nominal age 2466 Ma, lomagage 2443.0 Ma, himagage 2489.0 Ma.
# - **Proposed new age bracket: nominal age 2460 Ma, lomagage 2446 Ma, himagage 2473 Ma**.
# - Compilation method note: In the Hearst region of domain (II), two dykes contribute to
# the 2446 ± 3 Ma upper-intercept age: one (LH87-11) corresponds to site 214 of Halls and Palmer (1990) and yielded N-polarity, and the other (208) corresponds to site 208 of Halls and Palmer (1990) and yielded R-polarity with statistics not passing our quality criteria. Evans and Halls (2010) consider the R polarity to be older than the N polarity. The N polarity age is inferred from one dike that yielded an age of 2446 ± 3 Ma.
#
# ## References
#
# - Paleomagnetic source: Evans,D.A.D., Halls,H.C. (2010). Restoring Proterozoic deformation within the Superior craton. Precambrian Res., 183, 474-489.
# - Geochronology / age-constraint note (compilation): Heaman, L. M. (1997). Global mafic magmatism at 2.45 Ga: Remnants of an ancient large igneous province? Geology, 25(4), 299–302. https://doi.org/10.1130/0091-7613(1997)025%253C0299:GMMAGR%253E2.3.CO;2

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
plot_pole_overlap('MATACHEWAN R',Laurentia_poles,Torsvik2012_Laurentia)
