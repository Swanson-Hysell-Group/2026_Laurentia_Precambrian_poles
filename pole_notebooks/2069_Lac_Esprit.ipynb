# %% [markdown]
# # Lac Esprit ca. 2069 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Superior(East).
# - Compiled unit/pole label: LAC ESPRIT.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 8 sites, N = 82 samples; mean direction DEC/INC = 146.9°/-56.4°; K = 1000.0.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: nominal age 2069 Ma, lomagage 2068.0 Ma, himagage 2070.0 Ma.
# - Compilation method note: Buchan et al., 2007 obtained a U–Pb baddeleyite concordia upper intercept age of 2069 ± 1 Ma from a Lac Esprit dike swarm
#
# ## References
#
# - Paleomagnetic source: Evans,D.A.D., Halls,H.C. (2010). Restoring Proterozoic deformation within the Superior craton. Precambrian Res., 183, 474-489.
# - Geochronology / age-constraint note (compilation): Buchan, K. L., Goutier, J., Hamilton, M. A., Ernst, R. E., & Matthews, W. A. (2007). Paleomagnetism, U–Pb geochronology, and geochemistry of Lac Esprit and other dyke swarms, James Bay area, Quebec, and implications for Paleoproterozoic deformation of the Superior Province. Canadian Journal of Earth Sciences, 44(5), 643–664. https://doi.org/10.1139/e06-124

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('LAC ESPRIT',Laurentia_poles)
# Out:
# N = 82 (N ≥ 25; sufficient sample number);
# B = 8 (B ≥ 8; sufficient site number);
# K = 1000 (K ≥ 70; concern about underrepresenting PSV);
# A_95 of 6.4 passes Deenen et al. (2011) criteria of being between 5.2 and 22.1 for this number of sites

# %%
plot_pole_overlap('LAC ESPRIT',Laurentia_poles,Torsvik2012_Laurentia)
