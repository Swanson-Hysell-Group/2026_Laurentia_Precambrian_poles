# %% [markdown]
# # McNamara pole ~1390 Ma Elston et al. (2002)

# %% [markdown]
# ## Geologic context

# %% [markdown]
# The Mesoproterozoic Belt Supergroup, located in Montana and Idaho, USA, and Alberta and British Columbia, Canada, spans an enormous extent covering > 200,000 km<sup>2</sup> (Lonn et al. 2020).  It is a predominantly sedimentary succession over 15 km thick in places, which has been subdivided into four groups. The McNamara Formation is in the Missoula Group, which is the uppermost group (Lonn et al. 2020).  The Belt Supergroup was an early place of paleomagnetic analyses in the 1950s and 1960s, but the majority of subsequent paleomagnetic analyses were the product of years of work by Don Elston of the United States Geologic Survey and colleagues, which were published in Elston et al. (2002).  While Elston et al. (2002) note that carbonates and green-grey-black siliclastics were analyzed, the "weak and incoherent magnetizations" led the study to focus on red beds spanning the entirety of the stratigraphic succession.
#
# The McNamara Formation has a type section near Missoula, MT, where it is a red and green mudstone that is noted to be "chert-bearing", capped by a red quartz-rich sandstone unit with both flat-laminations and cross-bedding (Winston and Link 1993). Due to the microlaminae (mm-scale) and cm-scale laminae of siltstone and claystone, which contain abundant mudcracks, it is proposed to have been deposited in a playa mudflat environment that was covered by an alluvial environment. To the northwest, the McNamara fines and grades into green argillite, which is called the Libby Formation and -- depending on the study -- may include units of the Garnet Range Formation. The name McNamara is preferred by some across the entire basin within the United States, based on original publication age (Winston and Link 1993, Clapp and Deiss, 1931), while others use different names from east to west (Lonn et al. 2020). To the north in Canada, the McNamara Formation is correlated to the Roosville Formation (Lonn et al. 2020).

# %% [markdown]
# ## Paleomagnetic and rock magnetic data

# %% [markdown]
# According to Elston at el. (2002), "red beds are found near the base and top of the McNamara Formation with gray beds in between." No formal rock magnetic analyses were performed, but stepwise thermal demagnetizatin on select samples showed that a large component of the signal unblocked between 650 and 670/680 ºC, suggesting coarse-grained "specular" detrital hematite.   It is worth noting that the blanket demagnetization steps used to find paleomagnetic directions often did not reach these temperatures, with 5 sites at 590 ºC, two sites at 550 ºC, and two sites at 650 ºC.  It is noted that stepwise thermal demagnetization was performed on pilot samples in up to 8 steps.
#
# Site mean directions are reported using Fisher statistics. Mean site directions in the McNamara Formation have smeared declinations but constant inclination, which was interpreted to indicate relative vertical-axis rotation of > 50º; however, since sites spanned a large area, rotations were assumed as random and a mean was taken of all the sites (with the exclusion of the reversed interval in Trout Creek due to "contamination"). The formation mean for 10 sites was published as a virtual geomagnetic pole (prior literature data from Collinson and Runcorn, 1960, was reported but not included in this mean).
#
# The upper half of the McNamara is predominantly reverse polarity (as defined by Elston), contrasting with the normal polarity lower McNamara. Three sites showed mixed polarity in between these two polarity zones (West Twin Creek, Warm Spring Canyon, and the top of the Spotted Bear section, overlying 200 m of normal polarity). Reported site directions for Warm Springs Canyon and West Twin Creek were presumably flipped to the same hemisphere, such that the direction is reversed, while Spotted Bear is reported as fully normal (suggesting that the mixed polarity zone samples were not included). A further site (Trout Creek) is separated by polarity, with the reversed directions excluded. The initial paper suggested that normal and reversed directions were close to antiparallel, but no formal statistical analyses were reported. See below for formal statistical analyses.
#
# The data did pass a fold test with 97 $\pm$ 7% untilting as the optimum using Watson and Enkin, 1993.

# %% [markdown]
# ## Geochronology Constraints

# %% [markdown]
# Evans et al. (2000) reported a SHRIMP U–Pb zircon age of 1401 ± 6 Ma for a tuff in the very thin transition zone between the Bonner Quartzite and Libby Formation.  As noted above, this contact would correlate to the base of the McNamara Formation.
#
# Detrital zircon data from within the Roosville Formation finds maximum depositional ages of
# 1375.4 ± 10.5 Ma (YC2σ[3+], MSWD = 4.20, n = 3) and 1386.3 ± 11.2 Ma (YC1σ[2+], MSWD = 1.32, n = 2) (Hirtz et al., 2024), suggesting the McNamara Formation may have had a slow sedimentation rate.
#
# These sedimentary ages are consistent with an uppermost age constraint from a diabase in the Salmon River Arch of Idaho, which intrudes the Lemhi group (potentially the Yellowjacket Formation, although the stratigraphy has been substantially revised) and has an age of 1379 ± 1 Ma based on U-Pb TIMS dating of zircons (Doughty and Chamberlain 1996).  The Lemhi Group (and Yellowjacket Formation) has been correlated to units stratigraphically below the McNamara Formation within the Missoula Group, but has historically been used to mark the "end" of deposition within the Belt Basin.
#
# We have chosen to focus on the igneous age constraints and split the difference between the two for a nominal age of 1392 Ma.

# %% [markdown]
# ## References

# %% [markdown]
# Clapp, C. H., and Deiss, C. F., 1931, Correlation of Montana Algonkian formations:
# Geological Society of America Bulletin, v. 42, p. 673-696.
#
# Collinson, D.W., and Runcorn, S.K., 1960, Polar wandering and continental drift: Evidence of paleomagnetic observations in the United States: Geological Society of America Bulletin, v. 71, p. 915–958.
#
# Doughty, P.T., and Chamberlain, K.R., 1996, Salmon River Arch revisited: New evidence for 1370 Ma rifting near the end of deposition in the Middle Proterozoic Belt Basin: Canadian Journal of Earth Sciences, v. 33, p. 1037– 1052, DOI: 10.1139/e96-079.
#
# Elston, D. P., Enkin, R. J., Baker, J., & Kisilevsky, D. K. (2002). Tightening the Belt: Paleomagnetic-stratigraphic constraints on deposition, correlation, and deformation of the Middle Proterozoic (ca. 1.4 Ga) Belt-Purcell Supergroup, United States and Canada. Geological Society of America Bulletin, 114(5), 619-638. DOI: 10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
#
# Evans, K.V., Aleinikoff , J.N., Obradovich, J.D., and Fanning, C.M., 2000, SHRIMP U-Pb geochronology
# of volcanic rocks, Belt Supergroup, western Montana: Evidence for rapid deposition of sedimentary strata: Canadian Journal of Earth Sciences, v. 37, p. 1287–1300, DOI: 10.1139/cjes-37-9-1287
#
# Hirtz, J.A.M., Constenius, K.N., Horton, B.K., Valencia, V.A., and Pratt, B.R., 2024, Continental-scale drainage reorganization during Mesoproterozoic orogenesis: Evidence from the Belt Basin of western North America: Geosphere, v. 20, no. 4, p. 1133– 1161, https://doi.org/10.1130/GES02732.1
#
# Lonn, J. D., Burmester, R. F., Lewis, R. S., McFaddan, M. D., Metesh, J. J., & Vuke, S. M. (2020). The Mesoproterozoic Belt Supergroup. in Barth, S., ed., Geology of Montana: Montana Bureau of Mines and Geology Special Publication 122, 1, 1-38.
#
# Winston, D., and Link, P.K., 1993, Middle Proterozoic rocks of Montana, Idaho and eastern Washington: The Belt Supergroup, in Reed, J.C., Jr., Bickford, M.E., Houston, R.S., Link, P.K., Rankin, D.W.,
# Sims, P.K., and Van Schmus, W.R., eds., Precambrian: Conterminous U.S.: Geological Society of
# America, Decade of North American Geology, v. C-2, p. 487–517.

# %% [markdown]
# ## Site-level data

# %%
import pole_tools as pt
import pmagpy.ipmag as ipmag
import pmagpy.pmag as pmag
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
sites_df = pd.read_csv('../data/1392_McNamara/sites.txt', sep='\t',header=1)

# %%
sites_df.head()
# Out:
#     age  age_high  age_low  age_sigma age_unit  \
# 0  1392      1407     1378        NaN       Ma
# 1  1392      1407     1378        NaN       Ma
# 2  1392      1407     1378        NaN       Ma
# 3  1392      1407     1378        NaN       Ma
# 4  1392      1407     1378        NaN       Ma
#
#                                          citations  \
# 0  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 1  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 2  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;1
# 3  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;1
# 4  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;0
#
#                                          description  dir_alpha95  dir_dec  \
# 0  Geochronological results from Doughty and Cham...          7.5     26.5
# 1  Geochronological results from Doughty and Cham...          7.5     19.7
# 2  Geochronological results from Doughty and Cham...          8.9     34.0
# ...

# %% [markdown]
# ## Add VGPs

# %%
sites_df['vgp_lon'], sites_df['vgp_lat'], sites_df['vgp_dp'], sites_df['vgp_dm'] = pmag.dia_vgp(sites_df['dir_dec'], sites_df['dir_inc'], sites_df['dir_alpha95'], sites_df['lat'], sites_df['lon'])

# %%
sites_df.head()
# Out:
#     age  age_high  age_low  age_sigma age_unit  \
# 0  1392      1407     1378        NaN       Ma
# 1  1392      1407     1378        NaN       Ma
# 2  1392      1407     1378        NaN       Ma
# 3  1392      1407     1378        NaN       Ma
# 4  1392      1407     1378        NaN       Ma
#
#                                          citations  \
# 0  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 1  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 2  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;1
# 3  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;1
# 4  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;0
#
#                                          description  dir_alpha95  dir_dec  \
# 0  Geochronological results from Doughty and Cham...          7.5     26.5
# 1  Geochronological results from Doughty and Cham...          7.5     19.7
# 2  Geochronological results from Doughty and Cham...          8.9     34.0
# ...

# %%
# pmag.magic_write('../data/1390_McNamara/sites.txt', sites_df, 'sites', dataframe=True)

# %% [markdown]
# ## Site Location Map

# %%
pt.plot_site_map(sites_df, zoom_start=8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ## Plot

# %%
sites_geo = sites_df[sites_df['dir_tilt_correction'] == 0]
sites_tilt = sites_df[sites_df['dir_tilt_correction'] == 100]

plt.figure(figsize = (4,4))
ipmag.plot_net()

for row, site in sites_tilt.iterrows():
    if site['citations'] == '10.1130/0016-7606(1960)71[915:PWACDE]2.0.CO;2':
        col = 'orange'
    elif site['result_quality'] == 'g':
        col = 'b'
    elif site['result_quality'] == 'b':
        col = 'r'
    ipmag.plot_di_mean(dec=site['dir_dec'],
                       inc=site['dir_inc'],
                       a95=site['dir_alpha95'],
                       color=col)

# %% [markdown]
# Above, blue sites were included by Elston et al. (2002). The orange site is from prior literature (Collinson and Runcorn, 1960) and was excluded. The red site was excluded due to "contamination."

# %% [markdown]
# ## Recalculate pole based on site-level VGPs

# %% [markdown]
# We have recalculated the pole of Elston using individual site VGPs. We additionally have recalculated the pole for all sites and for including the interpreted "contaminated" site; we did not include the Collinson & Runcorn (1960) site.

# %%
# Elston's subset
sites_subset = sites_tilt[sites_tilt['result_quality'] == 'g']
_, pole_subset = pt.compute_mean_pole(sites_subset, unify_polarity=True, flip=True)

map_axis = ipmag.make_orthographic_map(200, 0, figsize=(5,5))

ipmag.plot_pole(map_axis, plon=pole_subset['dec'], 
                   plat=pole_subset['inc'], 
                   A95=pole_subset['alpha95'], 
                   color = 'blue', marker='s', label='Elston+ sites')

# All including Collinson and Runcorn (1960)
_, pole_all = pt.compute_mean_pole(sites_tilt, unify_polarity=True, flip=True)

ipmag.plot_pole(map_axis, plon=pole_all['dec'], 
                   plat=pole_all['inc'], 
                   A95=pole_all['alpha95'], 
                   color = 'red', marker='s', label='All sites')

# All excluding Collinson and Runcorn (1960)
sites_subset2 = sites_tilt[(sites_tilt['result_quality'] == 'g') | (sites_tilt['site'] == 'Trout Creek R')]
_, pole_subset2 = pt.compute_mean_pole(sites_subset2, unify_polarity=True, flip=True)

ipmag.plot_pole(map_axis, plon=pole_subset2['dec'], 
                   plat=pole_subset2['inc'], 
                   A95=pole_subset2['alpha95'], 
                   color = 'green', marker='s', label='Subset of sites')

plt.legend(loc='best')
plt.show()

# %%
pole_subset
# Out:
# {'dec': np.float64(210.19403698150285),
#  'inc': np.float64(-14.33102279727607),
#  'n': 10,
#  'r': np.float64(9.765708163859312),
#  'k': np.float64(38.413630403219265),
#  'alpha95': np.float64(7.893677070053882),
#  'csd': np.float64(13.068999523550437)}

# %% [markdown]
# Blue calculated pole is very close to the red one; green is an option that excludes Collinson and Runcorn (1960), but includes both data sets from Trout Creek as separate sites.  The last option includes the Trout Creek site twice and therefore weights that site proportionally more. Thus, we suggest simply using the subset chosen by Elston et al. (2002).

# %% [markdown]
# ## Site Mean Direction Calculations

# %%
dir_block, dir_mean = pt.compute_mean_direction(sites_subset, unify_polarity=True, flip=True)
ipmag.print_direction_mean(dir_mean)

ipmag.plot_net()
ipmag.plot_di(di_block=dir_block, color='blue', marker='o')
ipmag.plot_di_mean(dir_mean['dec'], dir_mean['inc'], dir_mean['alpha95'], 
                   color='red', marker='s')
ipmag.plt.title('Mean Site Directions (as measured at sites)')
ipmag.plt.show()
# Out:
# Dec: 37.2  Inc: -36.6
# Number of directions in mean (n): 10
# Angular radius of 95% confidence (a_95): 7.5
# Precision parameter (k) estimate: 42.8

# %%
centroid1 = np.mean(sites_subset['lat'], axis=0)
centroid2 = np.mean(sites_subset['lon'], axis=0)
print(f"Centroid Latitude: {centroid1:.6f}, Longitude: {centroid2:.6f}")
# Out:
# Centroid Latitude: 47.104000, Longitude: 246.344000

# %% [markdown]
# We will unite to the 47.10ºN, -113.66ºE (a rough centroid of the included sites.)

# %%
study_lat = 47.10
study_lon = -113.66

# %% [markdown]
# ## Get bedding from tilt correction to do fold test

# %% [markdown]
# Note that data from Collinson and Runcorn (1960) is not included here since no geographic coordinates or bedding orientations are provided.

# %%
# Find sites that have both geographic and tilt-corrected coordinates

sites_geolist = sites_geo.loc[
    sites_geo["site"].isin(sites_tilt["site"]),
    "site",
].tolist()

decs_fold = []
incs_fold = []
dip_dirs = []
dips = []

for site in sites_geolist:
    dec_geo = float(sites_geo.loc[sites_geo["site"] == site, "dir_dec"].iloc[0])
    inc_geo = float(sites_geo.loc[sites_geo["site"] == site, "dir_inc"].iloc[0])
    dec_tilt = float(sites_tilt.loc[sites_tilt["site"] == site, "dir_dec"].iloc[0])
    inc_tilt = float(sites_tilt.loc[sites_tilt["site"] == site, "dir_inc"].iloc[0])

    dip_dir, dip = pmag.get_tilt(dec_geo, inc_geo, dec_tilt, inc_tilt)

    decs_fold.append(dec_geo)
    incs_fold.append(inc_geo)
    dip_dirs.append(dip_dir)
    dips.append(dip)

diddd = ipmag.make_diddd_array(decs_fold, incs_fold, dip_dirs, dips)

# %%
ipmag.bootstrap_fold_test(diddd)
# Out:
# doing  1000  iterations...please be patient.....
# tightest grouping of vectors obtained at (95% confidence bounds):
# 82 - 109 percent unfolding
# range of all bootstrap samples:
# 41  -  117 percent unfolding

# %% [markdown]
# The data thus passes a fold-test.
#
# Bedding dips range from 9° to 45° and the samples are scattered across multiple separate fault panels/blocks.  Regional folding and faulting definitely occured in the Cretaceous, but it is unclear if earlier events occurred.  Many workers suggest synsedimentary normal faulting in the lower Belt Supergroup units. There is also the proposed Kootenay orogeny (1370–1300 Ma), as well as widespread metamorphism documented in the Belt Supergroup, with ages around 1100 Ma (Lonn et al. 2020).

# %% [markdown]
# ## Reversal test

# %%
decs_reversal = sites_tilt['dir_dec'].tolist()
incs_reversal = sites_tilt['dir_inc'].tolist()

ipmag.reversal_test_bootstrap(decs_reversal, incs_reversal)
# Out:
# Fail, distinct in x
# 0

# %%
ipmag.reversal_test_MM1990(decs_reversal, incs_reversal)
# Out:
# Results of Watson V test:
#
# Watson's V:           11.9
# Critical value of V:  8.0
# "Fail": Since V is greater than Vcrit, the two means can
# be distinguished at the 95% confidence level.
#
# M&M1990 classification:
#
# Angle between data set means: 16.3
# Critical angle for M&M1990:   13.4
# (0, np.float64(16.315413879779197), np.float64(13.42290576042475), '')

# %% [markdown]
# The sites fail a reversal test.

# %% [markdown]
# To probe the "contamination" of the Trout Creek site, we also wanted to perform a reversal test of sorts. Below, we have flipped the two means so that they are both "reversed," which shows that they do not share a common mean.

# %%
decs_trout = sites_tilt[sites_tilt['site'].str.contains('Trout')]['dir_dec'].tolist()
incs_trout = sites_tilt[sites_tilt['site'].str.contains('Trout')]['dir_inc'].tolist()
a95s_trout = sites_tilt[sites_tilt['site'].str.contains('Trout')]['dir_alpha95'].tolist()

plt.figure(figsize = (4,4))
ipmag.plot_net()

for i in range(len(incs_trout)):
    if incs_trout[i] > 0:
        ipmag.plot_di_mean(dec=decs_trout[i]-180, inc=-incs_trout[i], a95=a95s_trout[i])
    elif incs_trout[i] <= 0:
        ipmag.plot_di_mean(dec=decs_trout[i], inc=incs_trout[i], a95=a95s_trout[i])

# %% [markdown]
# ## Pole in the context of the Laurentia APWP

# %%
Laurentia_poles = pt.get_Laurentia_poles()
Laurentia_poles = pt.plot_apwp_context(Laurentia_poles, pole_subset['inc'], pole_subset['dec'], pole_subset['alpha95'])

# %% [markdown]
# ## R2: Deenen test

# %%
pt.Deenen_test(pole_subset['n'], pole_subset['alpha95'])
_ = pt.plot_Deenen_test(pole_subset)
# Out:
# A_95 of 7.9 passes Deenen et al. (2011) criteria of being between 4.8 and 19.2 for this number of sites

# %% [markdown]
# ## R7: Comparison with younger Laurentia poles

# %%
Laurentia_stricto_poles = pt.get_Laurentia_stricto_poles()
_ = pt.plot_pole_overlap('McNamara Formation (Elston et al. 2002)',
                     Laurentia_stricto_poles, pt.Torsvik2012_Laurentia,
                     pole_plat=pole_subset['inc'], pole_plon=pole_subset['dec'],
                     pole_A95=pole_subset['alpha95'], pole_age=1392)

# %%
dir_mean
# Out:
# {'dec': np.float64(37.236851671370836),
#  'inc': np.float64(-36.59376138711722),
#  'n': 10,
#  'r': np.float64(9.789615568745495),
#  'k': np.float64(42.77883085898385),
#  'alpha95': np.float64(7.470346838554319),
#  'csd': np.float64(12.384274318042797)}

# %%
pole_subset
# Out:
# {'dec': np.float64(210.19403698150285),
#  'inc': np.float64(-14.33102279727607),
#  'n': 10,
#  'r': np.float64(9.765708163859312),
#  'k': np.float64(38.413630403219265),
#  'alpha95': np.float64(7.893677070053882),
#  'csd': np.float64(13.068999523550437)}

# %% [markdown]
# ## R-score summary (Meert et al., 2020)
#
# | R | Criterion | Score | Justification |
# |---|---|---|---|
# | 1 | Age within ± 15 Ma | **1** | One SHRIMP U-Pb zircon age of 1401 ± 6 Ma in tuff at base of unit and one TIMS U-Pb zircon age of 1379 ± 1 Ma in intrusive from lower in the section; from Evans et al. (2000) and Doughty and Chamberlain (1996). |
# | 2 | Techniques and statistical analysis | **0** | (a) Only thermal demagnetization was used; however, these are red-beds (b) Blanket demagnetization was used with majority of sites at <600°C so fits have both pigmentary and detrital hematite. (c) N = 195 samples in 10 sites, k = 38.4, A95 = 7.9° passes Deenen et al. (2011) envelope (4.8°-19.2°). B = 10 sites ≥ 8 sites. |
# | 3 | Magnetic mineralogy characterized | **0** | Only thermal stepwise demagnetization used. |
# | 4 | Field tests constrain age of magnetization | **1** | Positive regional fold test, timing of folding unclear -- Cretaceous at latest |
# | 5 | Structural control / tectonic coherence | **0** | Within formation, there is 50 degree declination difference interpreted by Elston as recording vertical axis rotation. No inclination shallowing correction applied.|
# | 6 | Presence of reversals | **0** | Contains reversals but failed the reversal test|
# | 7 | No resemblance to younger poles | **1** | No overlap with younger poles |
# | | **Total R-score** | **3/7** | |

# %% [markdown]
# ### McNamara primary remanence pole
#
# |  | This study (site VGPs) | Elston et al. (2002) | Previous Nordic compilation |
# | --- | --- | --- | --- |
# | Component | McNamara primary | McNamara primary | McNamara primary |
# | N (sites) | 10 | 10 | 10 |
# | N (specimens) | 195 | — | 195 |
# | Dec (°) | 37.2 | 37.2 | 37.2 |
# | Inc (°) | -36.6 | -36.6 | -36.6 |
# | k (direction) | 42.8 | 42.8 | 42.8 |
# | α95 (direction, °) | 7.5 | 7.5 | 7.5 |
# | Pole lat (°N) | -14.3 | -13.5 | -13.5 |
# | Pole lon (°E) | 210.2 | 208.3 | 208.3 |
# | A95 | 7.9 | 6.7 | 6.7 |
# | pole (°) | — | — | — |
# | dp / dm (°) | — | — | 6.7 / 6.7 |

# %% [markdown]
# ## Nordic workshop ranking
#
# Prior Nordic Workshop compilations of paleomagnetic poles with expert-assigned rankings (Evans et al., 2021) have given the pole from the McNamara Formation an 'A' ranking.
#
# Our assessment is that careful evaluation of the pole suggests it should be assigned a 'B' ranking, parimarily due to the statistical/laboratory methodology used which make R2, R5, R6 scores of 0.

# %%
McNamara_summary = pt.make_nordic_summary(terrane='Laurentia', 
                                        rockname='McNamara', 
                                        sites=sites_subset,
                                        dir_mean=dir_mean,
                                        pole_mean=pole_subset,
                                        study_lon=study_lon,
                                        study_lat=study_lat,
                                        component_comment='',
                                        tests='f',
                                        R1=1,
                                        R2=0,
                                        R3=0,
                                        R4='f',
                                        R5=0,
                                        R6=0,
                                        R7=1,
                                        Grade='B', Grade_E21='A',
                                        nominal_age=1392,
                                        lomagage=1378,
                                        himagage=1407,
                                        REF_method='One SHRIMP U-Pb zircon age of 1401 ± 6 Ma in tuff at base of unit and one TIMS U-Pb zircon age of 1379 ± 1 Ma in intrusive from lower in the section; from Evans et al. (2000) and Doughty and Chamberlain (1996).',
                                        POLE_AUTHORS='Elston, D. P., Enkin, R. J., Baker, J., and Kisilevsky, D. K. ',
                                        YEAR=2002,
                                        JOURNAL='Geological Society of America Bulletin',
                                        VOLUME=114,
                                        VPAGES='619-638',
                                        TITLE='Tightening the Belt: Paleomagnetic-stratigraphic constraints on deposition, correlation, and deformation of the Middle Proterozoic (ca. 1.4 Ga) Belt-Purcell Supergroup, United States and Canada',
                                        COMMENT='Recalculated pole from Elston et al. (2002) individual site VGPs including a site he had excluded seemingly arbitarily as documented in Swanson-Hysell et al. 2026.'
                                        )
McNamara_summary
# Out:
#      Terrane  ROCKNAME GPMDB RESULT# MAGIC # COMPONENT TESTS  TILT  SLAT  \
# 0  Laurentia  McNamara                                     f   100  47.1
#
#     SLONG   B  ...                                         REF/method  \
# 0 -113.66  10  ...  One SHRIMP U-Pb zircon age of 1401 ± 6 Ma in t...
#
#    ROCKNAME                                       POLE AUTHORS  YEAR  \
# 0  McNamara  Elston, D. P., Enkin, R. J., Baker, J., and Ki...  2002
#
#                                   JOURNAL  VOLUME   VPAGES  \
# 0  Geological Society of America Bulletin     114  619-638
#
#                                                TITLE  \
# 0  Tightening the Belt: Paleomagnetic-stratigraph...
#
#                                              Comment                Lithology
# 0  Recalculated pole from Elston et al. (2002) in...  Muddy Sandstone; Redbed
#
# [1 rows x 71 columns]

# %%
# save the summary dictionary as a single-row CSV in data/nordic_summaries
pt.save_nordic_summary(McNamara_summary, '1392_McNamara')
# Out:
# '../data/nordic_summaries/1392_McNamara.csv'

# %% [markdown]
# ## Inclination-shallowing-corrected pole
#
# The pole above is reported as measured. Detrital remanence in sedimentary rocks
# is shallowed during compaction, so its inclination — and the paleolatitude that
# inclination implies — is a minimum. Only site-level mean directions are available for this unit (10 sites), far too few for an elongation/inclination (E/I) or SVEI determination of the flattening factor.
#
# Following Pierce et al. (2022), the flattening factor is instead resampled from
# their compilation of measured *f* values (`ipmag.find_compilation_kent`). Each
# resample unsquishes the mean direction implied by the pole at the sampling
# locality, and the resulting distribution of mean poles is summarized as a Kent
# (1982) distribution whose 95% confidence ellipse carries the flattening
# uncertainty along with the uncertainty in the pole itself. This corrected pole
# is exported to `data/nordic_summaries/kent/` and is the position plotted for
# this unit in the compilation figures; the main compilation table keeps the
# uncorrected pole.

# %%
# Inclination-shallowing-corrected Kent mean pole (Pierce et al., 2022). The
# random seed is fixed so the exported summary is reproducible.
kent = pt.compilation_kent_pole(pole_subset, study_lon, study_lat, random_seed=1)
plt.show()

McNamara_kent_summary = pt.make_kent_summary(
    McNamara_summary, kent, 'compilation', 'this study',
    comment='10 site-level mean directions: too few for an E/I or SVEI determination of f')
pt.save_kent_summary(McNamara_kent_summary, '1392_McNamara')
McNamara_kent_summary
# Out:
# Plon: 215.0  Plat: -4.2
# Major axis lon: 295.8  Major axis lat: 65.0
# Minor axis lon: 126.9  Minor axis lat: 24.5
# Major axis angle of 95% ellipse (Zeta): 15.3
# Minor axis angle of 95% ellipse (Eta): 8.0
# Number of directions in mean (n): 1000000
#      Terrane  ROCKNAME                Lithology  SLAT   SLONG  nominal age  \
# 0  Laurentia  McNamara  Muddy Sandstone; Redbed  47.1 -113.66         1392
#
#    lomagage  himagage Grade                             f method  ...  PLONG  \
# 0      1378      1407     B  compilation f (Pierce et al., 2022)  ...  215.0
#
#     Zdec  Zinc  Zeta   Edec  Einc  Eta   A95  n resampled  \
# 0  295.8  65.0  15.3  126.9  24.5  8.0  11.0      1000000
#
#                                              Comment
# 0  10 site-level mean directions: too few for an ...
#
# [1 rows x 28 columns]
