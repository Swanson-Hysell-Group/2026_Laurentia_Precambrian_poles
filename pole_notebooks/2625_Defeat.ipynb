# %% [markdown]
# # Defeat ca. 2625 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Slave.
# - Compiled unit/pole label: Defeat Suite.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 5 sites, N = 58 samples; mean direction DEC/INC = 2.0°/-47.0°; K = 30.0.
# - Field/statistical tests noted in compilation: C*+.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: lomagage 2620.0 Ma, himagage 2630.0 Ma.
# - Compilation method note: 2625, U-Pb: 2628 pm 3, 2624 pm4
#
# ## References
#
# - Paleomagnetic source: Mitchell, R.N., Bleeker, W., Van Breemen, O., LeCheminant, A.N., Peng, P., Nilsson, M.K.M., Evans, D.A.D. (2014). Plate tectonics before 2.0 Ga: Evidence from paleomagnetism of cratons within supercontinent Nuna. Am. J. Sci., 314, 878-894.
# - Geochronology / age-constraint note (compilation): 2625, U-Pb: 2628 pm 3, 2624 pm4

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
Mitchell2014_sites_geo, Mitchell2014_sites_tc = load_magic_sites('../data/2625_Defeat/sites.txt')
Mitchell2014_data = Mitchell2014_sites_tc if not Mitchell2014_sites_tc.empty else Mitchell2014_sites_geo
Mitchell2014_data = Mitchell2014_data.rename(columns={'dir_dec': 'dec', 'dir_inc': 'inc'}).reset_index(drop=True)
Mitchell2014_dir_n, Mitchell2014_dir_r = pmag.flip(ipmag.make_di_block(Mitchell2014_data['dec'].tolist(), Mitchell2014_data['inc'].tolist()))

Mitchell2014_dir = Mitchell2014_dir_n+Mitchell2014_dir_r
ipmag.fisher_mean(di_block=Mitchell2014_dir)
# Out:
# {'dec': 182.18862570160275,
#  'inc': 47.24337490556202,
#  'n': 5,
#  'r': 4.867056828855231,
#  'k': 30.088044128601354,
#  'alpha95': 14.175321454603957,
#  'csd': 14.766856011697504}

# %%
R2_test('Defeat Suite',Laurentia_poles)
# Out:
# N = 58 (N ≥ 25; sufficient sample number);
# B = 5 (B < 8; insufficient site number);
# K = 30 (70 ≥ K ≥ 10; meets PSV criteria);
# A_95 of 15.0 passes Deenen et al. (2011) criteria of being between 6.3 and 29.7 for this number of sites

# %%
plot_pole_overlap('Defeat Suite',Laurentia_poles,Torsvik2012_Laurentia)
