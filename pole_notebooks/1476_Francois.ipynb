# %% [markdown]
# # Francois ca. 1476 Ma paleomagnetic pole## Geologic Context- Terrane: Laurentia.- Compiled unit/pole label: St.Francois Mountains Acidic Rocks.## Paleomagnetic And Rock Magnetic Data- B = 18 sites, N = 103 samples; mean direction DEC/INC = 233.4°/36.9°; K = 27.0.- Field/statistical tests noted in compilation: C*+,F+,G+.- Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.## Age Constraints- Current bracket: lomagage 1460.0 Ma, himagage 1492.0 Ma.- Compilation method note: ok, GPMDB4.6## References- Paleomagnetic source: Meert, J.G., Stuckey, W. (2002). Revisiting the paleomagnetism of the 1.476 Ga St.Francois Mountains igneous province, Missouri.. Tectonics, 21(2), 1007, doi:10.1029/2000TC001265.- Geochronology / age-constraint note (compilation): ok, GPMDB4.6

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('St.Francois Mountains Acidic Rocks',Laurentia_poles)
# Out:
# N = 103 (N ≥ 25; sufficient sample number);
# B = 18 (B ≥ 8; sufficient site number);
# K = 27 (70 ≥ K ≥ 10; meets PSV criteria);
# A_95 of 6.1 passes Deenen et al. (2011) criteria of being between 3.8 and 13.3 for this number of sites

# %%
plot_pole_overlap('St.Francois Mountains Acidic Rocks',Laurentia_stricto_poles,Torsvik2012_Laurentia)
