# %% [markdown]
# # Malley ca. 2231 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Slave.
# - Compiled unit/pole label: Malley dykes.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 9 sites, N = 45 samples; mean direction DEC/INC = 138.3°/-53.8°; K = 81.0.
# - Field/statistical tests noted in compilation: C*+.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - **Current bracket: nominal age 2231 Ma, lomagage 2229.0 Ma, himagage 2233.0 Ma.**
# - Compilation method note: U–Pb baddeleyite age from Buchan et al., 2012.
#
# ## References
#
# - Paleomagnetic source: Buchan, K., LeCheminant, A.N., van Breemen, O. (2012). Malley diabase dykes of the Slave craton, Canadian Shield: U-Pb age, paleomagnetism, and implications for continental reconstructions in the early Paleoproterozoic. Can. J. Earth Sci., 49, 435-454.
# - Geochronology / age-constraint note (compilation): Buchan, K. L., LeCheminant, A. N., & van Breemen, O. (2012). Malley diabase dykes of the Slave craton, Canadian Shield: U–Pb age, paleomagnetism, and implications for continental reconstructions in the early Paleoproterozoic1Geological Survey of Canada Contribution 20110114. Canadian Journal of Earth Sciences, 49(2), 435–454. https://doi.org/10.1139/e11-061

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Malley dykes',Laurentia_poles)
# Out:
# N = 45 (N ≥ 25; sufficient sample number);
# B = 9 (B ≥ 8; sufficient site number);
# K = 81 (K ≥ 70; concern about underrepresenting PSV);
# A_95 of 6.7 passes Deenen et al. (2011) criteria of being between 5.0 and 20.5 for this number of sites

# %%
plot_pole_overlap('Malley dykes',Laurentia_poles,Torsvik2012_Laurentia)
