# %% [markdown]
# # Sourdough ca. 1899 Ma paleomagnetic pole## Geologic Context- Terrane: Laurentia-Wyoming.- Compiled unit/pole label: Sourdough mafic dike swarm.## Paleomagnetic And Rock Magnetic Data- B = 16 sites, N = 109 samples; mean direction DEC/INC = 65.1°/75.2°; K = 21.8; A95 = 8.1°.- Field/statistical tests noted in compilation: C+,Ro.- Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.## Age Constraints- Current compiled age: nominal age 1899.0 Ma.- Compilation method note: U-Pb baddeleyite: 1899+/-5 Ma## References- Paleomagnetic source: Kilian, T.M., Chamberlain, K.R., Evans, D.A.D., Bleeker, W., Cousens, B.L. (2016). Wyoming on the run—Toward  nal Paleoproterozoic assembly of Laurentia. Geology, 44, 863–866.- Geochronology / age-constraint note (compilation): U-Pb baddeleyite: 1899+/-5 Ma

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Sourdough mafic dike swarm',Laurentia_poles)
# Out:
# N = 109 (N ≥ 25; sufficient sample number);
# B = 16 (B ≥ 8; sufficient site number);
# K = 22 (70 ≥ K ≥ 10; meets PSV criteria);
# A_95 of 8.1 passes Deenen et al. (2011) criteria of being between 4.0 and 14.3 for this number of sites

# %%
plot_pole_overlap('Sourdough mafic dike swarm',Laurentia_poles,Torsvik2012_Laurentia)
