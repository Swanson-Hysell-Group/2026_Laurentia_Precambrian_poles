# %% [markdown]
# # Nipissing N1 ca. 2217 Ma paleomagnetic pole## Geologic Context- Terrane: Laurentia-Superior(East).- Compiled unit/pole label: NIPISSING N1.## Paleomagnetic And Rock Magnetic Data- mean direction DEC/INC = 7.4°/-43.9°; K = 1000.0.- Field/statistical tests noted in compilation: C+.- Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.## Age Constraints- Current bracket: lomagage 2213.0 Ma, himagage 2221.0 Ma.- Compilation method note: 2217±4, ## References- Paleomagnetic source: Buchan et al. (2000). Comparing the drift of Laurentia and Baltica in the Proterozoic: the importance of key palaeomagnetic poles. Tectonophysics, 319, 167-198.- Geochronology / age-constraint note (compilation): 2217±4,

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
# R2_test('NIPISSING N1',Laurentia_poles)

# %%
plot_pole_overlap('NIPISSING N1',Laurentia_poles,Torsvik2012_Laurentia)
