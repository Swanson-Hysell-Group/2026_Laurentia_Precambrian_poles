# %% [markdown]
# # Fort Frances ca. 2076 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Superior(West).
# - Compiled unit/pole label: FORT FRANCES.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - mean direction DEC/INC = 117.2°/-54.8°; K = 1000.0.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: nominal age 2076 Ma, lomagage 2072.0 Ma, himagage 2081.0 Ma.
# - Compilation method note: 2076+5/-4, two fractions of baddeleyite and four fractions of zircon were analysed from the Fort Francis dyke by Buchan et al., 1996. The age of concordia upper intercept age.
#
# ## References
#
# - Paleomagnetic source: Evans,D.A.D., Halls,H.C. (2010). Restoring Proterozoic deformation within the Superior craton. Precambrian Res., 183, 474-489.
# - Geochronology / age-constraint note (compilation): 2076+5/-4, Buchan, K. L., Halls, H. C., & Mortensen, J. K. (1996). Paleomagnetism, U–Pb geochronology, and geochemistry of Marathon dykes, Superior Province, and comparison with the Fort Frances swarm. Canadian Journal of Earth Sciences, 33(12), 1583–1595. https://doi.org/10.1139/e96-120

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
plot_pole_overlap('FORT FRANCES',Laurentia_poles,Torsvik2012_Laurentia)
