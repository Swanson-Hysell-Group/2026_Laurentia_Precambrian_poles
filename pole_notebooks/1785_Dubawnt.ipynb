# %% [markdown]
# # Dubawnt ca. 1785 Ma paleomagnetic pole## Geologic Context- Terrane: Laurentia.- Compiled unit/pole label: Dubawnt Group.## Paleomagnetic And Rock Magnetic Data- B = 30 sites, N = 130 samples; mean direction DEC/INC = 347.0°/-50.0°; K = 17.0.- Field/statistical tests noted in compilation: C+,Rc.- Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.## Age Constraints- Current bracket: lomagage 1750.0 Ma, himagage 1820.0 Ma.- Compilation method note: possibly ca.1750 ovp (Th.Raub 08 PhD thesis); ages from eastern Baker Lake ca.1810 Ma, Rainbird ages, Th.Raub thesis## References- Paleomagnetic source: Park,J.K., Irving,E., Donaldson,J.A. (1973). Paleomagnetism of the Dubawnt Group. Geol.Soc.Amer.Bull., 84, 859-870.- Geochronology / age-constraint note (compilation): possibly ca.1750 ovp (Th.Raub 08 PhD thesis); ages from eastern Baker Lake ca.1810 Ma, Rainbird ages, Th.Raub thesis

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Dubawnt Group',Laurentia_poles)
# Out:
# N = 130 (N ≥ 25; sufficient sample number);
# B = 30 (B ≥ 8; sufficient site number);
# K = 17 (70 ≥ K ≥ 10; meets PSV criteria);
# A_95 of 8.0 passes Deenen et al. (2011) criteria of being between 3.1 and 9.6 for this number of sites

# %%
plot_pole_overlap('Dubawnt Group',Laurentia_stricto_poles,Torsvik2012_Laurentia)
