# %% [markdown]
# # Clearwater ca. 1917 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Rae.
# - Compiled unit/pole label: Clearwater Anorthosite.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 8 sites, N = 115 samples; mean direction DEC/INC = 112.3°/38.0°; K = 315.8.
# - Component note: A Magnetization.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: nominal age 1917 Ma, lomagage 1910.0 Ma, himagage 1924.0 Ma.
# - Compilation method note: Halls and Hanes, 1999 developed two Ar isotope geochronology ages from the Clearwater anorthosite and obtained a 1917±7 Ma from hornblende and a 1839±5 Ma from biotite. The data hints a cooling age for the remanence and the 1917 Ma age is preferred given that the hornblende closure temperature (if it is a real cooling age) is closer to the remanence unblocking temperature.
#
# ## References
#
# - Paleomagnetic source: Halls,H.C., Hanes,J.A. (1999). Paleomagnetism, anisotropy of magnetic susceptibility and argon-argon geochronology of the Clearwater anorthosite, Saskatchewan, Canada. Tectonophysics, 312, 235-248.
# - Geochronology / age-constraint note (compilation): Halls, H. C., & Hanes, J. A. (1999). Paleomagnetism, anisotropy of magnetic susceptibility, and argon–argon geochronology of the Clearwater anorthosite, Saskatchewan, Canada. Tectonophysics, 312(2–4), 235–248. https://doi.org/10.1016/s0040-1951(99)00166-3

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Clearwater Anorthosite',Laurentia_poles)
# Out:
# N = 115 (N ≥ 25; sufficient sample number);
# B = 8 (B ≥ 8; sufficient site number);
# K = 316 (K ≥ 70; concern about underrepresenting PSV);
# A_95 of 2.9 is too small for Deenen criteria of 5.2 for this number of sites

# %%
plot_pole_overlap('Clearwater Anorthosite',Laurentia_poles,Torsvik2012_Laurentia)
