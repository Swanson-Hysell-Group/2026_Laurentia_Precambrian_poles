# %% [markdown]
# # Snowslip pole ~1449 Ma Elston et al. (2002)

# %% [markdown]
# ## Geologic Context
#
# The Mesoproterozoic Belt Supergroup, located in Montana and Idaho, USA, and Alberta and British Columbia, Canada, spans an enormous extent covering > 200,000 km<sup>2</sup> (Lonn et al. 2020).  It is a predominantly sedimentary succession over 15 km thick in places, which has been subdivided into four groups. The Snowslip Formation is in the Missoula Group, which is the uppermost group (Lonn et al. 2020).  The Belt Supergroup was an early place of paleomagnetic analyses in the 1950s and 1960s, but the majority of subsequent paleomagnetic analyses were the product of years of work by Don Elston of the United States Geologic Survey and colleagues, which were published in Elston et al. (2002).  While Elston et al. (2002) note that carbonates and green-grey-black siliclastics were analyzed, the "weak and incoherent magnetizations" led the study to focus on red beds spanning the entirety of the stratigraphic succession.
#
# The Snowslip Formation was defined in Glacier National Park, Montana, and contains three red mudcracked mudstone and quartz-rich sandstone units, separated by two green units of interbedded siltstone and mudstone with fewer mudcracks (Winston and Link 1993).  It has been interpreted as intertidal to peritidal, with episodes of sheetflood deposits (Winston and Link 1993).  The Snowslip Formation is interpreted to extend across western Montana to Clark Fork and Bonner's Ferry, Idaho, through correlation with the lower portion of the Upper Wallace Formation, which is less mudcracked and sandstone-rich (Lonn et al. 2020).  The Upper Wallace and Snowslip Formation are correlated with the Van Creek Formation in Canada (Lonn et al. 2020), although all of Elston et al. (2002)'s samples are from the United States and were noted to be from the base of the Snowslip Formation.

# %% [markdown]
# ## Paleomagnetic and rock magnetic data
#
# Elston et al. (2002) report 13 sites from the Snowslip Formation, which includes two sites from the literature.  Collinson and Runcorn (1960) measured an NRM, while Black (1963) used blanket demagnetization to 16 mT respectively. While Table 1 does not note that they were excluded from the formation mean, the caption notes that all 1960s studies were excluded.  Additionally, in Table 3, the included number of sites used in the mean is 2 less than listed in Table 1 (and mean pole calculations suggest that excluding the 1960s sites is closest to the reported mean). A formation mean of 9 sites is reported and calculated using Fisher statistics.
#
# The USGS subjected pilot samples to stepwise demagnetization in 8 steps, but then demagnetized the remaining samples in blanket steps -- in this case a 550 ºC step was used (which would include magnetite and all forms of hematite).  The single stepwise thermal demagnetization Zidjerveld shown highlighted that the vast majority of remanence is held at > 650 ºC, suggesting the presence of detrital hematite. No additional rock magnetic analyses were performed.
#
# The majority of sites carried a reversed direction (following the polarity convention of Elston et al. 2022). Normal directions were found at the base of the formation at Poorman Creek, as well as in Flint Creek (lower) and Trail Gulch.  However, the rare "purple" beds exposed at Flint Creek (lower) and Trail Gulch were discarded due to concerns about rotation and/or post-depositional overprinting.  These remanences had relatively steep inclinations and appeared to be CW-rotated based on the paleomagnetic declinations.  No reversal test was reported from the remaining normal polarity site (see below).
#
# Sites pass a fold test with 100 $\pm$ 6% untilting as the optimum, using Watson and Enkin, 1993.

# %% [markdown]
# ## Geochronology Constraints
#
# Constenius et al. (accepted) did ID-TIMS U-Pb dating on baddeleyite from the lower Purcell Lava and report an age of 1438.9 ± 3.2 Ma.  Dating of instrusive sills using LA-ICP-MS corroborate magmatism at this age in the Belt Supergroup. The Purcell Lava intrudes at the contact of the Snowslip and the overlying Shepard Formation.
#
# A minimum age constraint of 1454 ± 9 Ma from SHRIMP U-Pb zircon dating is given by the overlying metabentonite from the upper Helena Formation (Evans et al., 2000). A recent LA-ICP-MS U-Pb zircon date provides a quite similar age of 1450.4 ± 7.8 Ma (Constenius et al. accepted; this is a revision of a prior age published in Hirtz et al. 2024); these overlap substantially, and we use the Evans et al. (2000) date.  The Snowslip Formation directly overlies the Helena Formation in Glacier National Park, where this sample was collected.
#
# Because of this tight age-bracketing of the Snowslip Formation, we choose to pick the midpoint between the two age constraints (1458 and 1435.7 Ma) to arrive at 1449 Ma.

# %% [markdown]
# ## References
#
# Black, R.F., 1963, Palaeomagnetism of part of the Purcell System in southwestern Alberta and southeastern British Columbia: Geological Survey of Canada Bulletin 83, p. 1–31.
#
# Collinson, D.W., and Runcorn, S.K., 1960, Polar wandering and continental drift: Evidence of paleomagnetic observations in the United States: Geological Society of America Bulletin, v. 71, p. 915–958.
#
# Constenius, K.N., McGimsey, R.G., Valencia, V.A., Domanik, K.J., Chamberlain, K.R., Crowley, J., Hirtz, J.A.M., and Horton, B.K. (accepted). Stratigraphy of the Purcell Lava and revised geochronology of the Missoula Group: Implications for unconformities and magmatic episodes in the Mesoproterozoic Belt Basin. Geological Society of America Special Volume.
#
# Evans, K.V., Aleinikoff , J.N., Obradovich, J.D., and Fanning, C.M., 2000, SHRIMP U-Pb geochronology
# of volcanic rocks, Belt Supergroup, western Montana: Evidence for rapid deposition of sedimentary strata: Canadian Journal of Earth Sciences, v. 37, p. 1287–1300, DOI: 10.1139/cjes-37-9-1287
#
# Hirtz, J.A.M., Constenius, K.N., Horton, B.K., Valencia, V.A., and Pratt, B.R., 2024, Continental-scale drainage reorganization during Mesoproterozoic orogenesis: Evidence from the Belt Basin of western North America: Geosphere, v. 20, no. 4, p. 1133– 1161, https://doi.org/10.1130/GES02732.1
#
# Lonn, J. D., Burmester, R. F., Lewis, R. S., McFaddan, M. D., Metesh, J. J., & Vuke, S. M. (2020). The Mesoproterozoic Belt Supergroup. in Barth, S., ed., Geology of Montana: Montana Bureau of Mines and Geology Special Publication 122, 1, 1-38.
#
# Winston, D., and Link, P.K., 1993, Middle Proterozoic rocks of Montana, Idaho and eastern Washington: The Belt Supergroup, in Reed, J.C., Jr., Bickford, M.E., Houston, R.S., Link, P.K., Rankin, D.W.,
# Sims, P.K., and Van Schmus, W.R., eds., Precambrian: Conterminous U.S.: Geological Society of
# America, Decade of North American Geology, v. C-2, p. 487–517.

# %% [markdown]
# # Calculations

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import pmagpy.pmag as pmag
import pmagpy.ipmag as ipmag
import matplotlib.pyplot as plt
import pole_tools as pt

# %matplotlib inline
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %% [markdown]
# ## Read in sites

# %%
sites_df = pd.read_csv('../data/1449_Snowslip/sites.txt', sep='\t',header=1)

# %%
sites_df.head()
# Out:
#     age  age_high  age_low  age_sigma age_unit  \
# 0  1449    1435.7     1463        NaN       Ma
# 1  1449    1435.7     1463        NaN       Ma
# 2  1449    1435.7     1463        NaN       Ma
# 3  1449    1435.7     1463        NaN       Ma
# 4  1449    1435.7     1463        NaN       Ma
#
#                                          citations  \
# 0  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 1  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 2  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 3  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 4  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
#
#                                          description  dir_alpha95  dir_dec  \
# 0  Age constraints provided by a tuff in the unde...          4.4     32.7
# 1  Age constraints provided by a tuff in the unde...          4.4     31.1
# 2  Age constraints provided by a tuff in the unde...          6.8     31.1
# ...

# %% [markdown]
# ## Site location map

# %%
pt.plot_site_map(sites_df, zoom_start=8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ## Add site VGPs

# %%
sites_df['vgp_lon'], sites_df['vgp_lat'], sites_df['vgp_dp'], sites_df['vgp_dm'] = pmag.dia_vgp(sites_df['dir_dec'], sites_df['dir_inc'], sites_df['dir_alpha95'], sites_df['lat'], sites_df['lon'])

# %%
sites_df.head()
# Out:
#     age  age_high  age_low  age_sigma age_unit  \
# 0  1449    1435.7     1463        NaN       Ma
# 1  1449    1435.7     1463        NaN       Ma
# 2  1449    1435.7     1463        NaN       Ma
# 3  1449    1435.7     1463        NaN       Ma
# 4  1449    1435.7     1463        NaN       Ma
#
#                                          citations  \
# 0  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 1  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 2  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 3  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 4  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
#
#                                          description  dir_alpha95  dir_dec  \
# 0  Age constraints provided by a tuff in the unde...          4.4     32.7
# 1  Age constraints provided by a tuff in the unde...          4.4     31.1
# 2  Age constraints provided by a tuff in the unde...          6.8     31.1
# ...

# %%
# pmag.magic_write('../data/1449_Snowslip/sites.txt', sites_df, 'sites', dataframe=True)

# %% [markdown]
# ## Plot site means

# %%
#Elston selections following exclusions of rotation in Table 1 and exclusion of the 1960s as per Table 3 
sites_geo = sites_df[sites_df['dir_tilt_correction'] == 0]
sites_tilt = sites_df[sites_df['dir_tilt_correction'] == 100]

plt.figure(figsize = (4,4))
ipmag.plot_net()

for row, site in sites_tilt.iterrows():
    if site['site'] == 'Donovan Creek':
        col = 'orange'
    elif site['site'] == 'Pincher Ridge':
        col = 'orange'
    elif site['result_quality'] == 'b':
        col = 'r'
    elif site['result_quality'] == 'g':
        col = 'b'
    ipmag.plot_di_mean(dec=site['dir_dec'],
                       inc=site['dir_inc'],
                       a95=site['dir_alpha95'],
                       color=col)

# %% [markdown]
# Above, blue sites were included by Elston et al. (2002). Red sites were excluded due to rotation. Orange sites are from prior literature (Collinson and Runcorn 1960; Black 1963), which were included as per Table 1 and excluded as per Table 3.

# %% [markdown]
# ## Recalculate pole from site VGPs

# %%
# Elston's subset as per Table 1
sites_subset1 = sites_tilt[(sites_tilt['result_quality'] == 'g') | 
                           (sites_tilt['site'] == 'Donovan Creek') | (sites_tilt['site'] == 'Pincher Ridge')]

_, pole_subset1 = pt.compute_mean_pole(sites_subset1, unify_polarity=True, flip=True)

map_axis = ipmag.make_orthographic_map(200, 0, figsize=(5,5))

ipmag.plot_pole(map_axis, plon=pole_subset1['dec'], 
                   plat=pole_subset1['inc'], 
                   A95=pole_subset1['alpha95'], 
                   color = 'red', marker='s', label='Subset of sites (Table 1)')

# Elston's subset excluding the 1960s as per Table 3
sites_subset = sites_tilt[sites_tilt['result_quality'] == 'g']

_, pole_subset = pt.compute_mean_pole(sites_subset, unify_polarity=True, flip=True)

ipmag.plot_pole(map_axis, plon=pole_subset['dec'], 
                   plat=pole_subset['inc'], 
                   A95=pole_subset['alpha95'], 
                   color = 'blue', marker='s', label='Subset of sites (Table 3)')

# All
_, pole_all = pt.compute_mean_pole(sites_tilt, unify_polarity=True, flip=True)

ipmag.plot_pole(map_axis, plon=pole_all['dec'], 
                   plat=pole_all['inc'], 
                   A95=pole_all['alpha95'], 
                   color = 'green', marker='s', label='All sites')

_ = plt.legend(loc='best')

# %%
print ('Elston+ Table 1 subset Snowslip poles D = %2.1f I = %2.1f A95 = %2.1f'%(pole_subset1['dec'],pole_subset1['inc'], pole_subset1['alpha95']))
print ('Elston+ Table 3 subset Snowslip poles D = %2.1f I = %2.1f A95 = %2.1f'%(pole_subset['dec'],pole_subset['inc'], pole_subset['alpha95']))
print ('All Snowslip poles D = %2.1f I = %2.1f A95 = %2.1f'%(pole_all['dec'],pole_all['inc'], pole_all['alpha95']))
# Out:
# Elston+ Table 1 subset Snowslip poles D = 209.0 I = -23.2 A95 = 5.2
# Elston+ Table 3 subset Snowslip poles D = 212.1 I = -25.2 A95 = 3.3
# All Snowslip poles D = 204.5 I = -18.9 A95 = 9.1

# %% [markdown]
# ## Site Mean Direction Calculations

# %%
dir_block, dir_mean = pt.compute_mean_direction(sites_subset, unify_polarity=True, flip=True)
ipmag.print_direction_mean(dir_mean)

ipmag.plot_net()
ipmag.plot_di(di_block=dir_block, color='blue', marker='o')
ipmag.plot_di_mean(dir_mean['dec'], dir_mean['inc'], dir_mean['alpha95'], 
                   color='red', marker='s')
ipmag.plt.title('Mean Site Directions (as measured at sites)')
ipmag.plt.show()
# Out:
# Dec: 30.9  Inc: -20.6
# Number of directions in mean (n): 9
# Angular radius of 95% confidence (a_95): 4.6
# Precision parameter (k) estimate: 128.8

# %%
centroid1 = np.mean(sites_subset['lat'], axis=0)
centroid2 = np.mean(sites_subset['lon'], axis=0)
print(f"Centroid Latitude: {centroid1:.6f}, Longitude: {centroid2:.6f}")
# Out:
# Centroid Latitude: 47.912222, Longitude: 245.915556

# %% [markdown]
# We will unite to the 47.9ºN, -114.1ºE (a rough centroid of the sites.)

# %%
study_lat = 47.9
study_lon = -114.1

# %% [markdown]
# ## Get bedding from tilt correction to do fold test

# %%
# Find sites that have both geographic and tilt-corrected coordinates

sites_geolist = []
for site in sites_geo["site"]:
    if sites_tilt["site"].str.contains(site, regex=False).any():
        sites_geolist.append(site)

decs_fold = []
incs_fold = []
dip_dirs = []
dips = []

for site in sites_geolist:
    dec_geo = float(sites_geo.loc[sites_geo["site"] == site, "dir_dec"].iloc[0])
    inc_geo = float(sites_geo.loc[sites_geo["site"] == site, "dir_inc"].iloc[0])
    dec_tilt = float(sites_tilt.loc[sites_tilt["site"] == site, "dir_dec"].iloc[0])
    inc_tilt = float(sites_tilt.loc[sites_tilt["site"] == site, "dir_inc"].iloc[0])

    dip_dir, dip = pmag.get_tilt(dec_geo, inc_geo, dec_tilt, inc_tilt)

    decs_fold.append(dec_geo)
    incs_fold.append(inc_geo)
    dip_dirs.append(dip_dir)
    dips.append(dip)

diddd = ipmag.make_diddd_array(decs_fold, incs_fold, dip_dirs, dips)

# %%
ipmag.bootstrap_fold_test(diddd)
# Out:
# doing  1000  iterations...please be patient.....
# tightest grouping of vectors obtained at (95% confidence bounds):
# 74 - 111 percent unfolding
# range of all bootstrap samples:
# 48  -  119 percent unfolding

# %% [markdown]
# All sites measured by Elston et al. (2002) pass a fold test.
#
# We also performed a fold test on the subset included in the mean pole, reported in Elston et al. (2002) Table 3.

# %%
sites_subset_geo = sites_geo[sites_geo["result_quality"] == "g"]

sites_subset_geolist = []

for site in sites_subset_geo["site"]:
    if sites_tilt["site"].str.contains(site, regex=False).any():
        sites_subset_geolist.append(site)

decs_fold = []
incs_fold = []
dip_dirs = []
dips = []

for site in sites_subset_geolist:
    dec_geo = float(sites_geo.loc[sites_geo["site"] == site, "dir_dec"].iloc[0])
    inc_geo = float(sites_geo.loc[sites_geo["site"] == site, "dir_inc"].iloc[0])
    dec_tilt = float(sites_tilt.loc[sites_tilt["site"] == site, "dir_dec"].iloc[0])
    inc_tilt = float(sites_tilt.loc[sites_tilt["site"] == site, "dir_inc"].iloc[0])

    dip_dir, dip = pmag.get_tilt(dec_geo, inc_geo, dec_tilt, inc_tilt)

    decs_fold.append(dec_geo)
    incs_fold.append(inc_geo)
    dip_dirs.append(dip_dir)
    dips.append(dip)

diddd = ipmag.make_diddd_array(decs_fold, incs_fold, dip_dirs, dips)

ipmag.bootstrap_fold_test(diddd)
# Out:
# doing  1000  iterations...please be patient.....
# tightest grouping of vectors obtained at (95% confidence bounds):
# 79 - 117 percent unfolding
# range of all bootstrap samples:
# 64  -  119 percent unfolding

# %% [markdown]
# Elston's subset also passes a fold test.

# %% [markdown]
# ## Reversal test

# %% [markdown]
# The reversal test was performed below on all the samples.

# %%
decs_reversal = sites_tilt['dir_dec'].tolist()
incs_reversal = sites_tilt['dir_inc'].tolist()

ipmag.reversal_test_bootstrap(decs_reversal, incs_reversal)
# Out:
# Fail, distinct in x, y and z
# 0

# %% [markdown]
# The reversal test was also performed on just the subset of samples selected by Elston et al. (2002) for their pole.

# %%
decs_subset_reversal = sites_subset['dir_dec'].tolist()
incs_subset_reversal = sites_subset['dir_inc'].tolist()

ipmag.reversal_test_bootstrap(decs_subset_reversal, incs_subset_reversal)
# Out:
# Fail, distinct in x, y and z
# 0

# %% [markdown]
# It once again fails.

# %% [markdown]
# ## Pole in the context of the Laurentia APWP

# %%
Laurentia_poles = pt.get_Laurentia_poles()
Laurentia_poles = pt.plot_apwp_context(Laurentia_poles, pole_subset['inc'], pole_subset['dec'], 
                                       pole_subset['alpha95'])

# %% [markdown]
# # R2: Deenen test

# %%
pt.Deenen_test(pole_subset['n'], pole_subset['alpha95'])
_ = pt.plot_Deenen_test(pole_subset)
# Out:
# A_95 of 3.3 is too small for Deenen criteria of 5.0 for this number of sites

# %% [markdown]
# Deenan test fails -- too tightly clustered. This is likely related to Elston's broad definition of a site as a geographic area spanning several meters of stratigraphy, rather than a single stratigraphic layer.

# %% [markdown]
# ## R7: Comparison with younger Laurentia poles

# %%
Laurentia_poles = pt.get_Laurentia_poles()
Laurentia_stricto_poles = pt.get_Laurentia_stricto_poles()
_ = pt.plot_pole_overlap('Snowslip Formation', Laurentia_stricto_poles, pt.Torsvik2012_Laurentia,
                  pole_plat=pole_subset['inc'], pole_plon=pole_subset['dec'],
                  pole_A95=pole_subset['alpha95'], pole_age=1449)

# %%
pole_subset
# Out:
# {'dec': np.float64(212.07383088803937),
#  'inc': np.float64(-25.245444579878114),
#  'n': 9,
#  'r': np.float64(8.967463477116004),
#  'k': np.float64(245.87753364189462),
#  'alpha95': np.float64(3.2898719672818895),
#  'csd': np.float64(5.1656573473505984)}

# %% [markdown]
# ## R-score summary (Meert et al., 2020)
#
# | R | Criterion | Score | Justification |
# |---|---|---|---|
# | 1 | Age within ± 15 Ma | **1** | One SHRIMP U-Pb zircon age of 1454 ± 9 Ma from an underlying tuff and one LA-ICP-MS U-Pb zircon age of 1419.9 ± 8.4 Ma from overlying lava; from Evans et al. 2000 and Constenius et al. (accepted)|
# | 2 | Techniques and statistical analysis | **0** | (a) Only thermal demagnetization was used; however, these are red beds (b) Blanket demagnetization was used at <550°C so fits have magnetite, pigmentary hematite, and detrital hematite. (c) N = 268 samples, k = 246 (fail), A95 = 3.3° fails Deenen et al. (2011) envelope (>5.0°). B = 9 sites ≥ 8 sites. |
# | 3 | Magnetic mineralogy characterized | **0** | Only thermal stepwise demagnetization used for hematite identification. |
# | 4 | Field tests constrain age of magnetization | **1** | Positive regional fold test, timing of folding unclear (Cretaceous at latest). |
# | 5 | Structural control / tectonic coherence | **0** | No inclination shallowing correction applied. Questions about tectonic coherence as entirely on separate thrust sheets, but historically the Belt Supergroup has been treated at part of Laurentia due to underlying basement in one region|
# | 6 | Presence of reversals | **0** | Dual polarity, but fails a reversal test as only one normal site|
# | 7 | No resemblance to younger poles | **1** | No overlap with younger poles  |
# | | **Total R-score** | **3/7** | |

# %% [markdown]
# ## Nordic workshop ranking
#
# Prior Nordic Workshop compilations of paleomagnetic poles with expert-assigned rankings (Evans et al., 2021) have given the pole from the McNamara Formation an 'A' ranking.
#
# Our assessment is that careful evaluation of the pole suggests it should be assigned a 'B' ranking, primarily due to the statistical/laboratory methodology used, which make R2, R3, R5, and R6 scores of 0.

# %%
Snowslip_summary = pt.make_nordic_summary(terrane='Laurentia', 
                                        rockname='Snowslip', 
                                        sites=sites_subset,
                                        dir_mean=dir_mean,
                                        pole_mean=pole_subset,
                                        study_lon=study_lon,
                                        study_lat=study_lat,
                                        component_comment='',
                                        tests='f',
                                        R1=1,
                                        R2=0,
                                        R3=0,
                                        R4='f',
                                        R5=0,
                                        R6=0,
                                        R7=1,
                                        Grade='B', Grade_E21='A',
                                        nominal_age=1449,
                                        lomagage=1435.7,
                                        himagage=1463,
                                        REF_method='One SHRIMP U-Pb zircon age of 1454 ± 9 Ma from an underlying tuff and one LA-ICP-MS U-Pb zircon age of 1419.9 ± 8.4 Ma from overlying lava; from Evans et al. 2000 and Constenius et al. (accepted)',
                                        POLE_AUTHORS='Elston, D. P., Enkin, R. J., Baker, J., and Kisilevsky, D. K. ',
                                        YEAR=2002,
                                        JOURNAL='Geological Society of America Bulletin',
                                        VOLUME=114,
                                        VPAGES='619-638',
                                        TITLE='Tightening the Belt: Paleomagnetic-stratigraphic constraints on deposition, correlation, and deformation of the Middle Proterozoic (ca. 1.4 Ga) Belt-Purcell Supergroup, United States and Canada',
                                        COMMENT='Recalculated from Elston sites (same grouping of sites) as documented in Swanson-Hysell et al. 2026.'
                                        )
Snowslip_summary
# Out:
#      Terrane  ROCKNAME GPMDB RESULT# MAGIC # COMPONENT TESTS  TILT  SLAT  \
# 0  Laurentia  Snowslip                                     f   100  47.9
#
#    SLONG  B    N   DEC   INC     KD  ED95  PLAT  PLONG DP DM  A95  \
# 0 -114.1  9  268  30.9 -20.6  128.8   4.6 -25.2  212.1        3.3
#
#    f (1.0 vs 0.6)  INCf  PLATf  PLONf DPf DMf  A95f  f (1.0/0.8/0.6)  INCf  \
# 0             1.0 -20.6  -25.2  212.1           3.3              1.0 -20.6
#
#    PLATf  PLONf DPf DMf  A95f %REV DEMAGCODE Q1 24 10 16 Q2 Q3 Q4 Q5 Q6 Q7  \
# 0  -25.2  212.1           3.3
#
#   Q(7)  R1  R2  R3 R4  R5  R6  R7  Rsum Grade Grade E+21  nominal age  \
# 0        1   0   0  f   0   0   1     3     B          A         1449
#
#    age diff  lomagage  himagage  \
# 0        27      1436      1463
#
#                                           REF/method  ROCKNAME  \
# 0  One SHRIMP U-Pb zircon age of 1454 ± 9 Ma from...  Snowslip
#
#                                         POLE AUTHORS  YEAR  \
# ...

# %%
# save the summary dictionary as a single-row CSV in data/nordic_summaries
pt.save_nordic_summary(Snowslip_summary, '1449_Snowslip')
# Out:
# '../data/nordic_summaries/1449_Snowslip.csv'

# %% [markdown]
# ## Inclination-shallowing-corrected pole
#
# The pole above is reported as measured. Detrital remanence in sedimentary rocks
# is shallowed during compaction, so its inclination — and the paleolatitude that
# inclination implies — is a minimum. Only site-level mean directions are available for this unit (9 sites), far too few for an elongation/inclination (E/I) or SVEI determination of the flattening factor.
#
# Following Pierce et al. (2022), the flattening factor is instead resampled from
# their compilation of measured *f* values (`ipmag.find_compilation_kent`). Each
# resample unsquishes the mean direction implied by the pole at the sampling
# locality, and the resulting distribution of mean poles is summarized as a Kent
# (1982) distribution whose 95% confidence ellipse carries the flattening
# uncertainty along with the uncertainty in the pole itself. This corrected pole
# is exported to `data/nordic_summaries/kent/` and is the position plotted for
# this unit in the compilation figures; the main compilation table keeps the
# uncorrected pole.

# %%
# Inclination-shallowing-corrected Kent mean pole (Pierce et al., 2022). The
# random seed is fixed so the exported summary is reproducible.
kent = pt.compilation_kent_pole(pole_subset, study_lon, study_lat, random_seed=1)
plt.show()

Snowslip_kent_summary = pt.make_kent_summary(
    Snowslip_summary, kent, 'compilation', 'this study',
    comment='9 site-level mean directions: too few for an E/I or SVEI determination of f')
pt.save_kent_summary(Snowslip_kent_summary, '1449_Snowslip')
Snowslip_kent_summary
# Out:
# Plon: 214.6  Plat: -19.4
# Major axis lon: 264.5  Major axis lat: 61.4
# Minor axis lon: 132.1  Minor axis lat: 20.2
# Major axis angle of 95% ellipse (Zeta): 9.1
# Minor axis angle of 95% ellipse (Eta): 3.3
# Number of directions in mean (n): 7000
#      Terrane  ROCKNAME Lithology  SLAT  SLONG  nominal age  lomagage  \
# 0  Laurentia  Snowslip   Redbeds  47.9 -114.1         1449      1436
#
#    himagage Grade                             f method    f source f f low  \
# 0      1463     B  compilation f (Pierce et al., 2022)  this study
#
#   f high  PLAT uncorrected  PLONG uncorrected  A95 uncorrected  PLAT  PLONG  \
# 0                    -25.2              212.1              3.3 -19.4  214.6
#
#     Zdec  Zinc  Zeta   Edec  Einc  Eta  A95  n resampled  \
# 0  264.5  61.4   9.1  132.1  20.2  3.3  5.5         7000
#
#                                              Comment
# 0  9 site-level mean directions: too few for an E...
