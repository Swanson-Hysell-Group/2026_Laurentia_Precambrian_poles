# %% [markdown]
# # Kangamiut ca. 2042 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Greenland-Nain.
# - Compiled unit/pole label: Kangamiut Dykes.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 23 sites, N = 157 samples; mean direction DEC/INC = 220.0°/56.0°; K = 190.0.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: nominal age 2041, lomagage 2031 Ma, himagage 2054 Ma
# - Proposed new bracket: nominal age 2046 Ma, lomagage 2038.0 Ma, himagage 2054.0 Ma.
# - Compilation method note: Nutman et al., 1999, Leucodioritic cores of two dykes have yielded U–Pb zircon SHRIMP concordia upper intercept ages of 2036±5 Ma and 2046±8 Ma (2s). The older age is preferred given that the zircons likely experienced Pb loss in both samples which would result in apparent younger ages.
#
# ## References
#
# - Paleomagnetic source: Fahrig, W.F., Bridgwater, D. (1976). Late Archean-Early Proterozoic paleomagnetic pole positions from West Greenland. Early Hist. of Earth, 427-439.
# - Geochronology / age-constraint note (compilation): 2543, 2766, mixed polarity?

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Kangamiut Dykes',Laurentia_poles)
# Out:
# N = 157 (N ≥ 25; sufficient sample number);
# B = 23 (B ≥ 8; sufficient site number);
# K = 190 (K ≥ 70; concern about underrepresenting PSV);
# A_95 of 2.7 is too small for Deenen criteria of 3.4 for this number of sites

# %%
plot_pole_overlap('Kangamiut Dykes',Laurentia_poles,Torsvik2012_Laurentia)
