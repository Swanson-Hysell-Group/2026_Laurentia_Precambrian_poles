# %% [markdown]
# # Molson ca. 1878 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Superior(West).
# - Compiled unit/pole label: MOLSON B+C2.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - mean direction DEC/INC = 248.6°/66.7°; K = 1000.0.
# - Field/statistical tests noted in compilation: C+.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: nominal age 1885 Ma, lomagage 1881.0 Ma, himagage 1889.0 Ma.
# - Compilation method note: 1884.5 ± 3.6 Ma U-Pb baddeleyite age from one dike from Heaman et al., 2009.
#
# ## References
#
# - Paleomagnetic source: Evans,D.A.D., Halls,H.C. (2010). Restoring Proterozoic deformation within the Superior craton. Precambrian Res., 183, 474-489.
# - Geochronology / age-constraint note (compilation): 1877+7/-4 from Halls, H. C., & Heaman, L. M. (2000). The paleomagnetic significance of new U–Pb age data from the Molson dyke swarm, Cauchon Lake area, Manitoba. Canadian Journal of Earth Sciences, 37(6), 957–966. https://doi.org/10.1139/e00-010; 1884.5 +/- 3.6 Ma from Heaman, L. M., Peck, D., & Toope, K. (2009). Timing and geochemistry of 1.88 Ga Molson Igneous Events, Manitoba: Insights into the formation of a craton-scale magmatic and metallogenic province. Precambrian Research, 172(1), 143–162. https://doi.org/10.1016/j.precamres.2009.03.015

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
plot_pole_overlap('MOLSON B+C2',Laurentia_poles,Torsvik2012_Laurentia)
