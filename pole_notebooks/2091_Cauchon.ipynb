# %% [markdown]
# # Cauchon ca. 2091 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Superior(West).
# - Compiled unit/pole label: CAUCHON LAKE.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - mean direction DEC/INC = 123.3°/-63.9°; K = 1000.0.
# - Field/statistical tests noted in compilation: C+.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: nominal age 2091 Ma, lomagage 2089 Ma, himagage 2093 Ma.
# - Compilation method note: a baddeleyite–zircon U–Pb ID-TIMS upper intercept date of 2091 ± 2 Ma from Halls and Heaman 2000.
#
# ## References
#
# - Paleomagnetic source: Evans,D.A.D., Halls,H.C. (2010). Restoring Proterozoic deformation within the Superior craton. Precambrian Res., 183, 474-489.
# - Geochronology / age-constraint note (compilation): 2091±2, Halls, H. C., & Heaman, L. M. (2000). The paleomagnetic significance of new U–Pb age data from the Molson dyke swarm, Cauchon Lake area, Manitoba. Canadian Journal of Earth Sciences, 37(6), 957–966. https://doi.org/10.1139/e00-010

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
plot_pole_overlap('CAUCHON LAKE',Laurentia_poles,Torsvik2012_Laurentia)
