# %% [markdown]
# # Chengwatana ca. 1095 Ma paleomagnetic pole## Geologic Context- Terrane: Laurentia.- Compiled unit/pole label: Chengwatana Volcanics.## Paleomagnetic And Rock Magnetic Data- B = 8 sites, N = 60 samples; mean direction DEC/INC = 287.5°/45.8°; K = 48.5.- Field/statistical tests noted in compilation: Ro.- Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.## Age Constraints- Current bracket: lomagage 1093.0 Ma, himagage 1097.0 Ma.- Compilation method note: 1094.6±2.1 Ma 207Pb/206Pb age from 4 zircons from aphrytic rhyolite of the Chengwatana Volcanics, Zartman et al., 1997## References- Paleomagnetic source: Kean,W.F., Williams.,I., Chan,L., Feeney,J. (1997). Magnetism of the Keweenawan age Chengwatana lava flows, northwest Wisconsin. Geophys.Res.Lett., 24, 1523-1526.- Geochronology / age-constraint note (compilation): 1094.6±2.1 Ma 207Pb/206Pb age from 4 zircons from aphrytic rhyolite of the Chengwatana Volcanics, Zartman et al., 1997

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Chengwatana Volcanics',Laurentia_poles)
# Out:
# N = 60 (N ≥ 25; sufficient sample number);
# B = 8 (B ≥ 8; sufficient site number);
# K = 48 (70 ≥ K ≥ 10; meets PSV criteria);
# A_95 of 8.2 passes Deenen et al. (2011) criteria of being between 5.2 and 22.1 for this number of sites

# %%
plot_pole_overlap('Chengwatana Volcanics',Laurentia_stricto_poles,Torsvik2012_Laurentia)
