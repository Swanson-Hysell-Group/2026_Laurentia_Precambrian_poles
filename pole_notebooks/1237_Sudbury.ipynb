# %% [markdown]
# # Sudbury ca. 1237 Ma paleomagnetic pole## Geologic Context- Terrane: Laurentia.- Compiled unit/pole label: Sudbury Dykes Combined.## Paleomagnetic And Rock Magnetic Data- B = 52 sites, N = 205 samples; mean direction DEC/INC = 265.2°/2.3°; K = 1000.0.- Component note: Combined Result.- Field/statistical tests noted in compilation: C+.- Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.## Age Constraints- Current bracket: lomagage 1232.0 Ma, himagage 1242.0 Ma.- Compilation method note: ok on age; demag good in Stupavsky+Symons 82; and also maybe Schwarz+Buchan 82, GPMDB4.6## References- Paleomagnetic source: Palmer,H.C., Merz,B.A., Hayatsu,A. (1977). The Sudbury dikes of the Grenville Front region: paleomagnetism, petrochemistry, and K-Ar age studies. Canad.J.Earth Sci., 14, 1867-1887.- Geochronology / age-constraint note (compilation): ok on age; demag good in Stupavsky+Symons 82; and also maybe Schwarz+Buchan 82, GPMDB4.6

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Sudbury Dykes Combined',Laurentia_poles)
# Out:
# N = 205 (N ≥ 25; sufficient sample number);
# B = 52 (B ≥ 8; sufficient site number);
# K = 1000 (K ≥ 70; concern about underrepresenting PSV);
# A_95 of 2.5 passes Deenen et al. (2011) criteria of being between 2.5 and 6.8 for this number of sites

# %%
plot_pole_overlap('Sudbury Dykes Combined',Laurentia_stricto_poles,Torsvik2012_Laurentia)
