# %% [markdown]
# ## Central Arizona diabase ca. 1098 Ma paleomagnetic pole (N1 population)
#
# ### Geologic context
#
# There are widespread Proterozoic thick diabase intrusions in Central Arizona in southwestern Laurentia. Previous paleomagnetic data from these thick mafic intrusions show at least two distinct populations of paleomagnetic directions---one population with shallow westward directions (with one potential coeval intrusion with a reversed polarity), and the other population with steep N and S dual-polarity directions.
#
# These intrusions are not well dated and the paleomagnetic data is poorly paired with geochronology data. Harlan, 1993 did a paleomagnetic study on the sills and Donadini et al., 2011 reported an updated paleomagnetic study from the intrusions (including resampling some sills from Harlan, 1993 and regrouping paleomagnetic data into a unified site-level dataset). In SUPERCONTINENT SYMPOSIUM 2012 abstract compilation Donadini et al reported that one dike with the N1 direction (shallow and westerly reported in Donadini et al., 2011) is dated at 1088 ± 11 Ma (2 $\sigma$) by U-Pb geochronology. However, that date comes from personal communication with Ryan Bright and the data was not presented with what mineral it was conducted on or data table.
#
# In context of the Keweenawan Track paleomagnetic apparent polar wander path, the two populations of the paleomagnetic directions from the intrusions are possibly associated with an early pulse coincident with the early stage magmatism of the Midcontinent Rift before ca. 1105 Ma Alona Bay reversed polarity zone, whereas the population with shallower inclination possibly correlates with the younger pulse of magmatism in the MCR ca. 1096 Ma but could also be associated with the Portage Lake Volcanism. In Mohr et al., 2024, one mafic sill from the Salt River Canyon in Central Arizona was dated at 1097.97 ± 0.12 Ma which is consistent with it being associated with the mafic magmatism of the SWLLIP at the time. However, it is uncertain whether that dated sill was previously sampled for paleomagnetic study of Donadini et al., 2011.
#
# ### Paleomagnetic and rock magnetic data
#
# Harlan, 1993 conducted both AF and thermal demagnetization on their samples. PCA analysis was used to isolate the characteristic remanent magnetization (ChRM) directions. The demag data and IRM acquisition experimental data were used to infer magnetic mineralogy. Authors interpreted that the remanence is dominantly held by low-titanium magnetite.
#
# Donadini et al., 2011 conducted both AF and thermal demagnetization on their samples. Additional low-temperature demagentization was carried out for some of the samples.PCA analysis was used to isolate the characteristic remanent magnetization (ChRM) directions. In addition, the study measured hysteresis loops, x-T experiments, and petrographic and SEM data from their samples. Titanomagnetite and titanohematite were identified as the main magnetic carriers in the samples.
#
# Donadini et al., 2011 conducted a baked contact test on one sill (ED) that yielded a shallow and westerly direction (N1 population). The baked quartzite sedimentary rock samples of the Pioneer near the sill yielded a direction that overlaps with the sill direction. That direction is close to but distinct from previously reported paleomagnetic directions from the Pioneer quartzite in Scott and Paulo, 1976. The baked contact test results suggest that the shallow and westerly direction (N1 population) is likely a primary magnetization component.
#
# The study did not report tilt measurement nor did it apply any tilt correction to the paleomagnetic data. However, the authors did adopt the correction of Harlan (1993) for a consistent rotation of 5° associated with the hypothesized Colorado Plateau rotation.
#
# The site groupings of the sampled sills Zhang et al., 2024 re-compiled the paleomagnetic data from both studies and re-evaluated the groupings. A proposed mean pole is calculated for the N1 population which we will reproduce here.
#
# ### Age constraints
#
# - Sill FD: 1088 ± 11 Ma (2 $\sigma$) by U-Pb geochronology (Donadini et al., 2011; Donadini et al., 2012). However, that date comes from personal communication with Ryan Bright and the data was not presented with mineral source or a data table and the field guide is not peer-reviewed.
#
# ### References
#
# #### Paleomagnetism
#
# - Harlan, S. S. (1993). Paleornagnetism of Middle Proterozoic diabase sheets from central Arizona. Canadian Journal of Earth Sciences, 30(7), 1415–1426. https://doi.org/10.1139/e93-122
#
# - Donadini, F., Pesonen, L. J., Korhonen, K., Deutsch, A., & Harlan, S. S. (2011). Paleomagnetism and paleointensity of the 1.1 Ga old diabase sheets from central Arizona. Geophysica, 47(1–2), 3–30.
#
# - Zhang, Y., Anderson, N. S., Mohr, M. T., Nelson, L. L., Macdonald, F. A., Schmitz, M. D., Thurston, O. G., Guenthner, W. R., Karlstrom, K. E., & Swanson-Hysell, N. L. (2024). Paleomagnetic records from pulsed magmatism in the southwestern Laurentia large igneous province and Cardenas Basalt support rapid late Mesoproterozoic plate motion. Journal of Geophysical Research: Solid Earth, 129(10). https://doi.org/10.1029/2024jb029036
#
# #### Geochronology
#
# - Donadini, F., Pesonen, L. J., Korhonen, K., Deutsch, A., Harlan, S., Heaman, L., Helsinki, M. S., & Sangchan, P. (2012). Symmetric and asymmetric reversals in the 1.1 Ga central Arizona diabases: The debate continues. Supercontinent Symposium, 35–36.
#
# - Mohr, M. T., Schmitz, M. D., Swanson-Hysell, N. L., Karlstrom, K. E., Macdonald, F. A., Holland, M. E., Zhang, Y., & Anderson, N. S. (2024). High-precision U-Pb geochronology links magmatism in the southwestern Laurentia large igneous province and Midcontinent Rift. Geology. https://doi.org/10.1130/g51786.1

# %%
import pole_tools as pt
import pmagpy.ipmag as ipmag
import pmagpy.pmag as pmag
import matplotlib.pyplot as plt
import pmagpy.contribution_builder as cb
import pandas as pd
import numpy as np

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %% [markdown]
# ## import the MagIC contribution

# %%
# set the directory path (dir_path) to the data
dir_path = '../data/1098_Central_Arizona_sills/Harlan1993a'

# unpack the Harlan 1993 data contribution
ipmag.unpack_magic('magic_contribution_20655.txt', 
                     dir_path = dir_path,
                     input_dir_path = dir_path, print_progress=False)
# Out:
# 1  records written to file  /Users/penokean/0000_GitHub/2026_Laurentia_Precambrian_poles/data/1098_Central_Arizona_sills/Harlan1993a/contribution.txt
# 1  records written to file  /Users/penokean/0000_GitHub/2026_Laurentia_Precambrian_poles/data/1098_Central_Arizona_sills/Harlan1993a/locations.txt
# 31  records written to file  /Users/penokean/0000_GitHub/2026_Laurentia_Precambrian_poles/data/1098_Central_Arizona_sills/Harlan1993a/sites.txt
# True

# %%
# load the Harlan, 1993 site data
Harlan1993a_sites = pd.read_csv(f'{dir_path}/sites.txt', sep='\t', header=1)

# load the Donadini et al., 2011 data contribution
Donadini2011a_sites = pd.read_csv('../data/1098_Central_Arizona_sills/Donadini2011a/sites.txt', sep='\t', header=1)

# %% [markdown]
# ## Harlan (1993) Diabase sheets (sills) (Central Arizona)
#
# The sample sites are adjacent and within similar "cooling" units. We compile data from this study and attempt to combine the pmag results with those from the study of Donadini et al., 2011 study and try to distinguish individual cooling units and calculate the mean poles for the normal polarity sites and the reversed polarity sites. The main issue that we had to deal with was that the two studies had ambiguous overlap in sampled sills.
#
# According to the authors, demagnetization methods used in experiments are progressive AF or thermal demagnetizations. Least square algorithm was used in doing line fits.
#
# Issues related to this study and Donadini (2011) study in terms of overlapping sites and tilt correction, and rotation correction based on the Colodado Plateau:
# - Harlan's sites are all named as "GD##", which is different from the single site named "GD" in Donadini (2011) study.
# - The site GD in Donadini (2011) does not show up on their geologic map, because the site locations is exactly the same as site DC.
# - However, the samples used for paleointensity study and reported unreliable results in Donadini (2011) study are from the GD sites from Harlan (1993).
# - Harlan (1993) reported tilt correction for two sites, GD25 and GD26, which are further south from other sites. Donadidni (2011) mentioned that the amount of tilt in the region is small and thuse no tilt correction was applied. This is likely related to that the Harlan study is that they did not follow as strict field rules as Helsley to only sample diabase sites with good paleohorizontal constraint.
# - Donadini (2011) has inconsistent descriptions about rotation correction in their table 5 and subsequent texts. We are not sure if the data reported in table 5 is actually corrected for 5 $^\circ$ rotation.
# - They attribute the unusual scatter in their data to be due to a combination of poor sampling, not being unable to isolate the primary components, and Laramide orogeny remagnetizations.
#
# We are not including site GD21 because it is likely remagnetized; we are not including SR sites in Harlan (1993) because they are from another study by Sandberg and Butler (1986). Sites GD18, GD19, GD20 are interpreted to be significantly affected by Laramide Orogeny and were excluded by Harlan et al.
#
# Reference:
# Harlan, S. S. (1993). Paleomagnetism of Middle Proterozoic diabase sheets from central Arizona. Canadian Journal of Earth Sciences, 30(7), 1415-1426. DOI: 10.1139/e93-122.

# %%
Harlan1993a_sites = ipmag.vgp_calc(Harlan1993a_sites,tilt_correction='no',site_lon='lon',site_lat='lat',dec_is='dir_dec',inc_is='dir_inc')

# Plotting grouped data for each "cooling unit" following Harlan (1993) table 2
Harlan1993a_independent_sites = Harlan1993a_sites[Harlan1993a_sites['description'].notnull()]

# %% [markdown]
# ## Donadini (2011) Diabase sheets (sills) (central Arizona)
#
# Samples from 33 sites of diabase sills were collected from central Arizona. Step-wise thermal and AF treatments were both applied to isolate characteristic magnetizations. Principal component analysis were performed using the PmagPy software. Two distinct magnetic poles were interpreted. They did not correct for the rotation of the Colorado plateau (5 degree).
#
# Some sites were excluded from paleodirection anlysis based on rock magnetic studies: DF, ND, SD, VD, WD, XD3. Their final paleomagnetic analysis were based on selection criteria: MAD < 15, site a95 < 15, and k > 30, and N > 3. As a result the resultant mean pole position for the reversed pole has large uncertainty.
#
# Donadini, F., Pesonen, L.J., Korhonen, K., Deutsch, A. and Harlan, S.S., 2011. Paleomagnetism and paleointensity of the 1.1 Ga old diabase sheets from central Arizona. Geophysica, 47(1-2), pp.3-30.

# %%
Donadini2011a_sites = ipmag.vgp_calc(Donadini2011a_sites,tilt_correction='no',site_lon='lon',site_lat='lat',dec_is='dir_dec',inc_is='dir_inc')
# Dropping ND, SD, VD, XD3 according to authors' rejection
Donadini2011a_sites = Donadini2011a_sites.drop(Donadini2011a_sites[Donadini2011a_sites['site']=='ND'].index)
Donadini2011a_sites = Donadini2011a_sites.drop(Donadini2011a_sites[Donadini2011a_sites['site']=='VD'].index)
Donadini2011a_sites = Donadini2011a_sites.drop(Donadini2011a_sites[Donadini2011a_sites['site']=='XD3'].index)

Donadini2011a_sites
# Out:
#    site      location  dir_dec  dir_inc  dir_k  dir_alpha95  dir_n_samples  \
# 0    AD   Gila County    272.9     47.3   71.9          3.6             23
# 1    DB   Gila County    282.5     24.8  215.6          3.3             10
# 2    DC   Gila County    281.2     33.8   91.9          5.4              9
# 3    DF   Gila County    332.6     69.4  145.1          3.5             13
# 4    DG  Sierra Ancha    266.2     34.4   58.7          8.0              7
# 5    DJ  Sierra Ancha    281.9     52.8  325.5          2.9              9
# 6    ED   Gila County    288.6     51.6   71.5          5.4             11
# 7    FD   Gila County    279.2     49.3   48.5          8.0              8
# 8    GD   Gila County    278.8     29.0  102.8          6.0              7
# 9    KD  Sierra Ancha    293.8     13.4  142.3          3.3             14
# 10   LD  Sierra Ancha    283.4     18.8   45.4         13.8              4
# ...

# %%
ipmag.plot_net()
ipmag.plot_di(Donadini2011a_sites.dir_dec.tolist(),Donadini2011a_sites.dir_inc.tolist())

# %% [markdown]
# ## merging data from the two studies and resolve overlapping sites between Harlan (1993) and Donadini (2011)
#
# 1. We will primarily follow Harlan (1993) because they split the sills into individual cooling units.
#
# 2. GD27 == GD15 (the question is, are ID, DE, and WD from same sill as these, and are them three from same sill? in Arizona state map they are not!) Looks like the GD15 and GD27 are the same as DE. not sure if the ID and WD are the same as DE sill.
# So we will not take DE
#
# 3. Donadini DC and GD looks to be replicates of Harlan 29, 30. But Harlan splits two sills between 29 and 30.
# So we will not take DC or GD in Donadini.
#
# 4. The Sierra Ancha sites from Donadini are unique but we don't know whether they are from same sills.
#
# 5. Harlan GD12 and GD13 are the same sill which was also sampled as OD in Donadini, so we will calculate a mean direction for the sill and use the new mean as the site level data.
#
# 6. We interpret that the Donadini KD and LD are the same sill, due to close proximity and anomolous low inclination
#
# 7. for the salt river region data, we preferentially use Harlan data because they are split into sills. So we should drop all Donadini stes in Salt River region.
#
# 8. we should drop the Harlan GD23 site because it is anomolous inclination of 0.
#
# 9. Donadini BD and CD are likely the same sill, and be included since Harlan does not have reversed sill from Salt lake river area. BD has better kappa parameter so we choose to keep site BD.
#
# 10. KD and LD are likely from the same sill. But site LD has much larger uncertainty.
#
# 11. WD and ID in Donadini are close and have similar directions. They might be from the same sill. We use WD here because it has more samples and have tighter uncertainty.
#
# 12. site XD3 according to Donadini is not diabase and they dropped it.
#
# 13. VD was also dropped by Donadini.
#
# 14. SD appears to be a single site where an antipodal component to the normal polarity component was found. There is not enough data to give further insight into the origin of that direction. Thus we exclude it from our analysis.
#
# 15. We drop Harlan GD23 site because the anomolously 0 inclination angle.
#
# In summary, the steeeply reversed directions in central Arizona are from GD11, GD15-27, and BD, WD.

# %%
# filter for the sites to keep in Donadini data.
Donadini2011a_sites = Donadini2011a_sites[Donadini2011a_sites['site'].isin(['DF', 'DG', 'DJ', 'MD', 'BD', 'CD', 
                                                                            'KD', 'LD', 'ID', 'WD', 'SD', 'OD'])]
Harlan_Donadini = pd.concat([Harlan1993a_sites, Donadini2011a_sites], ignore_index=True)

# keep BD instead of CD for better uncertainty (they are same sill)
# keep WD instead of ID for better uncertainty (they are same sill)
# drop Donadini LD site and keep KD site because of close proximity and similar low inclination but LD has much larger uncertainty 
Harlan_Donadini = Harlan_Donadini.drop(Harlan_Donadini[Harlan_Donadini['site'] == 'LD'].index)
Harlan_Donadini = Harlan_Donadini.drop(Harlan_Donadini[Harlan_Donadini['site'] == 'CD'].index)
Harlan_Donadini = Harlan_Donadini.drop(Harlan_Donadini[Harlan_Donadini['site'] == 'ID'].index)

# drop Harlan GD23 site because the anomolously 0 inclination angle
Harlan_Donadini = Harlan_Donadini.drop(Harlan_Donadini[Harlan_Donadini['site'] == 'GD23'].index)

# take average of GD12, GD13 and OD as they are likely one same sill, the individual entry will be dropped and we calculate a mean direction from the three records
GD12_GD13_OD = Harlan_Donadini[Harlan_Donadini['site'].isin(['GD12', 'GD13', 'OD'])]
GD12_GD13_OD_mean = ipmag.fisher_mean(GD12_GD13_OD['dir_dec'].tolist(), GD12_GD13_OD['dir_inc'].tolist())
Harlan_Donadini = pd.concat([Harlan_Donadini, pd.DataFrame([{'site':'GD12_GD13_OD',
                                          'location': 'Gila County',
                                          'dir_dec': GD12_GD13_OD_mean['dec'],
                                          'dir_inc': GD12_GD13_OD_mean['inc'],
                                          'dir_k': GD12_GD13_OD_mean['k'], 
                                          'dir_alpha95': GD12_GD13_OD_mean['alpha95'],
                                          'lat': 33.55, 
                                          'lon': -110.69, 
                                          'geologic_classes': 'Intrusive:Igneous', 
                                          'geologic_types': 'Sill', 
                                          'lithologies': 'Diabase',
                                          'method_codes': 'LP-DIR-AF:LP-DIR-T:DE-BFL;LP-DC4',
                                          'result_quality': 'g',
                                          'result_type': 'i', 
                                          'age': '1100', 
                                          'age_unit': 'Ma', 
                                          'citations': 'Donadini2011a'}])])

Harlan_Donadini = ipmag.vgp_calc(Harlan_Donadini,tilt_correction='no',site_lon='lon',site_lat='lat',dec_is='dir_dec',inc_is='dir_inc')

individual_sills = ['GD01-02', 'GD03', 'GD04', 'GD05', 'GD06-07', 'GD08', 'GD09', 'GD10', 'GD12_GD13_OD', 
                'GD17', 'GD18-20', 'GD22', 'GD24', 'GD29', 'GD30', 'GD11', 'GD15-27', 
                       'DF', 'DG', 'DJ', 'MD', 'BD', 'KD', 'WD']
Harlan_Donadini = Harlan_Donadini[Harlan_Donadini['site'].isin(individual_sills)]
Harlan_Donadini = Harlan_Donadini.reset_index(drop=True)

Harlan_Donadini_dir_normal, Harlan_Donadini_dir_steep_reversed = pmag.flip(Harlan_Donadini[['dir_dec', 'dir_inc']].to_numpy())
Harlan_Donadini_pole_normal, Harlan_Donadini_pole_steep_reversed = pmag.flip(Harlan_Donadini[['vgp_lon','vgp_lat']].to_numpy())

# %%
reversed_sites = Harlan_Donadini[Harlan_Donadini['dir_inc'] < 0]['site'].tolist()
Harlan_Donadini_normal_vgp_df = Harlan_Donadini[~Harlan_Donadini['site'].isin(reversed_sites)].reset_index(drop=True)
Harlan_Donadini_normal_vgp_df
# Out:
#      age age_unit        citations  description  dir_alpha95     dir_dec  \
# 0   1100       Ma  10.1139/e93-122          1.0          NaN  279.200000
# 1   1100       Ma  10.1139/e93-122          2.0     3.600000  285.300000
# 2   1100       Ma  10.1139/e93-122          3.0     7.700000  295.500000
# 3   1100       Ma  10.1139/e93-122          4.0     5.800000  283.200000
# 4   1100       Ma  10.1139/e93-122          5.0          NaN  282.800000
# 5   1100       Ma  10.1139/e93-122          6.0     5.600000  318.000000
# 6   1100       Ma  10.1139/e93-122          7.0    11.500000  299.200000
# 7   1100       Ma  10.1139/e93-122          8.0     3.300000  267.500000
# 8   1100       Ma  10.1139/e93-122         10.0     8.300000  285.900000
# 9   1100       Ma  10.1139/e93-122         11.0          NaN  339.600000
# 10  1100       Ma  10.1139/e93-122         12.0     5.100000  270.100000
# 11  1100       Ma  10.1139/e93-122         14.0     4.000000  297.900000
# ...

# %% [markdown]
# ## print new interpreted directional mean and pole means

# %%
Harlan_Donadini_normal_dir_mean = ipmag.fisher_mean(di_block=Harlan_Donadini_dir_normal)
Harlan_Donadini_normal_dir_mean
# Out:
# {'dec': np.float64(287.6253113557007),
#  'inc': np.float64(47.35903548662463),
#  'n': 20,
#  'r': np.float64(18.78916367544802),
#  'k': np.float64(15.691633637626587),
#  'alpha95': np.float64(8.508326238840835),
#  'csd': np.float64(20.448004825314406)}

# %%
Harlan_Donadini_normal_mean = ipmag.fisher_mean(di_block=Harlan_Donadini_pole_normal)
Harlan_Donadini_normal_mean
# Out:
# {'dec': np.float64(177.43969545962125),
#  'inc': np.float64(30.64060469928467),
#  'n': 20,
#  'r': np.float64(18.677930346303807),
#  'k': np.float64(14.371406186414239),
#  'alpha95': np.float64(8.917790752693259),
#  'csd': np.float64(21.366598377030005)}

# %% [markdown]
# ## Site location map

# %%
pt.plot_site_map(Harlan_Donadini)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ### Site directions (as measured at site)

# %%
ipmag.print_direction_mean(Harlan_Donadini_normal_dir_mean)

ipmag.plot_net()
ipmag.plot_di(di_block=Harlan_Donadini_dir_normal, color='blue', marker='o')
ipmag.plot_di_mean(Harlan_Donadini_normal_dir_mean['dec'], Harlan_Donadini_normal_dir_mean['inc'], Harlan_Donadini_normal_dir_mean['alpha95'], 
                   color='red', marker='s')
ipmag.plt.title('Mean Site Directions (as measured at sites)')
ipmag.plt.show()
# Out:
# Dec: 287.6  Inc: 47.4
# Number of directions in mean (n): 20
# Angular radius of 95% confidence (a_95): 8.5
# Precision parameter (k) estimate: 15.7

# %% [markdown]
# ### Mean pole from VGPs

# %%
ipmag.print_pole_mean(Harlan_Donadini_normal_mean)
pole_plot = pt.plot_vgps_and_pole(Harlan_Donadini_pole_normal, Harlan_Donadini_normal_mean, 200, 15)
# Out:
# Plon: 177.4  Plat: 30.6
# Number of directions in mean (n): 20
# Angular radius of 95% confidence (A_95): 8.9
# Precision parameter (k) estimate: 14.4

# %% [markdown]
# ### Site direction (calculated from VGPS for common site location)

# %%
study_lon = 360-110.47
study_lat = 33.8
dir_block_from_vgps, dir_mean_from_vgps = pt.compute_mean_direction_from_vgps(Harlan_Donadini_normal_vgp_df, study_lon, study_lat,)

ipmag.print_direction_mean(dir_mean_from_vgps)

ipmag.plot_net()
ipmag.plot_di(di_block=dir_block_from_vgps, color='blue', marker='o')
ipmag.plot_di_mean(dir_mean_from_vgps['dec'], dir_mean_from_vgps['inc'], 
                   dir_mean_from_vgps['alpha95'], color='red', marker='s')
ipmag.plt.title('Mean Site Directions (calculated for common locality from VGPs)')
ipmag.plt.show()
# Out:
# Dec: 287.6  Inc: 47.2
# Number of directions in mean (n): 20
# Angular radius of 95% confidence (a_95): 8.6
# Precision parameter (k) estimate: 15.5

# %% [markdown]
# ### Pole in the context of the Laurentia APWP

# %%
Laurentia_poles = pt.get_Laurentia_poles()
Laurentia_poles = pt.plot_apwp_context(Laurentia_poles, Harlan_Donadini_normal_mean['inc'], Harlan_Donadini_normal_mean['dec'], Harlan_Donadini_normal_mean['alpha95'], age_min=635, age_max=1800, projection='orthographic', central_longitude=Harlan_Donadini_normal_mean['dec'], central_latitude=Harlan_Donadini_normal_mean['inc'])
plt.show()

# %% [markdown]
# ### R2: Deenen test

# %%
pt.Deenen_test(Harlan_Donadini_normal_mean['n'], Harlan_Donadini_normal_mean['alpha95'])
pt.plot_Deenen_test(Harlan_Donadini_normal_mean)
# Out:
# A_95 of 8.9 passes Deenen et al. (2011) criteria of being between 3.6 and 12.4 for this number of sites
# <Axes: title={'center': 'Deenen et al. (2011) test'}, xlabel='Number of sites (N)', ylabel='$A_{95}$ (°)'>

# %% [markdown]
# ### R2: paleosecular variation — Fisher Q–Q and SVEI
#
# The Fisher quantile–quantile (fishqq) test evaluates whether the normal-polarity
# site VGPs are Fisher-distributed, and the shape-elongation/inclination (SVEI)
# test compares the VGP elongation and V2 declination against the TK03.GAD
# paleosecular-variation model — together assessing whether secular variation is
# adequately sampled.

# %%
fishqq_result = pt.fishqq_vgps(Harlan_Donadini_normal_vgp_df, unify_polarity=True)
fishqq_result
# Out:
# {'Mode': 'Mode 1',
#  'Dec': np.float64(177.6715757391646),
#  'Inc': np.float64(29.659159432940623),
#  'N': 20,
#  'Mu': np.float64(1.297385281386965),
#  'Mu_critical': 1.207,
#  'Me': np.float64(0.5800418110000238),
#  'Me_critical': 1.094,
#  'Test_result': 'Fisher distribution rejected'}

# %%
svei_result = pt.svei_test_vgps(Harlan_Donadini_normal_vgp_df, study_lon, study_lat, model='TK03_GAD', plot=True)
print(f"paleolatitude = {svei_result['lat']:.1f}°")
print(f"elongation E = {svei_result['E']:.2f} "
      f"(model 95% bounds {svei_result['Esim_min']:.2f}–{svei_result['Esim_max']:.2f}; "
      f"{'consistent' if svei_result['E_result'] else 'inconsistent'})")
print(f"V2 declination = {svei_result['V2dec']:.1f}° "
      f"(model 95% bounds {svei_result['V2sim_min']:.1f}–{svei_result['V2sim_max']:.1f}; "
      f"{'consistent' if svei_result['V2_result'] else 'inconsistent'})")
# Out:
# paleolatitude = 28.6°
# elongation E = 2.40 (model 95% bounds 1.15–4.58; consistent)
# V2 declination = 246.9° (model 95% bounds 106.3–256.2; consistent)

# %% [markdown]
# ### R7: Comparison with younger Laurentia poles

# %%
Laurentia_poles = pt.get_Laurentia_poles()
Laurentia_stricto_poles = pt.get_Laurentia_stricto_poles()
pt.plot_pole_overlap('Central Arizona diabases -N', Laurentia_stricto_poles, pt.Torsvik2012_Laurentia,
                  pole_plat=Harlan_Donadini_normal_mean['inc'], pole_plon=Harlan_Donadini_normal_mean['dec'],
                  pole_A95=Harlan_Donadini_normal_mean['alpha95'])
# Out:
# <GeoAxes: >

# %% [markdown]
# ### R-score summary (Meert et al., 2020)
#
# | R | Criterion | Score | Justification |
# |---|---|---|---|
# | 1 | Age within ± 15 Ma | **1** | Central Arizona date of 1097.97 ± 0.12 (0.32) [1.14] Ma from Mohr et al. 2024 likely corresponds to bulk of magmatic activity. However, there is older and younger late Mesoproterozoic magmatic activity as revealed from reversed polarity sills and younger dates in northern Arizona from Mohr et al. 2024. *Previous Nordic compilation relied on 1088 ± 11 Ma U-Pb date (sill ED) from Donadini abstract 2012 with personal communication with Ryan Bright* |
# | 2 | Techniques and statistical analysis | **1** | (a) AF and thermal demagnetization applied. (b) PCA used for component isolation. (c) N = more than 25 sites, k = 14.4, A95 = 8.9° passes Deenen et al. (2011) envelope (3.6°–12.4°). B = 20 sites ≥ 8. |
# | 3 | Magnetic mineralogy characterized | **1** | Harlan, 1993 and Donadini et al., 2011 studies present x-T experimental data, hysteresis loops, SEM data, demag data that show titanomagnetite and titanohematite as primary carriers of remanence |
# | 4 | Field tests constrain age of magnetization | **1** | Successful baked contact test between one N1 sill and the Pioneer Shale sedimentary rock |
# | 5 | Structural control / tectonic coherence | **1** | No tilt correction reported but both studies applied 5 degrees Colorado Plateau rotation to the data. Mafic sill intrusions — no inclination shallowing correction needed. |
# | 6 | Presence of reversals | **0** | All directions are of single polarity. No reversal test possible. |
# | 7 | No resemblance to younger poles | **1** | The pole does not overlap with any known younger poles. |
# | | **Total R-score** | **6/7** | |

# %% [markdown]
# # Nordic workshop ranking
#
# Prior Nordic Workshop compilations have given this pole an A rating. However, given the non-Fisherian streak of the directions along the Keweenawan Track resulted to a downgrade to a B rating at the 2026 workshop.

# %% [markdown]
# ### Normal-polarity (N1) pole
#
# | Quantity | This study (site VGPs) | Donadini et al. (2011) | Previous Nordic compilation |
# |---|---|---|---|
# | Component | Normal polarity (N1) | Normal polarity (N1); Gila County this-study mean | Central Arizona diabases -N |
# | N (sites) | 20 | 13 | 13 |
# | N (specimens) | 141 | 139 | 139 |
# | Dec (°) | 287.6 | 274.8 | 274.8 |
# | Inc (°) | 47.4 | 38.7 | 38.7 |
# | k (direction) | 15.7 | 30.4 | 30.4 |
# | α95 (direction, °) | 8.5 | 7.6 | 7.6 |
# | Pole lat (°N) | 30.6 | 15.7 | 15.7 |
# | Pole lon (°E) | 177.4 | 175.3 | 175.3 |
# | A95, pole (°) | 8.9 | 7.3 | 7.0 |
# | dp / dm (°) | 8.9 / 8.9 | 5.4 / 9.1 | 5.4 / 9.1 |

# %%
Central_Arizona_summary = pt.make_nordic_summary(terrane='Laurentia', 
                                        rockname='Central Arizona diabases', 
                                        sites=Harlan_Donadini_normal_vgp_df,
                                        dir_mean=Harlan_Donadini_normal_dir_mean,
                                        pole_mean=Harlan_Donadini_normal_mean,
                                        study_lon=study_lon,
                                        study_lat=study_lat,
                                        component_comment='',
                                        tests='C (positive baked-contact test on sill ED; Donadini et al., 2011)',
                                        R1=1,
                                        R2=1,
                                        R3=1,
                                        R4='C',
                                        R5=1,
                                        R6=0,
                                        R7=1,
                                        Grade='A',
                                        nominal_age=1098,
                                        lomagage=1082,
                                        himagage=1110,
                                        REF_method='Central Arizona date of 1097.97 ± 0.12 (0.32) [1.14] Ma from Mohr et al. 2024 likely corresponds to bulk of magmatic activity. However, there is older and younger late Mesoproterozoic magmatic activity as revealed from reversed polarity sills and younger dates in northern Arizona from Mohr et al. 2024. *Previous Nordic compilation relied on 1088 ± 11 Ma U-Pb date (sill ED) from Donadini abstract 2012 with personal communication with Ryan Bright*',
                                        POLE_AUTHORS='Harlan, S. S., Donadini, F., Pesonen, L. J., Korhonen, K., Deutsch, A.',
                                        YEAR='1993, 2011',
                                        JOURNAL='Canadian Journal of Earth Sciences; Geophysica',
                                        VOLUME='30; 47',
                                        VPAGES='1415–1426;3-30',
                                        TITLE='Paleomagnetism of Middle Proterozoic diabase sheets from central Arizona;Paleomagnetism and paleointensity of the 1.1 Ga old diabase sheets from central Arizona',
                                        COMMENT='Calculated from site VGPs in Swanson-Hysell et al. 2026 following Zhang et al. 2024 grouping of sill sites; Non-Fisherian streak of directions along the Keweenawan Track.'
                                        )
Central_Arizona_summary
# Out:
#      Terrane                  ROCKNAME RESULT# COMPONENT  \
# 0  Laurentia  Central Arizona diabases
#
#                                                TESTS TILT  SLAT   SLONG   B  \
# 0  C (positive baked-contact test on sill ED; Don...       33.8  249.53  20
#
#      N  ...  himagage                                         REF/method  \
# 0  141  ...      1110  Central Arizona date of 1097.97 ± 0.12 (0.32) ...
#
#                    ROCKNAME  \
# 0  Central Arizona diabases
#
#                                         POLE AUTHORS        YEAR  \
# 0  Harlan, S. S., Donadini, F., Pesonen, L. J., K...  1993, 2011
#
#                                           JOURNAL  VOLUME          VPAGES  \
# 0  Canadian Journal of Earth Sciences; Geophysica  30; 47  1415–1426;3-30
#
#                                                TITLE  \
# 0  Paleomagnetism of Middle Proterozoic diabase s...
#
#                                              Comment
# ...

# %%
# save the summary dictionary as a single-row CSV in data/nordic_summaries
pt.save_nordic_summary(Central_Arizona_summary, '1098_Central_Arizona_intrusions')
# Out:
# '../data/nordic_summaries/1098_Central_Arizona_intrusions.csv'
