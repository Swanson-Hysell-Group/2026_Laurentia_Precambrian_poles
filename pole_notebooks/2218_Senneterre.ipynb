# %% [markdown]
# # Senneterre ca. 2218 Ma paleomagnetic pole## Geologic Context- Terrane: Laurentia-Superior(East).- Compiled unit/pole label: SENNETERRE.## Paleomagnetic And Rock Magnetic Data- B = 6 sites, N = 1000 samples; mean direction DEC/INC = 358.6°/-43.9°; K = 1000.0.- Field/statistical tests noted in compilation: C+.- Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.## Age Constraints- Current bracket: lomagage 2212.0 Ma, himagage 2224.0 Ma.- Compilation method note: 2216+8/-4, ## References- Paleomagnetic source: Buchan et al. (1993). Northeast-trending Early Proterozoic dykes of southern Superior Province: multiple episodes of emplacement recognized from integrated paleomagnetism and U-Pb geochronology. Can. J. Earth Sci., 30, 1286-1296.- Geochronology / age-constraint note (compilation): 2216+8/-4,

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('SENNETERRE',Laurentia_poles)
# Out:
# N = 1000 (N ≥ 25; sufficient sample number);
# B = 6 (B < 8; insufficient site number);
# K = 1000 (K ≥ 70; concern about underrepresenting PSV);
# A_95 of 6.0 passes Deenen et al. (2011) criteria of being between 5.9 and 26.5 for this number of sites

# %%
plot_pole_overlap('SENNETERRE',Laurentia_poles,Torsvik2012_Laurentia)
