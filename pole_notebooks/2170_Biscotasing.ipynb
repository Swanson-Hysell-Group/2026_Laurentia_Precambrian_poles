# %% [markdown]
# # Biscotasing ca. 2170 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Superior(East).
# - Compiled unit/pole label: BISCOTASING.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 12 sites, N = 1000 samples; mean direction DEC/INC = 263.9°/60.4°; K = 1000.0.
# - Field/statistical tests noted in compilation: C+.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: nominal age 2170 Ma, lomagage 2166.0 Ma, himagage 2171.0 Ma.
# - Compilation method note: 2166-2171, dates are reported in Halls, H.C., Stott, G.M., Davis, D.W., 2005. Paleomagnetism, geochronology and geochemistry of several Proterozoic mafic dike swarms in north-
# western Ontario. Ontario Geological Survey, Open File Report 6171, 59 p.; summarized in Halls et al. 2008
#
# ## References
#
# - Paleomagnetic source: Evans,D.A.D., Halls,H.C. (2010). Restoring Proterozoic deformation within the Superior craton. Precambrian Res., 183, 474-489.
# - Geochronology / age-constraint note (compilation): 2167-2172, range of ages summarized in Halls et al. 2008; Halls, H.C., Stott, G.M., Davis, D.W., 2005. Paleomagnetism, geochronology and geochemistry of several Proterozoic mafic dike swarms in north-
# western Ontario. Ontario Geological Survey, Open File Report 6171, 59 p.

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('BISCOTASING',Laurentia_poles)
# Out:
# N = 1000 (N ≥ 25; sufficient sample number);
# B = 12 (B ≥ 8; sufficient site number);
# K = 1000 (K ≥ 70; concern about underrepresenting PSV);
# A_95 of 7.0 passes Deenen et al. (2011) criteria of being between 4.4 and 17.1 for this number of sites

# %%
plot_pole_overlap('BISCOTASING',Laurentia_poles,Torsvik2012_Laurentia)
