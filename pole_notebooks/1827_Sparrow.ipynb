# %% [markdown]
# # Sparrow ca. 1827 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Rae.
# - Compiled unit/pole label: Sparrow Dykes.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 10 sites, N = 54 samples; mean direction DEC/INC = 131.0°/51.0°; K = 50.0.
# - Field/statistical tests noted in compilation: Co,Ro.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: lomagage 1823.0 Ma, himagage 1831.0 Ma.
# - Compilation method note: 1827±4 U-Pb TIMS baddeleyite fractions concordia upper intercept age from Bostock and Breemen, 1992.
#
# ## References
#
# - Paleomagnetic source: McGlynn,J.C., Hanson,G.N., Irving,E., Park,J.K. (1974). Paleomagnetism and age of Nonacho Group Sandstones and associated Sparrow dikes, District of Mackenzie. Canad.J.Earth Sci., 11, 30-42.
# - Geochronology / age-constraint note (compilation): Bostock, H. H., & Breemen, O. V. (1992). The timing of emplacement, and distribution of the Sparrow diabase dyke swarm, District of Mackenzie, Northwest Territories. Natural Resources Canada/CMSS/Information Management. https://doi.org/10.4095/134164

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Sparrow Dykes',Laurentia_poles)
# Out:
# N = 54 (N ≥ 25; sufficient sample number);
# B = 10 (B ≥ 8; sufficient site number);
# K = 50 (70 ≥ K ≥ 10; meets PSV criteria);
# A_95 of 7.9 passes Deenen et al. (2011) criteria of being between 4.8 and 19.2 for this number of sites

# %%
McGlynn1974_sites_geo, McGlynn1974_sites_tc = load_magic_sites('../data/1827_Sparrow/sites.txt')
McGlynn1974_data = McGlynn1974_sites_tc if not McGlynn1974_sites_tc.empty else McGlynn1974_sites_geo
McGlynn1974_data = McGlynn1974_data.rename(columns={'dir_dec': 'dec', 'dir_inc': 'inc'}).reset_index(drop=True)
ipmag.reversal_test_MM1990(McGlynn1974_data.dec.tolist(), McGlynn1974_data.inc.tolist())
# Out:
# Results of Watson V test:
#
# Watson's V:           4.9
# Critical value of V:  12.6
# "Pass": Since V is less than Vcrit, the null hypothesis
# that the two populations are drawn from distributions
# that share a common mean direction can not be rejected.
#
# M&M1990 classification:
#
# Angle between data set means: 21.2
# Critical angle for M&M1990:   34.4
# The McFadden and McElhinny (1990) classification for
# this test is: 'INDETERMINATE;
# (1, 21.224875716639247, 34.37536597735426, 'indeterminate')

# %%
plot_pole_overlap('Sparrow Dykes',Laurentia_poles,Torsvik2012_Laurentia)
