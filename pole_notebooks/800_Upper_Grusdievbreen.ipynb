# %% [markdown]
# # Upper Grusdievbreen ca. 800 Ma paleomagnetic pole## Geologic Context- Terrane: Laurentia-Svalbard.- Compiled unit/pole label: Upper Grusdievbreen Formation.## Paleomagnetic And Rock Magnetic Data- B = 5 sites, N = 107 samples; mean direction DEC/INC = 126.3°/14.7°; K = 84.2.- Field/statistical tests noted in compilation: Fo.- Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.## Age Constraints- Current bracket: lomagage 789.0 Ma, himagage 811.0 Ma.- Compilation method note: 789-811, authors## References- Paleomagnetic source: Maloof,A.C., Halverson,G.P., Kirschvink,J.L., Schrag,D.P., Weiss,B.P., Hoffman,P.F. (2006). Combined paleomagnetic, isotopic, and stratigraphic evidence for true polar wander from the Neoproterozoic Akademikerbreen Group, Svalbard, Norway. Geol.Soc.Am.Bulletin, 118, 1099-1124.- Geochronology / age-constraint note (compilation): 789-811, authors

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Upper Grusdievbreen Formation',Laurentia_poles)
# Out:
# N = 107 (N ≥ 25; sufficient sample number);
# B = 5 (B < 8; insufficient site number);
# K = 84 (K ≥ 70; concern about underrepresenting PSV);
# A_95 of 6.2 is too small for Deenen criteria of 6.3 for this number of sites

# %%
plot_pole_overlap('Upper Grusdievbreen Formation',Laurentia_poles,Torsvik2012_Laurentia)
