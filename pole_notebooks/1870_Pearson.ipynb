# %% [markdown]
# # MEAN Pearson A/Peninsular sill/Kilohigok basin sill ca. 1870 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Slave.
# - Compiled unit/pole label: MEAN Pearson A/Peninsular sill/Kilohigok basin sill.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 22 sites, N = 1000 samples; mean direction DEC/INC = 162.4°/3.5°; K = 1000.0.
# - Field/statistical tests noted in compilation: C+.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: nominal age 1870.0 Ma, lomagage 1866.0 Ma, himagage 1874.0 Ma.
# - Compilation method note: U-Pb on Kilohigok (Mara River) sill; Peninsular Sill, Hulbert (2005) reported an age of 1870 Ma for one of the sills, Davis and Bleeker, 2007 had a GAC abstract reporting an age of 1870 Ma.
#
# ## References
#
# - Paleomagnetic source: Mitchell,R.N., Hoffman,P.F., Evans,D.A.D. (2010). Coronation loop resurrected: Oscillatory apparent polar wander of Orosirian (2.05–1.8 Ga) paleomagnetic poles from Slave craton. Precambrian Res., 179, 121-134.
# - Geochronology / age-constraint note (compilation): U-Pb on Kilohigok (Mara River) sill; Peninsular Sill, Davis, W.J., Bleeker, W., 2007. New ages for Paleoproterozoic mafic intrusions in the western Slave Province and their potential relationship to tectonic events in the adjacent Wopmay orogen. Geological Association of Canada, Programs with Abstracts 32, 20.

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('MEAN Pearson A/Peninsular sill/Kilohigok basin sill',Laurentia_poles)
# Out:
# N = 1000 (N ≥ 25; sufficient sample number);
# B = 22 (B ≥ 8; sufficient site number);
# K = 1000 (K ≥ 70; concern about underrepresenting PSV);
# A_95 of 6.0 passes Deenen et al. (2011) criteria of being between 3.5 and 11.7 for this number of sites

# %%
plot_pole_overlap('MEAN Pearson A/Peninsular sill/Kilohigok basin sill',Laurentia_poles,Torsvik2012_Laurentia)
