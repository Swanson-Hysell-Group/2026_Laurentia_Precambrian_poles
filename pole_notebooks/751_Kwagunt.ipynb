# %% [markdown]
# ## import python libraries## References- Paleomagnetic source: Eyster, A., Weiss, B.P., Karlstrom, K., Macdonald, F.A. (2020). Paleomagnetism of the Chuar Group and evaluation of the late Tonian Laurentian apparent polar wander path with implications for the makeup and breakup of Rodinia. Geol.Soc.Amer.Bull., 132, 710-738.- Geochronology / age-constraint note (compilation): Re-Os age: 751.0+/-7.6 Ma; older than U-Pb: 729.0+/-0.9 Ma; see REFNO 4153

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %% [markdown]
# ## Kwagunt Formation
#
# This pole is from the lower Kwagunt Formation with data from the Carbon Butte and basal Awatubi members. Paleomagnetic data from Weil et al. 2004 and Eyster et al. 2019
#
# - R1: 1, 751.0 ± 7.6 Ma Re-Os date from Rooney et al., 2017 that is in stratigraphic proximity to the paleomagnetism samples
# - R2: 1, see below
# - R3: 1, rock magnetism experiments and extended discussion
# - R4: 1, (f) positive fold test
# - R5: 1, Colorado Plateau rotation could be considered to modify, but is minor and uncertain
# - R6: 1, Rc
# - R7: 0, overlaps with early Ordovician Laurentia poles

# %%
R2_test('Kwagunt Formation',Laurentia_poles)
# Out:
# N = 71 (N ≥ 25; sufficient sample number);
# B = 23 (B ≥ 8; sufficient site number);
# K = 43 (70 ≥ K ≥ 10; meets PSV criteria);
# A_95 of 3.5 passes Deenen et al. (2011) criteria of being between 3.4 and 11.4 for this number of sites

# %%
plot_pole_overlap('Kwagunt Formation',Laurentia_stricto_poles,Torsvik2012_Laurentia)
