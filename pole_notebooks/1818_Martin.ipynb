# %% [markdown]
# # Martin ca. 1818 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Rae.
# - Compiled unit/pole label: Martin Formation.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 15 sites, N = 56 samples; mean direction DEC/INC = 322.5°/-29.4°; K = 15.0.
# - Field/statistical tests noted in compilation: F+,Ro.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: lomagage 1814.0 Ma, himagage 1822.0 Ma.
# - Compilation method note: 1818±4 Ma, A U–Pb baddeleyite date from one dike broadly dates this magmatic event at ca. 1818±4 Ma (Morelli et al., 2009a)
#
# ## References
#
# - Paleomagnetic source: Evans,M.E., Bingham,D.K. (1973). Paleomagnetism of the Precambrian Martin Formation, Saskatchewan. Canad.J.Earth Sci., 10, 1485-1493.
# - Geochronology / age-constraint note (compilation): 1818±4 Ma, A U–Pb baddeleyite date from one dike broadly dates this magmatic event at ca. 1818±4 Ma; Morelli, R. M., Hartlaub, R. P., Ashton, K. E., & Ansdell, K. M. (2009). Evidence for enrichment of subcontinental lithospheric mantle from Paleoproterozoic intracratonic magmas: Geochemistry and U–Pb geochronology of Martin Group igneous rocks, western Rae Craton, Canada. Precambrian Research, 175(1–4), 1–15. https://doi.org/10.1016/j.precamres.2009.04.005

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Martin Formation',Laurentia_poles)
# Out:
# N = 56 (N ≥ 25; sufficient sample number);
# B = 15 (B ≥ 8; sufficient site number);
# K = 15 (70 ≥ K ≥ 10; meets PSV criteria);
# A_95 of 8.5 passes Deenen et al. (2011) criteria of being between 4.1 and 14.9 for this number of sites

# %%
plot_pole_overlap('Martin Formation',Laurentia_poles,Torsvik2012_Laurentia)
