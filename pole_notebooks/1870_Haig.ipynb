# %% [markdown]
# # Haig ca. 1870 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Superior.
# - Compiled unit/pole label: MEAN Haig/Flaherty/Sutton.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 27 sites, N = 100 samples; mean direction DEC/INC = 38.7°/-47.8°; K = 1000.0.
# - Component note: site-weighted VGP means from 3 results.
# - Field/statistical tests noted in compilation: C+,F+,Rc.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: nominal age 1870.0 Ma, lomagage 1869.0 Ma, himagage 1871.0 Ma.
# - Proposed new bracket: nominal age 1870 Ma, lomagage 1867.0 Ma, himagage 1873.0 Ma.
# - Compilation method note: 1870±3 reported in an unpublished GAC abstract by Hamilton et al., 2009.
#
# ## References
#
# - Paleomagnetic source: LULEÅ WORKING GROUP MEAN (2009).
# - Geochronology / age-constraint note (compilation): Hamilton, M., Buchan, K. L., Ernst, R. E., & Stott, G. M. (2009, May). Widespread and short-lived 1870 Ma mafic magmatism along the northern Superior craton margin. In American Geophysical Union-Geological Association of Canada, Joint Meeting (abstract# GA11A-01).

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('MEAN Haig/Flaherty/Sutton',Laurentia_poles)
# Out:
# N = 100 (N ≥ 25; sufficient sample number);
# B = 27 (B ≥ 8; sufficient site number);
# K = 1000 (K ≥ 70; concern about underrepresenting PSV);
# A_95 of 3.9 passes Deenen et al. (2011) criteria of being between 3.2 and 10.3 for this number of sites

# %%
plot_pole_overlap('MEAN Haig/Flaherty/Sutton',Laurentia_poles,Torsvik2012_Laurentia)
