# %% [markdown]
# # Purcell Lava ca. 1427 Ma paleomagnetic pole

# %% [markdown]
# ## Geologic Context

# %% [markdown]
# The Mesoproterozoic Belt-Purcell Supergroup, located in Montana and Idaho, USA and Alberta and British Columbia, Canada spans an enormous extent covering > 200,000 km<sup>2</sup> (Lonn et al. 2020).  It is a predominantly sedimentary succession over > 15 km thick in places, which has been subdivided into four groups. The Purcell Lava intrudes between the Shepard and Snowslip Formations, which are part of the Missoula Group (Lonn et al. 2020).  The Belt-Purcell Supergroup was an early place of paleomagnetic analyses in the 1950s and 1960s, but the majority of subsequent paleomagnetic analyses were the product of years of work by Don Elston of the United States Geologic Survey and colleagues, which were published in Elston et al. (2002).
#
# The Purcell Lava consists predominaly of alkalic basalts and extends in patches across northern Montana from near Libby, Montana (west), where it reaches a maximum of 385 m thick, to thinner exposures in Glacier National Park (east). In Canada, it is correlated to the Nicol Creek Formation and ranges in thickness from a few tens of meters to 750 m thick, spreading across East Kooteney, British Columbia, to Prairie Bluff, Alberta (McMechan 1981, Constenius et al. accepted).  All areas of the Purcell Lava consist of basal pillow basalts (subaqueous) overlain by pahoehoe flows (interpreted subaerial). Central and western exposures have distinct porphyritic flows with large feldspar crystals.  West of the Whitefish-Galton Range, the Purcell Lava consists of two sets of flow assemblages separated by a middle section of argillite, siltite, and sandstone (McMechan 1981, Constenius et al. accepted).  It is interpreted that the eastern exposures represent the lower Purcell Lava only.

# %% [markdown]
# ## Paleomagnetic and Rock Magnetic Data

# %% [markdown]
# Elston et al. (2002) reports 12 paleomagnetic sites of the Purcell Lava and Nicol Creek Formation.  Descriptions in the text suggest that Elston's sites might include more than one flow unit (samples separated by 40 m). Two of the sites noted above are from preexisting literature but reported by Elston.  Evans et al. (1975) is included as a locality mean of three sites; this study sampled a 50 m section with sites evenly spaced ~20 m apart and notes that the uppermost site was highly vesiculated, suggesting it was near a flow top.  There were no geologic indicators that the section represented more than one flow; however, we have included these sites below to probe whether the data are distinct or share a common mean, since these site means were published in the original manuscript. Another site from the literature (Black 1963) is reported but not included in the formation mean, as it used outdated lab protocols such as blanket low-field AF demagnetization.
#
# No separate rock magnetic analyses were done; however, reddened flow tops and microscopically observed hematite pigment on the subaerial flows suggest hematization by exposure to the atmosphere during and shortly after cooling (R. A. Burwash, pers. comm. 1974, reported in Evans et al. 1975).  Stepwise thermal demagnetization experiments were interpreted to indicate the main carrier is hematite. Examination of the Zijdervelds shows continual progressive demagnetization with larger losses between 200 - 400 ºC (pyrrhotite?) and 600-675 ºC (especially 650-675 ºC), suggesting the presence of hematite, potentially including both fine-grained (pigmentary) hematite and coarser grained specularite. Magnetite and pyrrhotite-bearing remanences were also noted, including in samples bearing hematite; the displayed Zijderveld shows an example with large losses by 300 ºC and near-complete demagnetization by 600 ºC. Sampled pillow basalts were interpreted to lack hematite and retained unreliable paleomagnetic records.
#
# Elston et al. (2002) used distinct treatments depending on the measurement lab. The USGS subjected pilot samples to stepwise demagnetization in 8 steps, but then demagnetized the remaining samples in blanket demagnetization steps--two sites were treated this way with a single step of 550 ºC. The Geologic Survey of Canada subjected samples to stepwise demagnetization in 8-15 steps, and directions were calculated using PCA. It appears only thermal demagnetization was used, due to the known presence of hematite, but it is not clearly reported.  Evans et al. (1975) performed stepwise demagnetization with one sample per site using AF and one using thermal.  However, the analyses were all performed based on vectors to endpoints from a single step that was chosen to maximize clustering.
#
# Of the 12 paleomagnetic sites, three sites (Blacktail Creek, Rexford, Teepee Creek) were separated into normal and reversed directions (following Elston's nomenclature) to provide distinct site means.  All of these normal directions were excluded from the formation mean due to "contamination" or "overprinting", as the directions were not antipodal, although no formal statistical reversal test was reported.  The study also noted that these directions had steeper inclinations and were thus grouped with two other sites with steep inclinations (Sage Creek and South Lost Creek).  These sites were also separated into two groups, with the group with steeper directions being excluded due to complete or partial overprint. The interpreted overprinted directions were usually in samples that had unblocking temperatures < 600 ºC, whereas the accepted samples had main remanence carried at > 650 ºC. One final site (Bull River) was excluded due to apparent rotation, based on the paleomagnetic data.
#
# Elston et al. (2002) provided a formation mean and VGP for the interpreted primary direction.  It passed a fold test using 100 ± 4 % untilting as the optimum, following Watson and Enkin (1993).  The study also provided a formation mean and VGP for the steeper inclination directions from 5 sites, interpreted as an overprint.  This direction had optimum untilting at 82 ± 10 % using Watson and Enkin (1993), suggesting it does not pass a fold test.

# %% [markdown]
# ## Geochronology constraints

# %% [markdown]
# Evans et al. (2000) dated a restricted "porphyritic rhyolite to quartz latite flow" from the lower part of the upper Purcell lava flows outcropping on Robinson Mountain near Libby, Montana, USA; using SHRIMP U–Pb zircon dating, the study got an age of 1443 ± 7 Ma.
#
# Constenius et al. (accepted) revisited the same location and reinterpreted it as a peperite. Based on detrital zircon U-Pb dating, they suggest the prior age is not a maximum depositional age.  Using LA-ICP-MS U-Pb zircon dating on the youngest population, the study reports an age of 1419.9 ± 8.4 Ma.  They also did ID-TIMS U-Pb dating on baddeleyite from the lower Purcell and report an age of 1438.9 ± 3.2 Ma.  Dating of instrusive sills using the alternative dating techniques corroborate magmatism at these ages in the Belt-Purcell Supergroup.
#
# Overall, due to the lack of documentation on which flow units were sampled for paleomagnetism, we choose to use these recent ages as the mimumum and maximum constraints (with error 1412-1442 Ma), as this range also incorporates the older age.  The nominal age is the middle at 1427 Ma.

# %% [markdown]
# ## References

# %% [markdown]
# Black, R.F., 1963, Palaeomagnetism of part of the Purcell System in southwestern Alberta and southeastern British Columbia: Geological Survey of Canada Bulletin 83, p. 1–31.
#
# Constenius, K.N., McGimsey, R.G., Valencia, V.A., Domanik, K.J., Chamberlain, K.R., Crowley, J., Hirtz, J.A.M., and Horton, B.K. (accepted). Stratigraphy of the Purcell Lava and revised geochronology of the Missoula Group:  Implications for unconformities and magmatic episodes in the Mesoproterozoic Belt Basin.  Geological Society of America Special Volume.
#
# Elston, D. P., Enkin, R. J., Baker, J., and Kisilevsky, D. K. (2002). Tightening the Belt: Paleomagnetic-stratigraphic constraints on deposition, correlation, and deformation of the Middle Proterozoic (ca. 1.4 Ga) Belt-Purcell Supergroup, United States and Canada. Geological Society of America Bulletin, 114(5), 619-638. DOI: 10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
#
# Evans, K.V., Aleinikoff , J.N., Obradovich, J.D., and Fanning, C.M., 2000, SHRIMP U-Pb geochronology
# of volcanic rocks, Belt Supergroup, western Montana: Evidence for rapid deposition of sedimentary strata: Canadian Journal of Earth Sciences, v. 37, p. 1287–1300, DOI: 10.1139/cjes-37-9-1287
#
# Evans, M.E., Bingham, D.K., and McMurry, E.W., 1975. New paleomagnetic results from the upper Belt-Purcell
# Supergroup of Alberta: Canadian Journal of Earth Sciences, v. 12, p. 52–61.
#
# Lonn, J. D., Burmester, R. F., Lewis, R. S., McFaddan, M. D., Metesh, J. J., & Vuke, S. M. (2020). The Mesoproterozoic Belt Supergroup. in Barth, S., ed., Geology of Montana: Montana Bureau of Mines and Geology Special Publication 122, 1, 1-38.
#
# McMechan, M.E., 1981, The Middle Proterozoic Purcell Supergroup in the southwestern Rocky and southeastern Purcell Mountains, British Columbia, and the initiation of the Cordilleran miogeocline, southern Canada and adjacent United States: Bulletin of Canadian Petroleum Geology, v. 29, p. 583– 621.

# %% [markdown]
# # Calculations

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import pmagpy.pmag as pmag
import pmagpy.ipmag as ipmag
import matplotlib.pyplot as plt

# %matplotlib inline
import matplotlib_inline

import pole_tools as pt

# %% [markdown]
# # Read in sites

# %%
sites_df = pd.read_csv('../data/1427_Purcell_Lava/sites.txt', sep='\t',header=1)

# %%
sites_df.head()
# Out:
#     age  age_high  age_low  age_sigma age_unit  \
# 0  1427      1442     1412        NaN       Ma
# 1  1427      1442     1412        NaN       Ma
# 2  1427      1442     1412        NaN       Ma
# 3  1427      1442     1412        NaN       Ma
# 4  1427      1442     1412        NaN       Ma
#
#                                          citations              description  \
# 0  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2  Excluded (contaminated)
# 1  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2  Excluded (contaminated)
# 2  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2                      NaN
# 3  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2                      NaN
# 4  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2  Excluded (contaminated)
#
#    dir_alpha95  dir_dec  dir_inc  dir_k  dir_n_samples  dir_tilt_correction  \
# 0         12.0    223.6     58.5   26.1              7                    0
# ...

# %% [markdown]
# # Add VGPs

# %% [markdown]
# Elston et al. (2002) only reported VGPs for location so here we calculate the site VGPs as well.

# %%
sites_df['vgp_lon'], sites_df['vgp_lat'], sites_df['vgp_dp'], sites_df['vgp_dm'] = pmag.dia_vgp(sites_df['dir_dec'], sites_df['dir_inc'], sites_df['dir_alpha95'], sites_df['lat'], sites_df['lon'])

# %%
sites_df.head()
# Out:
#     age  age_high  age_low  age_sigma age_unit  \
# 0  1427      1442     1412        NaN       Ma
# 1  1427      1442     1412        NaN       Ma
# 2  1427      1442     1412        NaN       Ma
# 3  1427      1442     1412        NaN       Ma
# 4  1427      1442     1412        NaN       Ma
#
#                                          citations              description  \
# 0  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2  Excluded (contaminated)
# 1  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2  Excluded (contaminated)
# 2  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2                      NaN
# 3  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2                      NaN
# 4  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2  Excluded (contaminated)
#
#    dir_alpha95  dir_dec  dir_inc  dir_k  dir_n_samples  dir_tilt_correction  \
# 0         12.0    223.6     58.5   26.1              7                    0
# ...

# %%
# pmag.magic_write('../data/1427_Purcell_Lava/sites.txt', sites_df, 'sites', dataframe=True)

# %% [markdown]
# # Site location map

# %%
pt.plot_site_map(sites_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# # Evans site-level data

# %% [markdown]
# Here we try using the site-level data from Evans et al. (1975) instead of the locality mean reported by Elston.
#
# Evans et al. (1975) reported tilt-corrected directions and the strike and dip of bedding, but not geographic directions or α95s. We calculated α95s using k and N, and geographic directions using the tilt-corrected directions and bedding strikes and dips. We will also calculate VGPs in this notebook.

# %% [markdown]
# ## Import data

# %%
sites_evans_df = pd.read_csv('../data/1427_Purcell_Lava/sites_Evans.txt', sep='\t',header=1)

# %%
sites_evans_df.head()
# Out:
#     age  age_high  age_low  age_sigma age_unit  \
# 0  1427      1442     1412        NaN       Ma
# 1  1427      1442     1412        NaN       Ma
# 2  1427      1442     1412        NaN       Ma
# 3  1427      1442     1412        NaN       Ma
# 4  1427      1442     1412        NaN       Ma
#
#                                          citations              description  \
# 0  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2  Excluded (contaminated)
# 1  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2  Excluded (contaminated)
# 2  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2                      NaN
# 3  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2                      NaN
# 4  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2  Excluded (contaminated)
#
#    dir_alpha95  dir_dec  dir_inc  dir_k  dir_n_samples  dir_tilt_correction  \
# 0         12.0    223.6     58.5   26.1              7                    0
# ...

# %% [markdown]
# ## Add VGPs

# %%
sites_evans_df['vgp_lon'], sites_evans_df['vgp_lat'], sites_evans_df['vgp_dp'], sites_evans_df['vgp_dm'] = pmag.dia_vgp(sites_evans_df['dir_dec'], sites_evans_df['dir_inc'], sites_evans_df['dir_alpha95'], sites_evans_df['lat'], sites_evans_df['lon'])

# %%
pmag.magic_write('../data/1427_Purcell_Lava/sites_Evans.txt', sites_evans_df, 'sites', dataframe=True)
# Out:
# 37  records written to file  ../data/1427_Purcell_Lava/sites_Evans.txt
# (True, '../data/1427_Purcell_Lava/sites_Evans.txt')

# %% [markdown]
# ## Plot

# %%
sites_evans_tilt = sites_evans_df[sites_evans_df['dir_tilt_correction'] == 100]

plt.figure(figsize = (4,4))
ipmag.plot_net()

for row, site in sites_evans_tilt.iterrows():
    if site['citations'] == '10.1139/e75-006':
        col = 'orange'
    elif site['result_quality'] == 'g':
        col = 'b'
    elif site['result_quality'] == 'b':
        col = 'r'
    ipmag.plot_di_mean(dec=site['dir_dec'],
                       inc=site['dir_inc'],
                       a95=site['dir_alpha95'],
                       color=col)

# %% [markdown]
# ## Quickly check if it changes pole

# %%
di_block_evans = ipmag.make_di_block(sites_evans_tilt['vgp_lon'].tolist(), sites_evans_tilt['vgp_lat'].tolist())
di_block_evans_flipped = pmag.flip(di_block_evans, combine=True)
decs_evans_flipped = [row[0] for row in di_block_evans_flipped]
incs_evans_flipped = [row[1] for row in di_block_evans_flipped]

pole_evans = ipmag.fisher_mean(dec=decs_evans_flipped, inc=incs_evans_flipped)
pole_evans
# Out:
# {'dec': 32.822149558886984,
#  'inc': 14.952103222168367,
#  'n': 19,
#  'r': 17.887582500676604,
#  'k': 16.180975228228714,
#  'alpha95': 8.60676167892583,
#  'csd': 20.136439072074726}

# %% [markdown]
# Compare with pole from all sites mentioned by Elston (including the sites he excluded):
#
# {'dec': 32.603643301826246,
#
#  'inc': 13.823605860255755,
#
#  'n': 17,
#
#  'r': 15.922581912259043,
#
#  'k': 14.850316865895113,
#
#  'alpha95': 9.575594628377713,
#
#  'csd': 21.01924724161825}

# %% [markdown]
# This does not make a significant difference. We will go with the original site list reported by Elston, which includes the Evans data as a locality mean. This is in accordance with the recommendation of Evans et al. (1975), who suggest that their sites likely encompass only one flow and are therefore best treated as a single unit.

# %% [markdown]
# # Plot

# %%
sites_geo = sites_df[sites_df['dir_tilt_correction'] == 0]
sites_tilt = sites_df[sites_df['dir_tilt_correction'] == 100]

plt.figure(figsize = (4,4))
ipmag.plot_net()

for row, site in sites_tilt.iterrows():
    if site['result_quality'] == 'g':
        col = 'b'
    elif site['result_quality'] == 'b':
        col = 'r'
    ipmag.plot_di_mean(dec=site['dir_dec'],
                       inc=site['dir_inc'],
                       a95=site['dir_alpha95'],
                       color=col)

# %% [markdown]
# The red sites were excluded from the formation pole by the original authors due to overprinting, age of study, or rotation (see above). The blue sites were included by Elston, including the locality mean of individual sites from Evans et al. (1975).
#
# We also plotted to show the two "groupings" proposed by Elston et al. (2002) below. The blue sites are the "primary" magnetizations, while the red sites are interpreted as overprinted. The black site is rotated.

# %%
plt.figure(figsize = (4,4))
ipmag.plot_net()

for row, site in sites_tilt.iterrows():
    if site['dir_inc'] > 0:
        # flipped = pmag.flip([[site['dir_dec'], site['dir_inc']]], combine=True)
        dec = site['dir_dec'] - 180
        inc = -site['dir_inc']
        col = 'r'
    elif site['dir_dec'] > 80:
        dec = site['dir_dec']
        inc = site['dir_inc']
        col = 'k'
    elif site['dir_inc'] < -50:
        dec = site['dir_dec']
        inc = site['dir_inc']
        col = 'r'
    else:
        dec = site['dir_dec']
        inc = site['dir_inc']
        col = 'b'
    
    ipmag.plot_di_mean(dec=dec,
                       inc=inc,
                       a95=site['dir_alpha95'],
                       color=col)

# %% [markdown]
# Notably, the five exlcuded overprinted sites were separated from sites that were included based on polarity; in including them, we have therefore potentially double-counted several sites although it is quite plausible they represent distinct flow units, etc.

# %% [markdown]
# # Recalculate pole based on VGPs

# %% [markdown]
# We have recalculated the pole of Elston using individual site VGPs.   We additionally have recalculated the pole for all sites and for just including the interpreted overprinted sites; we did not include the Black (1963) site or the rotated sites.

# %%
# Elston's subset
sites_subset = sites_tilt[sites_tilt['result_quality'] == 'g']
di_block_subset = ipmag.make_di_block(sites_subset['vgp_lon'].tolist(), sites_subset['vgp_lat'].tolist())
di_block_subset_flipped = pmag.flip(di_block_subset, combine=True)
decs_subset_flipped = [row[0] for row in di_block_subset_flipped]
incs_subset_flipped = [row[1] for row in di_block_subset_flipped]

pole_subset = ipmag.fisher_mean(dec=decs_subset_flipped, inc=incs_subset_flipped)

map_axis = ipmag.make_orthographic_map(200, 0, figsize=(5,5))

ipmag.plot_pole(map_axis, plon=pole_subset['dec']+180, 
                   plat=-pole_subset['inc'], 
                   A95=pole_subset['alpha95'], 
                   color = 'blue', marker='s', label='Elston+ pole (hematite)')


# All
di_block_all = ipmag.make_di_block(sites_tilt['vgp_lon'].tolist(), sites_tilt['vgp_lat'].tolist())
di_block_all_flipped = pmag.flip(di_block_all, combine=True)
decs_all_flipped = [row[0] for row in di_block_all_flipped]
incs_all_flipped = [row[1] for row in di_block_all_flipped]

pole_all = ipmag.fisher_mean(dec=decs_all_flipped, inc=incs_all_flipped)

ipmag.plot_pole(map_axis, plon=pole_all['dec']+180, 
                   plat=-pole_all['inc'], 
                   A95=pole_all['alpha95'], 
                   color = 'red', marker='s', label='All sites')


# Only overprint
sites_overprint = sites_tilt[abs(sites_tilt['dir_inc']) > 45]

di_block_overprint = ipmag.make_di_block(sites_overprint['vgp_lon'].tolist(), 
                                                  sites_overprint['vgp_lat'].tolist())
di_block_overprint_flipped = pmag.flip(di_block_overprint, combine=True)
decs_overprint_flipped = [row[0] for row in di_block_overprint_flipped]
incs_overprint_flipped = [row[1] for row in di_block_overprint_flipped]

pole_overprint= ipmag.fisher_mean(dec=decs_overprint_flipped, 
                                            inc=incs_overprint_flipped)

ipmag.plot_pole(map_axis, plon=pole_overprint['dec'], 
                   plat=pole_overprint['inc'], 
                   A95=pole_overprint['alpha95'], 
                   color = 'hotpink', marker='s', label='Elston+ excluded (mag + pyr)')

# Elston subset + overprinted
sites_subset_overprinted = sites_tilt[(sites_tilt['citations'] != '10.4095/100602') & 
                                      (sites_tilt['site'] != 'Bull River')]

di_block_subset_overprinted = ipmag.make_di_block(sites_subset_overprinted['vgp_lon'].tolist(), 
                                                  sites_subset_overprinted['vgp_lat'].tolist())
di_block_subset_overprinted_flipped = pmag.flip(di_block_subset_overprinted, combine=True)
decs_subset_overprinted_flipped = [row[0] for row in di_block_subset_overprinted_flipped]
incs_subset_overprinted_flipped = [row[1] for row in di_block_subset_overprinted_flipped]

pole_subset_overprinted = ipmag.fisher_mean(dec=decs_subset_overprinted_flipped, 
                                            inc=incs_subset_overprinted_flipped)

ipmag.plot_pole(map_axis, plon=pole_subset_overprinted['dec']+180, 
                   plat=-pole_subset_overprinted['inc'], 
                   A95=pole_subset_overprinted['alpha95'], 
                   color = 'green', marker='s', label='All except rotated & 1960s')

plt.legend(loc='best')

# %%
pole_subset_overprinted
# Out:
# {'dec': 35.54656626847584,
#  'inc': 13.598613522224403,
#  'n': 15,
#  'r': 14.382575565878339,
#  'k': 22.674839585699576,
#  'alpha95': 8.207613173685454,
#  'csd': 17.010336589162105}

# %% [markdown]
# The above shows the difference in pole between using Elston's subset (blue), all sites (red), subset including overprinted (green) but not the rotated site or 1960s site. The calculated pole using only Elston's interpreted overprint is also shown in pink. In order to remain agnostic about the mineralogical determinations, we propose using the green pole.

# %% [markdown]
# ## Site Mean Direction Calculations

# %%
dir_block, dir_mean = pt.compute_mean_direction(sites_subset_overprinted, unify_polarity=True, flip=True)
ipmag.print_direction_mean(dir_mean)

ipmag.plot_net()
ipmag.plot_di(di_block=dir_block, color='blue', marker='o')
ipmag.plot_di_mean(dir_mean['dec'], dir_mean['inc'], dir_mean['alpha95'], 
                   color='red', marker='s')
ipmag.plt.title('Mean Site Directions (as measured at sites)')
ipmag.plt.show()
# Out:
# Dec: 30.4  Inc: -36.2
# Number of directions in mean (n): 15
# Angular radius of 95% confidence (a_95): 9.3
# Precision parameter (k) estimate: 17.9

# %%
centroid1 = np.mean(sites_subset_overprinted['lat'], axis=0)
centroid2 = np.mean(sites_subset_overprinted['lon'], axis=0)
print(f"Centroid Latitude: {centroid1:.6f}, Longitude: {centroid2:.6f}")
# Out:
# Centroid Latitude: 49.250667, Longitude: 245.066667

# %% [markdown]
# We will unite to the 49.25ºN, -114.93ºE (a rough centroid of the sites.)

# %%
study_lat = 49.25
study_lon = -114.93

# %% [markdown]
# # Get bedding from tilt correction to do fold test

# %% [markdown]
# Elston et al. (2002) reported bedding directions for each site; however, we have calculated these directions based on the reported data to perform a fold test.

# %%
# Find sites that have both geographic and tilt-corrected coordinates

sites_geolist = []
for site in sites_geo['site']:
    if sites_tilt['site'].str.contains(site).any():
        sites_geolist.append(site)

decs_fold = []
incs_fold = []        
dip_dirs = []
dips = []
for site in sites_geolist:
    dec_geo = float(sites_geo[sites_geo['site'] == site]['dir_dec'])
    inc_geo = float(sites_geo[sites_geo['site'] == site]['dir_inc'])
    dec_tilt = float(sites_tilt[sites_tilt['site'] == site]['dir_dec'])
    inc_tilt = float(sites_tilt[sites_tilt['site'] == site]['dir_inc'])
    dip_dir, dip = pmag.get_tilt(dec_geo, inc_geo, dec_tilt, inc_tilt)
    decs_fold.append(dec_geo)
    incs_fold.append(inc_geo)
    dip_dirs.append(dip_dir)
    dips.append(dip)
    
diddd = ipmag.make_diddd_array(decs_fold, incs_fold, dip_dirs, dips)

ipmag.bootstrap_fold_test(diddd)
# Out:
# doing  1000  iterations...please be patient.....
#
# tightest grouping of vectors obtained at (95% confidence bounds):
# 72 - 119 percent unfolding
# range of all bootstrap samples:
# 51  -  119 percent unfolding

# %% [markdown]
# These data (including sites excluded by Elston) do pass a fold test.

# %% [markdown]
# We have also performed a fold test with only the sites Elston et al. (2002) included in the primary pole.

# %%
# Filter for Elston's subset
sites_subset = sites_tilt[sites_tilt['result_quality'] == 'g']
sites_subset_geo = sites_geo[sites_geo['result_quality'] == 'g']

# Find sites that have both geographic and tilt-corrected coordinates
sites_geolist = []
for site in sites_subset_geo['site']:
    if sites_subset['site'].str.contains(site).any():
        sites_geolist.append(site)

decs_fold = []
incs_fold = []        
dip_dirs = []
dips = []
for site in sites_geolist:
    dec_geo = float(sites_subset_geo[sites_subset_geo['site'] == site]['dir_dec'])
    inc_geo = float(sites_subset_geo[sites_subset_geo['site'] == site]['dir_inc'])
    dec_tilt = float(sites_subset[sites_subset['site'] == site]['dir_dec'])
    inc_tilt = float(sites_subset[sites_subset['site'] == site]['dir_inc'])
    dip_dir, dip = pmag.get_tilt(dec_geo, inc_geo, dec_tilt, inc_tilt)
    decs_fold.append(dec_geo)
    incs_fold.append(inc_geo)
    dip_dirs.append(dip_dir)
    dips.append(dip)
    
diddd = ipmag.make_diddd_array(decs_fold, incs_fold, dip_dirs, dips)

ipmag.bootstrap_fold_test(diddd)
# Out:
# doing  1000  iterations...please be patient.....
#
# tightest grouping of vectors obtained at (95% confidence bounds):
# 83 - 119 percent unfolding
# range of all bootstrap samples:
# 76  -  119 percent unfolding

# %% [markdown]
# These data do pass a fold test.

# %% [markdown]
# We have also performed a fold test with only the sites Elston et al. (2002) included in the overprinted VGP.

# %%
# Filter for steep sites
sites_overprint = sites_tilt[abs(sites_tilt['dir_inc']) > 45]
sites_overprint_geo = sites_geo[sites_geo['site'].isin(sites_overprint['site'])]

# Find sites that have both geographic and tilt-corrected coordinates
sites_geolist = []
for site in sites_overprint_geo['site']:
    if sites_overprint['site'].str.contains(site).any():
        sites_geolist.append(site)

decs_fold = []
incs_fold = []        
dip_dirs = []
dips = []
for site in sites_geolist:
    dec_geo = float(sites_overprint_geo[sites_overprint_geo['site'] == site]['dir_dec'])
    inc_geo = float(sites_overprint_geo[sites_overprint_geo['site'] == site]['dir_inc'])
    dec_tilt = float(sites_overprint[sites_overprint['site'] == site]['dir_dec'])
    inc_tilt = float(sites_overprint[sites_overprint['site'] == site]['dir_inc'])
    dip_dir, dip = pmag.get_tilt(dec_geo, inc_geo, dec_tilt, inc_tilt)
    decs_fold.append(dec_geo)
    incs_fold.append(inc_geo)
    dip_dirs.append(dip_dir)
    dips.append(dip)
    
diddd = ipmag.make_diddd_array(decs_fold, incs_fold, dip_dirs, dips)

ipmag.bootstrap_fold_test(diddd)
# Out:
# doing  1000  iterations...please be patient.....
#
# tightest grouping of vectors obtained at (95% confidence bounds):
# 55 - 112 percent unfolding
# range of all bootstrap samples:
# 6  -  119 percent unfolding

# %% [markdown]
# The steep group passes a fold test.

# %% [markdown]
# # Reversal test

# %%
decs_reversal = sites_tilt['dir_dec'].tolist()
incs_reversal = sites_tilt['dir_inc'].tolist()

ipmag.reversal_test_bootstrap(decs_reversal, incs_reversal)
# Out:
# Fail, distinct in x and z
# 0

# %% [markdown]
# As suggested by the calculations by Elston et al. (2002), these directions do not pass a reversal test. However, we also attempted to do a reversal test on the five means of the "steep" group only.

# %%
decs_reversal_overprint = sites_overprint['dir_dec'].tolist()
incs_reversal_overprint = sites_overprint['dir_inc'].tolist()

ipmag.reversal_test_bootstrap(decs_reversal_overprint, incs_reversal_overprint)
# Out:
# Pass
# 1

# %% [markdown]
# The steep group passes a reversal test. But is it significant?

# %%
ipmag.reversal_test_MM1990(decs_reversal_overprint, incs_reversal_overprint)
# Out:
# Results of Watson V test:
#
# Watson's V:           2.3
# Critical value of V:  10.5
# "Pass": Since V is less than Vcrit, the null hypothesis
# that the two populations are drawn from distributions
# that share a common mean direction can not be rejected.
#
# M&M1990 classification:
#
# Angle between data set means: 10.6
# Critical angle for M&M1990:   22.9
# The McFadden and McElhinny (1990) classification for
# this test is: 'indeterminate'
# (1, 10.617967954094496, 22.91453955357089, 'indeterminate')

# %% [markdown]
# The test is indeterminate.

# %% [markdown]
# ## R2: Deenen test

# %%
pt.Deenen_test(pole_subset_overprinted['n'], pole_subset_overprinted['alpha95'])
pt.plot_Deenen_test(pole_subset_overprinted)
# Out:
# A_95 of 8.2 passes Deenen et al. (2011) criteria of being between 4.1 and 14.9 for this number of sites
# <Axes: title={'center': 'Deenen et al. (2011) test'}, xlabel='Number of sites (N)', ylabel='$A_{95}$ (°)'>

# %% [markdown]
# ## R7: Comparison with younger Laurentia poles

# %%
Laurentia_poles = pt.get_Laurentia_poles()
Laurentia_stricto_poles = pt.get_Laurentia_stricto_poles()
pt.plot_pole_overlap('Purcell Lava', Laurentia_stricto_poles, pt.Torsvik2012_Laurentia,
                  pole_plat=pole_subset_overprinted['inc'], pole_plon=pole_subset_overprinted['dec'],
                  pole_A95=pole_subset_overprinted['alpha95'], pole_age=1427)
# Out:
# <GeoAxes: >

# %% [markdown]
# ## R-score summary (Meert et al., 2020)

# %% [markdown]
# | R | Criterion | Score | Justification |
# |---|---|---|---|
# | 1 | Age within ± 15 Ma | **1** | One U-Pb ID-TIMS baddeleyite age of 1438.9 ± 3.3 Ma and one LA-ICP-MS U-Pb zircon age of 1419.9 ± 8.4 Ma (which agrees with ID-TIMS of an intrusive unit); from Constenius et al. (accepted); other ID-TIMS age of Purcell Lava within this range. |
# | 2 | Techniques and statistical analysis | **1** | (a) Both thermal and AF demagnetization applied to one site (b) Blanket demagnetization and PCA were both used, with majority PCA. (c) N = 225 samples, k = 22.7, A95 = 8.2° passes Deenen et al. (2011) envelope (4.1°–14.9°). B = 15 sites ≥ 8. |
# | 3 | Magnetic mineralogy characterized | **0** | Thermal stepwise demagnetization used only. Personal communication of microscopy for pigmentary hematite data not available. |
# | 4 | Field tests constrain age of magnetization | **1** | Positive fold test |
# | 5 | Structural control / tectonic coherence | **1** | Contentious as entirely on thrust sheets, but historically the Belt Supergroup has been treated at part of Laurentia|
# | 6 | Presence of reversals | **0** | Contains reversals but failed the reversal test; directions held by different carriers|
# | 7 | No resemblance to younger poles | **1** | No overlap with younger poles. |
# | | **Total R-score** | **5/7** | |

# %%
pole_subset_overprinted
# Out:
# {'dec': 35.54656626847584,
#  'inc': 13.598613522224403,
#  'n': 15,
#  'r': 14.382575565878339,
#  'k': 22.674839585699576,
#  'alpha95': 8.207613173685454,
#  'csd': 17.010336589162105}

# %% [markdown]
# ### Primary + overprint (all sites) pole
#
# | | This study (site VGPs) | Elston et al. (2002) | Previous Nordic compilation |
# |---|---|---|---|
# | Component | all sites except rotated & 1960s | Purcell primary | Primary |
# | N (sites) | 15 | 10 | 10 |
# | N (specimens) | 225 | — | 166 |
# | Dec (°) | 30.4 | 26.6 | 26.6 |
# | Inc (°) | -36.2 | -25.7 | -25.7 |
# | k (direction) | 17.9 | 64.0 | 64.0 |
# | α95 (direction, °) | 9.3 | 6.1 | 6.1 |
# | Pole lat (°N) | 13.6 | -23.6 | -23.6 |
# | Pole lon (°E) | 35.5 | 215.6 | 215.6 |
# | A95 | 8.2 | 4.8 | 4.8 |
# | pole (°) | — | — | — |
# | dp / dm (°) | — | — | 4.8 / 4.8 |

# %% [markdown]
# ## Nordic workshop ranking
#
# Prior Nordic Workshop compilations of paleomagnetic poles with expert-assigned rankings (Evans et al., 2021) have given the pole from the Purcell Lava an 'A' ranking.
#
# Our assessment and community evaluation by the 2026 Nordic Workshop is that careful evaluation of the pole suggests it should be assigned a 'B' ranking, primarily due to the poorly documented mineralogical complexity which make R3 and R6 scores of 0.  We further suggest using a recalculated pole including all measured sites by Elston et al. (2002) regardless of mineralogy (but not a clearly rotated one.)

# %%
Purcell_Lava_summary = pt.make_nordic_summary(terrane='Laurentia', 
                                        rockname='Purcell Lava', 
                                        sites=sites_subset_overprinted,
                                        dir_mean=dir_mean,
                                        pole_mean=pole_subset_overprinted,
                                        study_lon=study_lon,
                                        study_lat=study_lat,
                                        component_comment='',
                                        tests='f',
                                        R1=1,
                                        R2=1,
                                        R3=0,
                                        R4='f',
                                        R5=1,
                                        R6=0,
                                        R7=1,
                                        Grade='B',
                                        nominal_age=1427,
                                        lomagage=1412,
                                        himagage=1442,
                                        REF_method='One U-Pb ID-TIMS baddeleyite age of 1438.9 ± 3.3 Ma and one LA-ICP-MS U-Pb zircon age of 1419.9 ± 8.4 Ma (which agrees with ID-TIMS of an intrusive unit); from Constenius et al. (accepted); other ID-TIMS age of Purcell Lava within this range.',
                                        POLE_AUTHORS='Elston, D. P., Enkin, R. J., Baker, J., and Kisilevsky, D. K. ',
                                        YEAR=2002,
                                        JOURNAL='Geological Society of America Bulletin',
                                        VOLUME=114,
                                        VPAGES='619-638',
                                        TITLE='Tightening the Belt: Paleomagnetic-stratigraphic constraints on deposition, correlation, and deformation of the Middle Proterozoic (ca. 1.4 Ga) Belt-Purcell Supergroup, United States and Canada',
                                        COMMENT=''
                                        )
Purcell_Lava_summary
# Out:
#      Terrane      ROCKNAME RESULT# COMPONENT TESTS  TILT   SLAT   SLONG   B  \
# 0  Laurentia  Purcell Lava                       f   100  49.25 -114.93  15
#
#      N   DEC   INC  abs(I)    KD  ED95  PLAT  PLONG DP DM  A95    f  INCf  \
# 0  225  30.4 -36.2    36.2  17.9   9.3  13.6   35.5        8.2  1.0 -36.2
#
#    PLATf  PLONf DPf DMf  A95f    f  INCf  PLATf  PLONf DPf DMf  A95f %REV  \
# 0   13.6   35.5           8.2  1.0 -36.2   13.6   35.5           8.2
#
#   DEMAGCODE 40 24 10 16 Q2 Q3 Q4 Q5 Q6 Q7 Q(7)  R1  R2  R3 R4  R5  R6  R7  R  \
# 0                                                1   1   0  f   1   0   1  5
#
#   Grade  nominal age  lomagage  himagage  \
# 0     B         1427      1412      1442
#
#                                           REF/method      ROCKNAME  \
# 0  One U-Pb ID-TIMS baddeleyite age of 1438.9 ± 3...  Purcell Lava
#
#                                         POLE AUTHORS  YEAR  \
# 0  Elston, D. P., Enkin, R. J., Baker, J., and Ki...  2002
#
# ...

# %%
# save the summary dictionary as a single-row CSV in data/nordic_summaries
pt.save_nordic_summary(Purcell_Lava_summary, '1427_Purcell_Lava')
# Out:
# '../data/nordic_summaries/1427_Purcell_Lava.csv'
