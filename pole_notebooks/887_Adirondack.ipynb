# %% [markdown]
# # Adirondack Highlands ca. 887 Ma paleomagnetic pole
#
# ## Geologic context
#
# The Adirondack Highlands of northern New York preserve a granulite-facies metamorphic record from the Grenvillian orogeny. Brown and McEnroe (2012) collected paleomagnetic samples from an east-west traverse across the Highlands, sampling three principal rock units: (1) microcline gneisses (GMS) of the western and far-western Highlands, (2) the metamorphosed anorthosites of the Marcy Massif and associated metamorphic rocks (metasyenites, metadiorites, granitic gneisses), and (3) post-metamorphic fayalite-bearing granites of the Wanakena and Ausable Forks plutons. Protracted granulite-facies Grenvillian metamorphism (T > 650 °C) persisted at high grade to ca. 996 Ma (Zhang et al., 2026) and reset pre-existing magnetizations, with new remanence acquired during subsequent slow cooling through the Tonian.
#
# Each of the three rock units carries a stable remanence with characteristic dual polarity. The remanence is carried by ilmeno-hematite in the microcline gneisses and by magnetite in the metamorphosed anorthosites (with subsidiary hemo-ilmenite) and in the post-metamorphic fayalite granites. Brown and McEnroe (2012) reported a pole at 18.4°S, 151.1°E for the gneisses, 25.1°S, 149.0°E for the anorthosite group (combining 11 anorthosite sites with 3 associated metamorphic rock sites for a 14-site grouping in their Table 3), and 28.4°S, 132.7°E for the fayalite granite.
#
# Zhang et al. (2026, *Tectonics*) develop new U-Pb petrochronology and thermochronology datasets from zircon, garnet, titanite, rutile, and apatite from the Adirondack Highlands. Probabilistic thermal history inversion of these data shows that the Adirondack Highlands cooled slowly throughout the Tonian, with the magnetite-carried remanence in the Marcy Massif anorthosite acquired ca. **887 ± 23 Ma** — about 85 Myr later than the ca. 970 Ma cooling-curve estimate of Brown and McEnroe (2012). Zhang et al. additionally report a positive inverse baked-contact test in which an unmetamorphosed mafic dike (site GD1) bakes its anorthosite host (site MA11); because such dikes intrude Proterozoic but not Paleozoic rocks in the region (Fisher, 1977) and are correlated with Ediacaran dikes dated elsewhere in the Grenville Province (Kamo et al., 1995; Halls et al., 2015), the test demonstrates that the anorthosite magnetite remanence is Proterozoic in age. This revised age fills a critical gap in the Laurentia apparent polar wander path between the ca. 990 Ma Jacobsville Formation pole and the ca. 780 Ma Gunbarrel pole, with implications for the position of Rodinia in the early to mid-Tonian.
#
# ## Paleomagnetic and rock magnetic data
#
# Brown and McEnroe (2012) characterized the magnetic mineralogy of the Adirondack rocks using SEM petrography of oxide microstructures, isothermal remanent magnetization (IRM) acquisition, hysteresis loops, low-temperature susceptibility, and thermomagnetic experiments. The microcline gneisses are dominated by ilmeno-hematite with multiple generations of fine ilmenite exsolution lamellae, which give rise to the distinctive lamellar magnetism of these rocks. The metamorphosed anorthosites and the fayalite granites are dominated by magnetite (with subsidiary hemo-ilmenite in some anorthosites). The hemo-ilmenite remanence in the microcline gneisses is interpreted by Brown and McEnroe (2012) as a chemical remanent magnetization (CRM) acquired during sub-solvus exsolution of ilmenite lamellae from a titanohematite host, whereas the magnetite-carried remanence in the metamorphosed anorthosites and fayalite granites is a thermoremanent magnetization (TRM) acquired on cooling through the magnetite Curie temperature. Given current knowledge, it is more straight-forward to time calibrate the magnetite-held TRM.
#
# Site mean directions were determined after progressive alternating-field (AF) and thermal demagnetization, with characteristic directions isolated by principal component analysis (Kirschvink, 1980). Sites with normal polarity (steep-down, SE declination) and reversed polarity (steep-up, NW declination) occur in all three rock units. Brown and McEnroe (2012) note that the metamorphic rocks pass the McFadden and McElhinny (1990) reversal test as Class C (γ_o = 4.88° vs. γ_c = 4.68°, slightly outside the 95% level), while the fayalite granite passes the test as Class C (limited by only one normal-polarity site).
#
# ## Three poles, three locations
#
# The MagIC contribution for this study reports three pole results — one per location — following the groupings of Brown and McEnroe (2012) Table 3:
#
# 1. **Adirondack microcline gneiss** (14 sites, ilmeno-hematite carrier; 900 ± 100 Ma)
# 2. **Adirondack metamorphic anorthosite** (11 anorthosite + 3 associated metamorphic rock sites = 14 sites total, magnetite carrier; 887 ± 23 Ma per Zhang et al., 2026)
# 3. **Adirondack fayalite granite** (8 sites, magnetite carrier; 900 ± 100 Ma)
#
# The R-criteria assessment below focuses on the 887 Ma metamorphic anorthosite pole — the result on which the new Zhang et al. age constraint operates.
#
# ## References
#
# ### Paleomagnetism and magnetic mineralogy
#
# - Brown, L. L., & McEnroe, S. A. (2012). Paleomagnetism and magnetic mineralogy of Grenville metamorphic and igneous rocks, Adirondack Highlands, USA. *Precambrian Research*, 212–213, 57–74. https://doi.org/10.1016/j.precamres.2012.04.012
#
# ### Geochronology and thermochronology
#
# - Zhang, Y., Hodgin, E. B., Schmitz, M. D., Schwartz, D. M., Mohr, M. T., Crowley, J. L., & Swanson-Hysell, N. L. (2026). Protracted high-grade metamorphism and slow cooling in the Adirondacks recalibrate Neoproterozoic global paleogeography. *Tectonics*, 45, e2025TC009333. https://doi.org/10.1029/2025TC009333
# - The paleomagnetic baked-contact-test data of Zhang et al. (2026) are archived in MagIC (https://doi.org/10.7288/V4/MAGIC/20549).

# %%
import pole_tools as pt
import pmagpy.ipmag as ipmag
import pmagpy.pmag as pmag
import matplotlib.pyplot as plt
import numpy as np

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %% [markdown]
# ## Site-level data
#
# All 36 sites are stored at `dir_tilt_correction = 0` (geographic coordinates) since these basement metamorphic and igneous rocks have no bedding tilt to correct. The MagIC `location` field assigns each site to one of the three pole groupings.

# %%
sites_geo, sites_tc = pt.load_magic_sites('../data/887_Adirondack_anorthosite/sites.txt')
print(f'{len(sites_geo)} sites loaded (all geographic coordinates)')
print(sites_geo['location'].value_counts())
sites_geo[['site', 'location', 'lat', 'lon',
           'dir_dec', 'dir_inc', 'dir_k', 'dir_alpha95',
           'vgp_lat', 'vgp_lon', 'dir_n_samples']]
# Out:
# 36 sites loaded (all geographic coordinates)
# location
# Adirondack microcline gneiss          14
# Adirondack metamorphic anorthosite    14
# Adirondack fayalite granite            8
# Name: count, dtype: int64
#      site                            location    lat     lon  dir_dec  \
# 0     AD1        Adirondack microcline gneiss  44.20  286.00    232.1
# 1     AD2        Adirondack microcline gneiss  44.20  286.00    257.8
# 2     AD5        Adirondack microcline gneiss  44.20  286.00    292.2
# 3     AD6        Adirondack microcline gneiss  44.20  286.00    271.2
# 4    AD11        Adirondack microcline gneiss  44.20  286.00     98.1
# 5    AD15        Adirondack microcline gneiss  44.20  286.00    138.7
# 6    AD18        Adirondack microcline gneiss  44.20  286.00    111.6
# 7    AD21        Adirondack microcline gneiss  44.20  286.00    318.4
# 8    AD22        Adirondack microcline gneiss  44.20  286.00    282.3
# ...

# %% [markdown]
# ## Site location map

# %%
pt.plot_site_map(sites_geo, zoom_start=8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ## Mean poles by rock unit
#
# Each location's pole is computed as a Fisher mean of site VGPs after polarity unification (`unify_polarity=True`). All three units have a mix of normal (AN) and reverse (AR) polarity sites; the unification flips the minority polarity to common reverse polarity before averaging.

# %%
for loc in ['Adirondack microcline gneiss',
            'Adirondack metamorphic anorthosite',
            'Adirondack fayalite granite']:
    sub = sites_geo[sites_geo['location'] == loc].reset_index(drop=True)
    _, pole = pt.compute_mean_pole(sub, unify_polarity=True)
    print(f'\n=== {loc} (N={pole["n"]}) ===')
    ipmag.print_pole_mean(pole)
# Out:
# === Adirondack microcline gneiss (N=14) ===
# Plon: 328.7  Plat: 19.0
# Number of directions in mean (n): 14
# Angular radius of 95% confidence (A_95): 11.2
# Precision parameter (k) estimate: 13.6
#
# === Adirondack metamorphic anorthosite (N=14) ===
# Plon: 323.4  Plat: 25.2
# Number of directions in mean (n): 14
# Angular radius of 95% confidence (A_95): 12.9
# Precision parameter (k) estimate: 10.5
#
# === Adirondack fayalite granite (N=8) ===
# Plon: 311.7  Plat: 28.5
# Number of directions in mean (n): 8
# Angular radius of 95% confidence (A_95): 7.1
# Precision parameter (k) estimate: 62.7

# %% [markdown]
# ## Anorthosite pole — VGP plot
#
# The remainder of the analysis focuses on the 887 ± 23 Ma metamorphic anorthosite pole.

# %%
sites_anorth = sites_geo[
    sites_geo['location'] == 'Adirondack metamorphic anorthosite'
].reset_index(drop=True)

vgp_block, pole_mean = pt.compute_mean_pole(sites_anorth, unify_polarity=True, flip=True)
ipmag.print_pole_mean(pole_mean)
pole_plot = pt.plot_vgps_and_pole(vgp_block, pole_mean, figsize=(5, 5))
# Out:
# Plon: 143.4  Plat: -25.2
# Number of directions in mean (n): 14
# Angular radius of 95% confidence (A_95): 12.9
# Precision parameter (k) estimate: 10.5

# %%
ax = ipmag.make_orthographic_map(central_longitude=150,central_latitude=0, figsize=(5,5))
ipmag.plot_pole(ax, 149.0, -25.1, np.sqrt(10.6*12.7),
               label='direction-calculated pole as reported\nin Brown and McEnroe (2011)',
               color='darkblue',marker='o')
ipmag.plot_pole(ax, pole_mean['dec'], pole_mean['inc'], pole_mean['alpha95'],
               label='VGP calculated pole as calculated from\nsites reported in Brown and McEnroe (2011) and\nsite locations (Brown, personal communication)',
               color='darkred',marker='s')
plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# ## Anorthosite site directions (as measured at sites)

# %%
ipmag.plot_net()
ipmag.plot_di(dec=sites_anorth['dir_dec'],inc=sites_anorth['dir_inc'], color='blue', marker='o')
ipmag.plt.title('Mean Site Directions (as measured at sites)')
ipmag.plt.show()

# %%
ipmag.reversal_test_bootstrap(dec=sites_anorth['dir_dec'],inc=sites_anorth['dir_inc'])
# Out:
# Fail, distinct in y and z
# 0

# %%
ipmag.reversal_test_MM1990(dec=sites_anorth['dir_dec'],inc=sites_anorth['dir_inc'])
# Out:
# Results of Watson V test:
#
# Watson's V:           12.2
# Critical value of V:  7.1
# "Fail": Since V is greater than Vcrit, the two means can
# be distinguished at the 95% confidence level.
#
# M&M1990 classification:
#
# Angle between data set means: 20.0
# Critical angle for M&M1990:   15.2
# (0, np.float64(20.00099289791517), np.float64(15.193434580949635), '')

# %%
dir_block, dir_mean = pt.compute_mean_direction(sites_anorth, unify_polarity=True, flip=True)
ipmag.print_direction_mean(dir_mean)

ipmag.plot_net()
ipmag.plot_di(di_block=dir_block, color='blue', marker='o')
ipmag.plot_di_mean(dir_mean['dec'], dir_mean['inc'], dir_mean['alpha95'],
                   color='red', marker='s')
ipmag.plt.title('Mean Site Directions (as measured at sites)')
ipmag.plt.show()
# Out:
# Dec: 280.3  Inc: -67.8
# Number of directions in mean (n): 14
# Angular radius of 95% confidence (a_95): 7.8
# Precision parameter (k) estimate: 26.7

# %% [markdown]
# ## Anorthosite mean direction at common locality
#
# Site VGPs are converted back to directions at a common Adirondack locality (44.2°N, -73.9°E ≈ central Marcy Massif) for comparison with the Brown and McEnroe (2012) Table 2 mean direction (I = -67.3°, D = 283.9° for the combined 14-site group).

# %%
study_lat = 44.2
study_lon = -73.9
dir_block_from_vgps, dir_mean_from_vgps = pt.compute_mean_direction_from_vgps(
    sites_anorth, study_lon, study_lat, unify_polarity=True, flip=True)
ipmag.print_direction_mean(dir_mean_from_vgps)

ipmag.plot_net()
ipmag.plot_di(di_block=dir_block_from_vgps, color='blue', marker='o')
ipmag.plot_di_mean(dir_mean_from_vgps['dec'], dir_mean_from_vgps['inc'],
                   dir_mean_from_vgps['alpha95'], color='red', marker='s')
ipmag.plt.title('Mean Site Directions (calculated for common locality from VGPs)')
ipmag.plt.show()
# Out:
# Dec: 288.6  Inc: -68.3
# Number of directions in mean (n): 14
# Angular radius of 95% confidence (a_95): 8.6
# Precision parameter (k) estimate: 22.5

# %% [markdown]
# ## Paleosecular variation and VGP-shape diagnostics
#
# The Fisher-quantile (fishqq) test assesses whether the site VGPs are drawn from a
# Fisher distribution, and the shape-elongation/inclination (SVEI) test compares the
# VGP-scatter elongation against the TK03.GAD paleosecular-variation model expectation
# at the sampling paleolatitude.

# %%
fishqq_result = pt.fishqq_vgps(sites_anorth, unify_polarity=True)
fishqq_result
# Out:
# {'Mode': 'Mode 1',
#  'Dec': np.float64(323.6971918383888),
#  'Inc': np.float64(24.75186971040446),
#  'N': 14,
#  'Mu': np.float64(0.7371083716926277),
#  'Mu_critical': 1.207,
#  'Me': np.float64(1.0981595553251413),
#  'Me_critical': 1.094,
#  'Test_result': 'Fisher distribution rejected'}

# %%
_slat, _slon = float(sites_anorth['lat'].mean()), float(sites_anorth['lon'].mean())
try:
    svei_result = pt.svei_test_vgps(sites_anorth, _slon, _slat, model='TK03_GAD', plot=True)
except TypeError:
    svei_result = pt.svei_test_vgps(sites_anorth, _slon, _slat, model='TK03_GAD', plot=False)
    print('(SVEI elongation plot skipped: E below the TK03.GAD model minimum)')
print(f"paleolatitude = {svei_result['lat']:.1f} deg; elongation E = {svei_result['E']:.2f} "
      f"({'consistent' if svei_result['E_result'] else 'inconsistent'} with TK03.GAD)")
# Out:
# paleolatitude = 51.7 deg; elongation E = 2.83 (consistent with TK03.GAD)

# %% [markdown]
# ## Pole in the context of the Laurentia APWP

# %%
Laurentia_poles = pt.get_Laurentia_poles()
Laurentia_poles = pt.plot_apwp_context(Laurentia_poles, pole_mean['inc'], pole_mean['dec'], pole_mean['alpha95'], age_min=635, age_max=1800, projection='orthographic', central_longitude=pole_mean['dec'], central_latitude=pole_mean['inc'])
plt.show()

# %% [markdown]
# ## R2: Deenen test

# %%
pt.Deenen_test(pole_mean['n'], pole_mean['alpha95'])
print(f'\nVGP Fisher precision K = {pole_mean["k"]:.1f} (R2 PSV threshold: 10 ≤ K ≤ 70)')
pt.plot_Deenen_test(pole_mean)
# Out:
# A_95 of 12.9 passes Deenen et al. (2011) criteria of being between 4.2 and 15.6 for this number of sites
#
# VGP Fisher precision K = 10.5 (R2 PSV threshold: 10 ≤ K ≤ 70)
# <Axes: title={'center': 'Deenen et al. (2011) test'}, xlabel='Number of sites (N)', ylabel='$A_{95}$ (°)'>

# %% [markdown]
# ## R7: Comparison with younger Laurentia poles

# %%
Laurentia_stricto_poles = pt.get_Laurentia_stricto_poles()
pt.plot_pole_overlap('MEAN Wyoming "Gunbarrel" dykes',
                     Laurentia_stricto_poles, pt.Torsvik2012_Laurentia,
                     pole_plat=pole_mean['inc'], pole_plon=pole_mean['dec'],
                     pole_A95=pole_mean['alpha95'], pole_age=887)
# Out:
# <GeoAxes: >

# %% [markdown]
# ## R-score summary (Meert et al., 2020) — 887 Ma anorthosite pole
#
# | R | Criterion | Score | Justification |
# |---|---|---|---|
# | 1 | Age within ± 15 Ma | **0** | Magnetite remanence acquisition age of **887 ± 23 Ma** from Zhang et al. (2026, *Tectonics*), based on probabilistic thermal history inversion of U-Pb zircon, garnet, titanite, rutile, and apatite data. The 1σ uncertainty (23 Ma) modestly exceeds the strict ± 15 Ma threshold, although the underlying U-Pb dates are tightly constrained (metamorphic zircon to 995.81 ± 0.74 Ma; titanite 1017.91–995.95 Ma; garnet ca. 1040–1007 Ma; rutile and apatite cooling dates ca. 890–850 Ma) and the inversion-derived remanence age is well-resolved. |
# | 2 | Techniques and statistical analysis | **1** | (a) ✓ Both AF and thermal demagnetization performed (Brown and McEnroe, 2012, §4.1). (b) ✓ Principal component analysis used (Kirschvink, 1980). (c) ✓ Deenen test passes (A95 = 12.9° within [4.2°, 15.6°] for N = 14); N = 68 samples ≥ 25; B = 14 sites ≥ 8; **VGP Fisher precision K = 10.5 just above the 10 ≤ K ≤ 70 threshold**. The directional Fisher precision *k* = 28 (Brown 2012, Table 2) for the 14-site group is well within range. |
# | 3 | Magnetic mineralogy characterized | **1** | Brown and McEnroe (2012) provide an extensive magnetic-mineralogy study (their §3): SEM petrography of oxide microstructures, IRM acquisition, hysteresis loops, Day-plot analysis, low-temperature susceptibility, and thermomagnetic experiments. The metamorphosed anorthosites are shown to be dominated by multidomain to PSD magnetite (Curie temperature ~570 °C), with subsidiary hemo-ilmenite as inclusions in plagioclase. |
# | 4 | Field tests constrain age of magnetization | **1** | Zhang et al. (2026) report a positive inverse baked-contact test (the host rock, not the intrusion, carries the pole; code c per resources/field_test_codes.md) from a 9-cm-thick unmetamorphosed mafic dike (site GD1) that intrudes the Marcy anorthosite host (site MA11). Anorthosite samples 1.5–4 cm from the dike are fully baked and carry the dike direction; a sample 6 cm away is partially baked; samples >6 cm from the dike carry an origin-trending, low-Ti-titanomagnetite component (sharp unblocking 570–590 °C) that matches the magnetite characteristic direction at other Marcy anorthosite sites of Brown and McEnroe (2012). Because such dikes intrude Proterozoic but not Paleozoic rocks (Fisher, 1977) and are correlated with Ediacaran dikes dated elsewhere in the Grenville Province (Kamo et al., 1995; Halls et al., 2015), the positive test demonstrates the anorthosite magnetite remanence is Proterozoic. Dike-plane orientations are indistinguishable from vertical, consistent with minimal Phanerozoic tilting. (Baked-contact data archived as MagIC 20549.) |
# | 5 | Structural control / tectonic coherence | **1** | The Adirondack Highlands form a coherent ~125 km block of granulite-facies basement separated from the Lowlands by the Carthage-Colton shear zone (Mezger et al., 1992). The Highlands have not experienced discernible Paleozoic metamorphism or deformation (McLelland et al., 1996, 2010), and there is no evidence for internal block rotations or tilting since cooling through magnetite blocking temperatures although there is not paleohorizontal control. The unit is a rigid part of Laurentia post-magnetization. |
# | 6 | Presence of reversals | **0** | Both normal (4 sites) and reverse (7 sites) polarities are observed in the metamorphic anorthosite group (and in the combined 14-site grouping). Brown and McEnroe (2012) report that the combined metamorphic-rock group fails the McFadden and McElhinny (1990) reversal test at the 95% level (γ_o = 4.88° vs. γ_c = 4.68°). The failure is marginal — the test would qualify as Class C if it passed — but a strict reading of R6 requires a passing test. |
# | 7 | No resemblance to younger poles | **1** | The 887 Ma anorthosite pole at ~25°S, 145°E does not overlap with the Phanerozoic Laurentia APWP (which occupies a different region of the globe through the Cambrian–present interval). The positive inverse baked-contact test against a crosscutting (likely Ediacaran) mafic dike (R4) provides independent confirmation that the magnetization is Proterozoic and predates the Phanerozoic. |
# | | **Total R-score** | **5/7** | |

# %% [markdown]
# ## Nordic workshop ranking
#
# Proposed: **B**

# %% [markdown]
# ### Adirondack metamorphic anorthosite pole
#
# | | This study (site VGPs) | Brown & McEnroe (2012) | Previous Nordic compilation (as NR in Swanson-Hysell, 2021) |
# |---|---|---|---|
# | Component | Adirondack metamorphic anorthosite | Combined meta. rocks | Adirondack metamorphic anorthosite |
# | N (sites) | 14 | 14 | 14 |
# | N (specimens) | 68 | — | 68 |
# | Dec (°) | 288.6 | 283.9 | 288.6 |
# | Inc (°) | -68.3 | -67.3 | -68.3 |
# | k (direction) | 22.5 | 28 | 22.5 |
# | α95 (direction, °) | 8.6 | 7.7 | 8.6 |
# | Pole lat (°N) | -25.2 | -25.1 | -25.2 |
# | Pole lon (°E) | 143.4 | 149.0 | 143.4 |
# | A95, pole (°) | 12.9 | — | 12.9 |
# | dp / dm (°) | — | 10.6 / 12.7 | — |

# %%
Adirondack_anorthosite_summary = pt.make_nordic_summary(
    terrane='Laurentia',
    rockname='Adirondack metamorphic anorthosite',
    sites=sites_anorth,
    dir_mean=dir_mean_from_vgps,
    pole_mean=pole_mean,
    study_lon=study_lon,
    study_lat=study_lat,
    component_comment='Magnetite-carried granulite-cooling remanence',
    tests='c+ (positive inverse baked contact test: GD1 dike bakes MA11 anorthosite host; Zhang et al., 2026; MagIC 20549); reversal test marginal failure (γ_o = 4.88°, γ_c = 4.68°) per Brown and McEnroe (2012)',
    R1=0,
    R2=1,
    R3=1,
    R4='c',
    R5=1,
    R6=0,
    R7=1,
    Grade='B',
    nominal_age=887,
    lomagage=864,
    himagage=910,
    REF_method='Magnetite remanence acquisition age 887 ± 23 Ma from probabilistic thermal history inversion of U-Pb zircon, garnet, titanite, rutile, and apatite thermochronology (Zhang et al., 2026, Tectonics, doi:10.1029/2025TC009333). Underlying U-Pb dates: metamorphic zircon to 996 Ma, titanite 1018–996 Ma, garnet 1040–1007 Ma, rutile/apatite cooling 890–850 Ma. Site directional data from Brown and McEnroe (2012).',
    POLE_AUTHORS='Brown, L. L., & McEnroe, S. A.',
    YEAR=2012,
    JOURNAL='Precambrian Research',
    VOLUME='212-213',
    VPAGES='57-74',
    TITLE='Paleomagnetism and magnetic mineralogy of Grenville metamorphic and igneous rocks, Adirondack Highlands, USA',
    COMMENT='Pole calculated from VGPs as documented in Zhang et al. 2026 and Swanson-Hysell et al. 2026.'
)
Adirondack_anorthosite_summary
# Out:
#      Terrane                            ROCKNAME RESULT#  \
# 0  Laurentia  Adirondack metamorphic anorthosite
#
#                                        COMPONENT  \
# 0  Magnetite-carried granulite-cooling remanence
#
#                                                TESTS  TILT  SLAT  SLONG   B  \
# 0  c+ (positive inverse baked contact test: GD1 d...     0  44.2  -73.9  14
#
#     N  ...  himagage                                         REF/method  \
# 0  68  ...       910  Magnetite remanence acquisition age 887 ± 23 M...
#
#                              ROCKNAME                    POLE AUTHORS  YEAR  \
# 0  Adirondack metamorphic anorthosite  Brown, L. L., & McEnroe, S. A.  2012
#
#                 JOURNAL   VOLUME VPAGES  \
# 0  Precambrian Research  212-213  57-74
#
#                                                TITLE  \
# 0  Paleomagnetism and magnetic mineralogy of Gren...
#
#                                              Comment
# ...

# %%
# save the summary dictionary as a single-row CSV in data/nordic_summaries
pt.save_nordic_summary(Adirondack_anorthosite_summary, '887_Adirondack')
# Out:
# '../data/nordic_summaries/887_Adirondack.csv'
