# %% [markdown]
# # Pilcher Garnet Range-Libby pole ~1390 Ma Elston et al. (2002)

# %% [markdown]
# ## Geologic context
#
# The Mesoproterozoic Belt Supergroup, located in Montana and Idaho, USA, and Alberta and British Columbia, Canada, spans an enormous extent covering > 200,000 km<sup>2</sup> (Lonn et al. 2020). It is a predominantly sedimentary succession over 15 km thick in places, which has been subdivided into four groups. The Garnet Range, Libby, and Pilcher Formations are at the top of the Missoula Group, which is the uppermost group (Lonn et al. 2020). The Belt Supergroup was an early place of paleomagnetic analyses in the 1950s and 1960s, but the majority of subsequent paleomagnetic analyses were the product of years of work by Don Elston of the United States Geologic Survey and colleagues, which were published in Elston et al. (2002). While Elston et al. (2002) note that carbonates and green-grey-black siliclastics were analyzed, the "weak and incoherent magnetizations" led the study to focus on red beds spanning the entirety of the stratigraphic succession.
#
# The Garnet Range Formation, in its type area near Missoula, MT, sharply overlies the McNamara and is a green-grey micaceous quartz-rich sandstone and mudstone (Winston and Link 1993).  It marks a clear transition in the underlying Belt-Purcell Supergroup units, with an abundance of fresh detrital minerals (feldspar and unweathered magnetite in addition to the mica) and lenses of sand with large-scale hummocky cross-stratification, interpreted as expansion of the Belt Basin (Winston and Link 1993).   The Garnet Range is included in the Libby Formation in western Montana and Idaho, and the Rooseville Formation in Canada (Lonn et al. 2020).  The Garnet Range is overlain in the Missoula area by the Pilcher Formation, a purple and white cross-bedded sand that has a limited outcrop area (Winston and Link, 1993). It has been suggested to be the final filling of the Belt Basin by tidal/fluvial deposits.

# %% [markdown]
# ## Paleomagnetic and rock magnetic data
#
# Elston et al. (2002) report 5 sites--one from the Pilcher Formation, three from the Garnet Range, and one from the Libby Formation (presumably the upper portion).  Elston et al. (2002) emphasize that these units were grouped to have enough localities.
#
# The text notes that in most samples a >50%  magnetization is lost above 590 ºC, suggesting hematite as an important remanence carrier.  Zijdervelds of two samples show a large drop in magnetization above 650 ºC, highlighting the importance of coarse detrital hematite in these samples.  No additional rock magnetism was performed on these samples; microscopy of the unweathered detrital magnetite noted in the Garnet Range has not been published by prior authors.
#
# The USGS subjected pilot samples to stepwise demagnetization in 8 steps, but then demagnetized the remaining samples in blanket demagnetization steps--all sites were treated this way, using steps of 550 ºC (1 Garnet Range site), 590 ºC (Pilcher and Libby sites), and 630 ºC (2 Garnet Range sites).
#
# Of the five sites, one was excluded form the formation mean direciton and pole--the Garnet Range Formation at Flint Creek--due to interpreted counterclockwise vertical-axis rotation based on paleomagnetic directions.  Elston et al. (2002) note caution with using this pole as the other four sites are small in number and near major structures that could also cause vertical-axis rotation.
#
# All of the sites share the same polarity (reversed).

# %% [markdown]
# ## Geochronology Constraints
#
# Evans et al. (2000) reported a SHRIMP U–Pb zircon age of 1401 ± 6 Ma for a tuff in the very thin transition zone between the Bonner Quartzite and Libby Formation.
#
# Detrital zircon U-Pb dating from the Garnet Range and Pilcher Formations using LA-ICP-MS found some older MDAs, but also provided two constraints of 1384.0 ± 23.5 Ma and 1390.4 ± 24.9 Ma (Parker and Hendrix 2022).
#
# These sedimentary ages are consistent with an uppermost age constraint from a diabase in the Salmon River Arch of Idaho, which intrudes the Lemhi group (potentially the Yellowjacket Formation, although the stratigraphy has been substantially revised) and has an age of 1379 ± 1 Ma based on U-Pb TIMS dating of zircons (Doughty and Chamberlain 1996). The Lemhi Group (and Yellowjacket Formation) has been correlated to units stratigraphically below the McNamara Formation within the Missoula Group, but has historically been used to mark the "end" of deposition within the Belt Basin.
#
# Stratigraphic relationships show this unit is younger than the McNamara Formation (which forms the lower part of the Libby Formation)--we have thus chosen a nominal age of 1385 Ma.

# %% [markdown]
# # References
#
# Doughty, P.T., and Chamberlain, K.R., 1996, Salmon River Arch revisited: New evidence for 1370 Ma rifting near the end of deposition in the Middle Proterozoic Belt Basin: Canadian Journal of Earth Sciences, v. 33, p. 1037– 1052, DOI: 10.1139/e96-079.
#
# Elston, D. P., Enkin, R. J., Baker, J., & Kisilevsky, D. K. (2002). Tightening the Belt: Paleomagnetic-stratigraphic constraints on deposition, correlation, and deformation of the Middle Proterozoic (ca. 1.4 Ga) Belt-Purcell Supergroup, United States and Canada. Geological Society of America Bulletin, 114(5), 619-638. DOI: 10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
#
# Evans, K.V., Aleinikoff , J.N., Obradovich, J.D., and Fanning, C.M., 2000, SHRIMP U-Pb geochronology
# of volcanic rocks, Belt Supergroup, western Montana: Evidence for rapid deposition of sedimentary strata: Canadian Journal of Earth Sciences, v. 37, p. 1287–1300, DOI: 10.1139/cjes-37-9-1287
#
# Lonn, J. D., Burmester, R. F., Lewis, R. S., McFaddan, M. D., Metesh, J. J., & Vuke, S. M. (2020). The Mesoproterozoic Belt Supergroup. in Barth, S., ed., Geology of Montana: Montana Bureau of Mines and Geology Special Publication 122, 1, 1-38.
#
# Parker, S.D., and Hendrix, M.S., 2022, Detrital zircon record of the Mesoproterozoic Belt Basin and implications for horizontal
# and vertical tectonic models, in Foulger, G.R., Hamilton, L.C., Jurdy, D.M., Stein, C.A., Howard, K.A., and Stein, S., eds., In the Footsteps of Warren B. Hamilton: New Ideas in Earth Science: Geological Society of America Special Paper 553, p. 159– 176, DOI: 10.1130/2021.2553(14).
#
# Winston, D., and Link, P.K., 1993, Middle Proterozoic rocks of Montana, Idaho and eastern Washington: The Belt Supergroup, in Reed, J.C., Jr., Bickford, M.E., Houston, R.S., Link, P.K., Rankin, D.W.,
# Sims, P.K., and Van Schmus, W.R., eds., Precambrian: Conterminous U.S.: Geological Society of
# America, Decade of North American Geology, v. C-2, p. 487–517.

# %% [markdown]
# # Calculations of Site Level Data

# %%
import pole_tools as pt
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import pmagpy.pmag as pmag
import pmagpy.ipmag as ipmag
import matplotlib.pyplot as plt

# %matplotlib inline
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %% [markdown]
# ## Read in sites

# %%
sites_df = pd.read_csv('../data/1385_Garnet_Range/sites.txt', sep='\t',header=1)

# %%
sites_df.head()
# Out:
#     age  age_high  age_low  age_sigma age_unit  \
# 0  1385      1407     1378        NaN       Ma
# 1  1385      1407     1378        NaN       Ma
# 2  1385      1407     1378        NaN       Ma
# 3  1385      1407     1378        NaN       Ma
# 4  1385      1407     1378        NaN       Ma
#
#                                          citations  \
# 0  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 1  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 2  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 3  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 4  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
#
#                                          description  dir_alpha95  dir_dec  \
# 0  Pilcher; Geochronological results from Doughty...          5.4     25.2
# 1  Pilcher; Geochronological results from Doughty...          5.4     27.4
# 2  Garnet Range; Geochronological results from Do...          4.1     21.8
# ...

# %% [markdown]
# ## Add VGPs

# %%
sites_df['vgp_lon'], sites_df['vgp_lat'], sites_df['vgp_dp'], sites_df['vgp_dm'] = pmag.dia_vgp(sites_df['dir_dec'], sites_df['dir_inc'], sites_df['dir_alpha95'], sites_df['lat'], sites_df['lon'])

# %%
sites_df.head()
# Out:
#     age  age_high  age_low  age_sigma age_unit  \
# 0  1385      1407     1378        NaN       Ma
# 1  1385      1407     1378        NaN       Ma
# 2  1385      1407     1378        NaN       Ma
# 3  1385      1407     1378        NaN       Ma
# 4  1385      1407     1378        NaN       Ma
#
#                                          citations  \
# 0  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 1  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 2  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 3  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
# 4  10.1130/0016-7606(2002)114<0619:TTBPSC>2.0.CO;2
#
#                                          description  dir_alpha95  dir_dec  \
# 0  Pilcher; Geochronological results from Doughty...          5.4     25.2
# 1  Pilcher; Geochronological results from Doughty...          5.4     27.4
# 2  Garnet Range; Geochronological results from Do...          4.1     21.8
# ...

# %%
# pmag.magic_write('../data/1385_Garnet_Range/sites.txt', sites_df, 'sites', dataframe=True)

# %% [markdown]
# ## Site Location Map

# %%
pt.plot_site_map(sites_df, zoom_start=8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# Note that the Basin Draw site plots in the middle of Flathead Lake. The reported location from Elston et al. (2002) may be inaccurate; the most likely explanation is that the longitude should be -115.1º.

# %% [markdown]
# ## Plot

# %%
sites_geo = sites_df[sites_df['dir_tilt_correction'] == 0]
sites_tilt = sites_df[sites_df['dir_tilt_correction'] == 100]

plt.figure(figsize = (4,4))
ipmag.plot_net()

for row, site in sites_tilt.iterrows():
    if site['result_quality'] == 'g':
        col = 'g'
    elif site['result_quality'] == 'b':
        col = 'r'
    ipmag.plot_di_mean(dec=site['dir_dec'],
                       inc=site['dir_inc'],
                       a95=site['dir_alpha95'],
                       color=col)

# %% [markdown]
# Above, green poles were included by Elston et al. (2002). The red site was excluded due to rotation.

# %% [markdown]
# ## Recalculate pole

# %%
# Elston's subset
sites_subset = sites_tilt[sites_tilt['result_quality'] == 'g']

_, pole_subset = pt.compute_mean_pole(sites_subset, flip=True)

map_axis = ipmag.make_orthographic_map(200, 0, figsize=(5,5))

ipmag.plot_pole(map_axis, plon=pole_subset['dec'], 
                   plat=pole_subset['inc'], 
                   A95=pole_subset['alpha95'], 
                   color = 'blue', marker='s', label='Subset of sites')

# All
_, pole_all = pt.compute_mean_pole(sites_tilt, flip=True)

ipmag.plot_pole(map_axis, plon=pole_all['dec'], 
                   plat=pole_all['inc'], 
                   A95=pole_all['alpha95'], 
                   color = 'red', marker='s', label='All sites')

_ = plt.legend(loc='best')

# %% [markdown]
# The blue calculated pole is very close to the red one. Visually, the excluded site does look rotated. We suggest using the subset chosen by Elston et al. (2002).

# %% [markdown]
# ## Site Mean Direction Calculations

# %%
dir_block, dir_mean = pt.compute_mean_direction(sites_subset)
ipmag.print_direction_mean(dir_mean)

ipmag.plot_net()
ipmag.plot_di(di_block=dir_block, color='blue', marker='o')
ipmag.plot_di_mean(dir_mean['dec'], dir_mean['inc'], dir_mean['alpha95'], 
                   color='red', marker='s')
ipmag.plt.title('Mean Site Directions (as measured at sites)')
ipmag.plt.show()
# Out:
# Dec: 28.4  Inc: -32.5
# Number of directions in mean (n): 4
# Angular radius of 95% confidence (a_95): 9.1
# Precision parameter (k) estimate: 102.2

# %%
centroid1 = np.mean(sites_subset['lat'], axis=0)
centroid2 = np.mean(sites_subset['lon'], axis=0)
print(f"Centroid Latitude: {centroid1:.6f}, Longitude: {centroid2:.6f}")
# Out:
# Centroid Latitude: 46.717500, Longitude: 246.345000

# %% [markdown]
# We will unite to the 46.72ºN, -113.66ºE (a rough centroid of the included sites.)

# %%
study_lat = 46.72
study_lon = -113.66

# %% [markdown]
# # Get bedding from tilt correction to do fold test

# %%
# Only for subset of Elston's; one of these doesn't have geographic coordinate
# information or bedding strike-dip, so is also excluded.

sites_geolist = sites_geo.loc[
    sites_geo["site"].isin(sites_subset["site"]),
    "site",
].tolist()

decs_fold = []
incs_fold = []
dip_dirs = []
dips = []

for site in sites_geolist:
    dec_geo = float(sites_geo.loc[sites_geo["site"] == site, "dir_dec"].iloc[0])
    inc_geo = float(sites_geo.loc[sites_geo["site"] == site, "dir_inc"].iloc[0])
    dec_tilt = float(sites_tilt.loc[sites_tilt["site"] == site, "dir_dec"].iloc[0])
    inc_tilt = float(sites_tilt.loc[sites_tilt["site"] == site, "dir_inc"].iloc[0])

    dip_dir, dip = pmag.get_tilt(dec_geo, inc_geo, dec_tilt, inc_tilt)

    decs_fold.append(dec_geo)
    incs_fold.append(inc_geo)
    dip_dirs.append(dip_dir)
    dips.append(dip)

diddd = ipmag.make_diddd_array(decs_fold, incs_fold, dip_dirs, dips)

# %%
ipmag.bootstrap_fold_test(diddd)
# Out:
# doing  1000  iterations...please be patient.....
# tightest grouping of vectors obtained at (95% confidence bounds):
# -9 - 119 percent unfolding
# range of all bootstrap samples:
# -9  -  119 percent unfolding

# %% [markdown]
# The fold test is inconclusive due to the low number of sites.
#
# Bedding dips range from 5.5° to 25° and the samples are scattered across separate fault panels/blocks.  Regional folding and faulting definitely occured in the Cretaceous, but it is unclear if earlier events occurred.  Many workers suggest synsedimentary normal faulting in the lower Belt Supergroup units. There is also the proposed Kootenay orogeny (1370–1300 Ma), as well as widespread metamorphism documented in the Belt Supergroup, with ages around 1100 Ma (Lonn et al. 2020).

# %% [markdown]
# ## Pole in the context of the Laurentia APWP

# %%
Laurentia_poles = pt.get_Laurentia_poles()
Laurentia_poles = pt.plot_apwp_context(Laurentia_poles, pole_subset['inc'], pole_subset['dec'], pole_subset['alpha95'])

# %% [markdown]
# ## R2: Deenen test

# %%
pt.Deenen_test(pole_subset['n'], pole_subset['alpha95'])
_ = pt.plot_Deenen_test(pole_subset)
# Out:
# A_95 of 7.9 passes Deenen et al. (2011) criteria of being between 6.9 and 34.2 for this number of sites

# %% [markdown]
# ## R7: Comparison with younger Laurentia poles

# %%
Laurentia_stricto_poles = pt.get_Laurentia_stricto_poles()
_ = pt.plot_pole_overlap('McNamara Formation (Elston et al. 2002)',
                     Laurentia_stricto_poles, pt.Torsvik2012_Laurentia,
                     pole_plat=pole_subset['inc'], pole_plon=pole_subset['dec'],
                     pole_A95=pole_subset['alpha95'], pole_age=719)

# %% [markdown]
# ## R-score summary (Meert et al., 2020)
#
# | R | Criterion | Score | Justification |
# |---|---|---|---|
# | 1 | Age within ± 15 Ma | **1** | One SHRIMP U-Pb zircon age of 1401 ± 6 Ma in tuff at base of unit and one TIMS U-Pb zircon age of 1379 ± 1 Ma in intrusive from lower in the section; from Evans et al. (2000) and Doughty and Chamberlain (1996). |
# | 2 | Techniques and statistical analysis | **0** | (a) Only thermal demagnetization was used; however, these are red-beds (b) Blanket demagnetization was used with majority of sites at <600°C so fits have both pigmentary and detrital hematite. (c) N = 76 samples in 4 sites, k = 102.2, A95 = 9.1° cannot have a Deenen et al. (2011) test applied. B = 4 sites ≦ 8 sites so fails. |
# | 3 | Magnetic mineralogy characterized | **0** | Only thermal stepwise demagnetization used. |
# | 4 | Field tests constrain age of magnetization | **0** | Inconclusive regional fold test, timing of folding unclear -- Cretaceous at latest |
# | 5 | Structural control / tectonic coherence | **0** | No inclination shallowing correction applied. Questions about tectonic coherence as entirely on separate thrust sheets, but historically the Belt Supergroup has been treated at part of Laurentia due to underlying basement in one region|
# | 6 | Presence of reversals | **0** | Contains no reversals|
# | 7 | No resemblance to younger poles | **1** | No overlap with younger poles |
# | | **Total R-score** | **2/7** | |

# %% [markdown]
# ## Nordic workshop ranking
#
# Prior Nordic Workshop compilations of paleomagnetic poles with expert-assigned rankings (Evans et al., 2021) have given the pole from the Spokane Formation an 'A' ranking.
#
# Our assessment is that careful evaluation of the pole suggests it should be assigned a 'B' ranking, primarily due to the statistical/laboratory methodology used which make R2, R3, and R5 scores of 0.   Although the R-score is lower than most B poles, the number of samples is high.

# %%
Garnet_Range_summary = pt.make_nordic_summary(terrane='Laurentia', 
    lithology='sedimentary',
                                        rockname='Pilcher, Garnet Range, Libby', 
                                        sites=sites_subset,
                                        dir_mean=dir_mean,
                                        pole_mean=pole_subset,
                                        study_lon=study_lon,
                                        study_lat=study_lat,
                                        component_comment='',
                                        tests='f',
                                        R1=1,
                                        R2=0,
                                        R3=0,
                                        R4=0,
                                        R5=0,
                                        R6=0,
                                        R7=1,
                                        Grade='B', Grade_E21='A',
                                        nominal_age=1385,
                                        lomagage=1378,
                                        himagage=1407,
                                        REF_method='One SHRIMP U-Pb zircon age of 1401 ± 6 Ma in tuff at base of unit and one TIMS U-Pb zircon age of 1379 ± 1 Ma in intrusive from lower in the section; from Evans et al. (2000) and Doughty and Chamberlain (1996).',
                                        POLE_AUTHORS='Elston, D. P., Enkin, R. J., Baker, J., and Kisilevsky, D. K. ',
                                        YEAR=2002,
                                        JOURNAL='Geological Society of America Bulletin',
                                        VOLUME=114,
                                        VPAGES='619-638',
                                        TITLE='Tightening the Belt: Paleomagnetic-stratigraphic constraints on deposition, correlation, and deformation of the Middle Proterozoic (ca. 1.4 Ga) Belt-Purcell Supergroup, United States and Canada',
                                        COMMENT='Recalculated from the site VGPs as documented in Swanson-Hysell et al. 2026.'
                                        )
Garnet_Range_summary
# Out:
#      Terrane                      ROCKNAME GPMDB RESULT# MAGIC # COMPONENT  \
# 0  Laurentia  Pilcher, Garnet Range, Libby
#
#   TESTS  TILT   SLAT   SLONG  B   N   DEC   INC     KD  ED95  PLAT  PLONG DP  \
# 0     f   100  46.72 -113.66  4  76  28.4 -32.5  102.2   9.1 -20.6  217.6
#
#   DM  A95  f (1.0 vs 0.6)  INCf  PLATf  PLONf  DPf   DMf  A95f  \
# 0     7.9             0.6 -46.7   11.1   41.0  7.6  11.8   9.4
#
#    f (1.0/0.8/0.6)  INCf  PLATf  PLONf  DPf   DMf  A95f %REV DEMAGCODE Q1 24  \
# 0              0.6 -46.7   11.1   41.0  7.6  11.8   9.4
#
#   10 16 Q2 Q3 Q4 Q5 Q6 Q7 Q(7)  R1  R2  R3 R4  R5  R6  R7  Rsum Grade  \
# 0                                1   0   0      0   0   1     2     B
#
#   Grade E+21  nominal age  age diff  lomagage  himagage  \
# 0          A         1385        29      1378      1407
#
#                                           REF/method  \
# 0  One SHRIMP U-Pb zircon age of 1401 ± 6 Ma in t...
#
#                        ROCKNAME  \
# ...

# %%
# save the summary dictionary as a single-row CSV in data/nordic_summaries
pt.save_nordic_summary(Garnet_Range_summary, '1385_Garnet_Range')
# Out:
# '../data/nordic_summaries/1385_Garnet_Range.csv'

# %% [markdown]
# ## Inclination-shallowing-corrected pole
#
# The pole above is reported as measured. Detrital remanence in sedimentary rocks
# is shallowed during compaction, so its inclination — and the paleolatitude that
# inclination implies — is a minimum. Only site-level mean directions are available for these units (4 sites), far too few for an elongation/inclination (E/I) or SVEI determination of the flattening factor.
#
# Following Pierce et al. (2022), the flattening factor is instead resampled from
# their compilation of measured *f* values (`ipmag.find_compilation_kent`). Each
# resample unsquishes the mean direction implied by the pole at the sampling
# locality, and the resulting distribution of mean poles is summarized as a Kent
# (1982) distribution whose 95% confidence ellipse carries the flattening
# uncertainty along with the uncertainty in the pole itself. This corrected pole
# is exported to `data/nordic_summaries/kent/` and is the position plotted for
# this unit in the compilation figures; the main compilation table keeps the
# uncorrected pole.

# %%
# Inclination-shallowing-corrected Kent mean pole (Pierce et al., 2022). The
# random seed is fixed so the exported summary is reproducible.
kent = pt.compilation_kent_pole(pole_subset, study_lon, study_lat, random_seed=1)
plt.show()

Garnet_Range_kent_summary = pt.make_kent_summary(
    Garnet_Range_summary, kent, 'compilation', 'this study',
    comment='4 site-level mean directions: too few for an E/I or SVEI determination of f')
pt.save_kent_summary(Garnet_Range_kent_summary, '1385_Garnet_Range')
Garnet_Range_kent_summary
# Out:
# Plon: 221.2  Plat: -11.1
# Major axis lon: 282.3  Major axis lat: 67.9
# Minor axis lon: 135.0  Minor axis lat: 18.9
# Major axis angle of 95% ellipse (Zeta): 14.5
# Minor axis angle of 95% ellipse (Eta): 8.0
# Number of directions in mean (n): 1000000
#      Terrane                      ROCKNAME Lithology   SLAT   SLONG  \
# 0  Laurentia  Pilcher, Garnet Range, Libby   Redbeds  46.72 -113.66
#
#    nominal age  lomagage  himagage Grade                             f method  \
# 0         1385      1378      1407     B  compilation f (Pierce et al., 2022)
#
#      f source     f  f low  f high  PLAT uncorrected  PLONG uncorrected  \
# 0  this study  0.62   0.43    0.91             -20.6              217.6
#
#    A95 uncorrected  PLAT  PLONG   Zdec  Zinc  Zeta   Edec  Einc  Eta   A95  \
# 0              7.9 -11.1  221.2  282.3  67.9  14.5  135.0  18.9  8.0  10.8
#
#    n resampled                                            Comment
# ...
