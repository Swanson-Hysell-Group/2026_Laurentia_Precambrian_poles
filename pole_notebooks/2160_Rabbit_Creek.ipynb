# %% [markdown]
# # Rabbit Creek ca. 2160 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia-Wyoming.
# - Compiled unit/pole label: Rabbit Creek, Powder River and South Path Dykes.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 13 sites, N = 81 samples; mean direction DEC/INC = 212.8°/-59.0°; K = 48.5; A95 = 7.6°.
# - Field/statistical tests noted in compilation: C+,Rc
# .
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current compiled age: nominal age 2160.0 Ma, lomagage 2152.0 Ma, himagage 2171.0 Ma.
# - Compilation method note: Kilian et al. 2015 study reported paleomagnetic data and U-Pb baddeleyite dates from four samples that yielded Powder River Pass dyke (2163.9$\pm$7.1 Ma), Wind River –South Pass dyke (2164.1+7.3 Ma), ‘French Creek’ diabase dyke (2155.9$\pm$2.9 Ma), and ‘Rabbit Creek’ diabase dyke (2154.2$\pm$2.2 Ma), and ‘Dike C’ near Hazelton Peak (2157.7$\pm$3.6 Ma). So the age range we should use would cover the range reported including uncertainty propagations. Let's do nominal age=2160 Ma,lomagage=2152 Ma, himagage=2171 Ma.
#
#
# ## References
#
# - Paleomagnetic source: Kilian, T.M., Bleeker, W., Chamberlain, K., Evans, D.A.D., Cousens, B. (2015). Palaeomagnetism, geochronology and geochemistry of the Palaeoproterozoic Rabbit Creek and Powder River dyke swarms: implications for Wyoming in supercraton Superia. Geological Society, London, Special Publications, 424, 15–45.
# - Geochronology / age-constraint note (compilation): U-Pb baddeleyite: 2156+/-3  2154+/-3  2158+/-4  2164+/-7  2164+/-7 Ma

# %%
import sys
sys.path.append('../data/')
from pole_tools import *

Laurentia_poles = get_Laurentia_poles() # get all poles
Laurentia_stricto_poles = get_Laurentia_stricto_poles() # get only Laurentia poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
R2_test('Rabbit Creek, Powder River and South Path Dykes',Laurentia_poles)
# Out:
# N = 81 (N ≥ 25; sufficient sample number);
# B = 13 (B ≥ 8; sufficient site number);
# K = 48 (70 ≥ K ≥ 10; meets PSV criteria);
# A_95 of 7.6 passes Deenen et al. (2011) criteria of being between 4.3 and 16.3 for this number of sites

# %%
plot_pole_overlap('Rabbit Creek, Powder River and South Path Dykes',Laurentia_poles,Torsvik2012_Laurentia)
