# %% [markdown]
# # Baie B ca. 583 Ma paleomagnetic pole
#
# ## Geologic Context
#
# - Terrane: Laurentia.
# - Compiled unit/pole label: Baie des Moutons complex B.
#
# ## Paleomagnetic And Rock Magnetic Data
#
# - B = 6 sites, N = 56 samples; mean direction DEC/INC = 163.1°/6.0°; K = 10.5.
# - Component note: B direction.
# - Rock-magnetic interpretation: expand with mineral carriers/coercivity/unblocking evidence from source studies.
#
# ## Age Constraints
#
# - Current bracket: lomagage 581.0 Ma, himagage 585.0 Ma.
# - Compilation method note: 583.4±2.0 Ma weighted mean of four hornblende 40Ar–39Ar plateau ages from sites MB20 (B component site) and MB44 (A component site) from McCausland et al 2011 (same study as pole)
#
# ## References
#
# - Paleomagnetic source: McCausland, P.J.A., Hankard, F., Van der Voo, R., Hall, C.M. (2011). Ediacaran paleogeography of Laurentia: Paleomagnetism and 40Ar–39Ar geochronology of the 583Ma Baie des Moutons syenite, Quebec. Precambrian Res., 187, 58-78.
# - Geochronology / age-constraint note (compilation): 583.4±2.0 Ma weighted mean of four hornblende 40Ar–39Ar plateau ages from sites MB20 (B component site) and MB44 (A component site) from McCausland et al 2011 (same study as pole)

# %% [markdown]
# ## import python libraries

# %%
import pole_tools as pt

Laurentia_poles = pt.get_Laurentia_poles()  # get all poles
Laurentia_stricto_poles = pt.get_Laurentia_stricto_poles()  # Laurentia-only poles

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
pt.R2_test('Baie des Moutons complex B', Laurentia_poles)
# Out:
# N = 56 (N ≥ 25; sufficient sample number);
# B = 6 (B < 8; insufficient site number);
# K = 10 (70 ≥ K ≥ 10; meets PSV criteria);
# A_95 of 15.4 passes Deenen et al. (2011) criteria of being between 5.9 and 26.5 for this number of sites

# %%
pt.plot_pole_overlap('Baie des Moutons complex B', Laurentia_stricto_poles, pt.Torsvik2012_Laurentia)
